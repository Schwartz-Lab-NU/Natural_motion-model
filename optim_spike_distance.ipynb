# %% [markdown]
# # Spike distance

# %%
from neo.core import SpikeTrain
from quantities import ms
import numpy as np
import pickle
import quantities as pq
from elephant.spike_train_dissimilarity import victor_purpura_distance
import matplotlib.pyplot as plt
from scipy.optimize import differential_evolution
from scipy.special import expit
from scipy.stats import wasserstein_distance
import matplotlib.patches as patches
import h5py
from scipy.signal import convolve
from scipy.interpolate import griddata
import pickle

def compute_emd_matrix(spike_trains):
    """
    Compute a pairwise EMD distance matrix for a list of spike trains.
    
    Parameters:
        spike_trains: list of lists, where each sublist is a spike train
    
    Returns:
        emd_matrix: 2D numpy array of shape (N, N) with pairwise EMD values
    """
    num_trials = len(spike_trains)
    emd_matrix = np.zeros((num_trials, num_trials))

    for i in range(num_trials):
        for j in range(i + 1, num_trials):  # Only compute upper triangle
            emd = wasserstein_distance(spike_trains[i], spike_trains[j])
            emd_matrix[i, j] = emd
            emd_matrix[j, i] = emd  # Symmetric matrix

    return emd_matrix

def plot_matrix(matrix, title="Pairwise EMD Distance Matrix"):
    """
    Plots a matrix as a heatmap using Matplotlib.

    Parameters:
        matrix: 2D numpy array to be visualized.
        title: Title of the plot.
    """
    plt.figure(figsize=(10, 8))
    plt.imshow(matrix, cmap="coolwarm", aspect="auto")
    plt.colorbar(label="EMD Distance")
    plt.title(title)
    plt.xlabel("Trial Index")
    plt.ylabel("Trial Index")
    plt.show()
    
def block_means(matrix,n_groups, group_size):
# Initialize an array to store the averaged values.
    block_means = np.zeros((n_groups, n_groups))

    # Loop through each block, compute its mean, and store it.
    for i in range(n_groups):
        for j in range(n_groups):
            
            block = matrix[i*group_size:(i+1)*group_size, j*group_size:(j+1)*group_size]
            # Compute the average of the block.
            block_means[i, j] = block.mean()
    return block_means

def block_stats_all(matrix, n_real):

    real_real = matrix[0:n_real, 0:n_real]
    real_model = matrix[0:n_real, n_real:]
    model_model = matrix[n_real:, n_real:]
    
    stats = []
    for label, block in zip(["Real–Real", "Real–Model", "Model–Model"],
                              [real_real, real_model, model_model]):
        mean_val = block.mean()
        range_val = block.max() - block.min()
        std_val = block.std()
        cv_val = std_val / mean_val if mean_val != 0 else 0
        stats.append([label, f"{mean_val:.2f}", f"{range_val:.2f}", f"{std_val:.2f}", f"{cv_val:.2f}"])
    return stats

def plot_matrixcat_and_stats(matrix, title="Pairwise EMD Distance Matrix", n_real=None, n_model=None, group_size=None):
    """
    Plots a heatmap of the matrix with:
      - A category bar above (dividing trials into "Real" and "Model").
      - (Optional) Block mean annotations inside the heatmap if group_size is provided.
      - A table below the heatmap displaying statistics computed for three blocks:
            • Real–Real (real vs. real)
            • Real–Model (real vs. model)
            • Model–Model (model vs. model)
      
      The table columns are: Block, Mean, Range, Std, and CV (with CV as the last column).
    
    Parameters:
      - matrix: 2D numpy array (assumed square).
      - title: Title for the heatmap.
      - n_real: Number of real trials (left portion). Defaults to half the number of columns.
      - n_model: Number of model trials (right portion). Defaults to the remainder.
      - group_size: If provided, used for annotating the heatmap with block means.
                    For a 2x2 division of a square matrix, use group_size = matrix.shape[0]//2.
    """
    # Total number of trials (columns)
    N = matrix.shape[1]
    if n_real is None or n_model is None:
        n_real = N // 2
        n_model = N - n_real

    # Create the main heatmap with colorbar.
    fig, ax = plt.subplots(figsize=(8, 8))
    im = ax.imshow(matrix, cmap="coolwarm", aspect="auto")
    ax.set_xlabel("Trial Index")
    ax.set_ylabel("Trial Index")
    ax.set_title(title, fontsize=12, pad=30)
    fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04, label="EMD Distance")

    # Get the position of the heatmap axis.
    pos = ax.get_position()
    gap_val = 0.005         # Vertical gap between the heatmap and the category bar.
    cat_bar_height = 0.03     # Height of the category bar.

    # Create a new axis above the heatmap for the category bar.
    cat_ax = fig.add_axes([pos.x0, pos.y0 + pos.height + gap_val, pos.width, cat_bar_height])
    cat_ax.set_xlim(0, N)
    cat_ax.set_ylim(0, 1)
    cat_ax.axis("off")

    # Define a gap (in trial units) between the two black bars.
    gap = 2  
    real_width = n_real - gap / 2
    model_width = n_model - gap / 2

    # Draw the "Real" bar (black) covering the real trials.
    cat_ax.add_patch(patches.Rectangle((0, 0), real_width, 0.21, facecolor="black"))
    # Draw the "Model" bar (black) covering the model trials.
    cat_ax.add_patch(patches.Rectangle((n_real + gap/2, 0), model_width, 0.21, facecolor="black"))

    # Add text labels over each bar.
    cat_ax.text(real_width / 2, 0.5, "Real", ha="center", va="bottom", fontsize=10, fontweight="bold", color="black")
    cat_ax.text(n_real + gap/2 + model_width / 2, 0.5, "Model", ha="center", va="bottom", fontsize=10, fontweight="bold", color="black")

    # Create an axis for the statistics table below the heatmap.
    table_height = 0.15  # Adjust table height as needed.
    table_ax = fig.add_axes([pos.x0, pos.y0 - table_height - 0.1, pos.width, table_height])
    table_ax.axis('off')
    
    # Compute block statistics for three blocks.
    stats = block_stats_all(matrix, n_real)
    column_labels = ["Block", "Mean", "Range", "Std", "CV"]
    cell_text = stats  # Each row: [Block, Mean, Range, Std, CV]
    
    table = table_ax.table(cellText=cell_text, colLabels=column_labels, loc='center', cellLoc='center')
    table.auto_set_font_size(False)
    table.set_fontsize(10)
    table.scale(1, 2)
    table_ax.set_title("Block Statistics", fontsize=12, pad=10)
    
    plt.show()

def generate_stimuli(trajx, trajy,board_size=400, diameter=30,fps = 60,pretime = 50,tailtime =50,type='natural',preframes=15,tailframes=45,stimframes=15):
    stimuli = []
    dt = 1/fps

    board_range = [-(board_size/2), (board_size/2)]  
    radius = diameter / 2  

    x_vals = np.linspace(board_range[0], board_range[1], board_size+1)
    y_vals = np.linspace(board_range[0], board_range[1], board_size+1)
    X, Y = np.meshgrid(x_vals, y_vals)
    
    if type == 'natural':
        if len(trajx) != len(trajy):
            raise ValueError("trajx and trajy must have the same length.")
        if len(trajx) == 0:
            raise ValueError("Trajectory arrays must not be empty.")

        preframenum = int(pretime / 1000 /dt)
        tailframenum = int(tailtime / 1000 /dt)
        for _ in range(preframenum):
            frame = np.zeros((board_size+1, board_size+1), dtype=np.uint8)
            stimuli.append(frame)   
        
        for frame_idx, (x, y) in enumerate(zip(trajx, trajy)):
            # if frame_idx < preframenum or frame_idx >= (len(trajx) - tailframenum):
            #     # Draw blank
            #     frame = np.zeros((board_size, board_size), dtype=np.uint8)
            # else:
                # Draw the circle
            frame = np.zeros((board_size+1, board_size+1), dtype=np.uint8)
            mask = (X - x) ** 2 + (Y - y) ** 2 <= radius ** 2
            frame[mask] = 1

            stimuli.append(frame)   
            
        for _ in range(tailframenum):
            frame = np.zeros((board_size+1, board_size+1), dtype=np.uint8)
            stimuli.append(frame)   
    if type == 'spotfield':
        if len(trajx) != len(trajy):
            raise ValueError("trajx and trajy must have the same length.")
        if len(trajx) == 0:
            raise ValueError("Trajectory arrays must not be empty.")

    
        for section_idx, (x, y) in enumerate(zip(trajx, trajy)):
            frame = np.zeros((board_size+1, board_size+1), dtype=np.uint8)
            for _ in range(preframes):
                stimuli.append(frame)   
                
            frame = np.zeros((board_size+1, board_size+1), dtype=np.uint8)
            mask = (X - x) ** 2 + (Y - y) ** 2 <= radius ** 2
            frame[mask] = 1
            for _ in range(stimframes):
                stimuli.append(frame)   
            frame = np.zeros((board_size+1, board_size+1), dtype=np.uint8)
            for _ in range(tailframes):
                stimuli.append(frame)   
        
    return np.array(stimuli)


def spatial_filterSF(rf,A=0.2):
    return A * rf

def gaussian_2d(x, y, sigma_x, sigma_y, A=0.2, x0=0, y0=0):
    X, Y = np.meshgrid(x, y, indexing='ij')
    return A * np.exp(-((X - x0)**2 / (2 * sigma_x**2) + (Y - y0)**2 / (2 * sigma_y**2)))


def difference_of_gaussians(x, y, sigma_c, sigma_s, A_c=0.4, A_s=0.2):
    X, Y = np.meshgrid(x, y, indexing='ij')
    center = A_c * np.exp(-(X**2 + Y**2) / (2 * sigma_c**2))
    surround = A_s * np.exp(-(X**2 + Y**2) / (2 * sigma_s**2))
    return center - surround

def biphasic_temporal_filter(t, 
                             t_neg=40, t_pos=400, t_peak=120, 
                             sigma_neg=18, sigma_pos=56,
                             rel_ampli=1):
    t_shifted = t - t[0]

    # Negative phase
    negative_phase = - (t_shifted / t_neg) \
                     * np.exp(-((t_shifted - t_neg)**2)/(2*sigma_neg**2))

    # Positive phase
    positive_phase =  (t_shifted / t_pos) \
                     * np.exp(-((t_shifted - t_peak)**2)/(2*sigma_pos**2))

    temporal_filter = rel_ampli*negative_phase + (positive_phase)

    # Normalize so the max abs value is 1
    temporal_filter /= np.max(np.abs(temporal_filter))
    return temporal_filter

def apply_temporal_filter_to_movie(movie, temporal_filter):

    F, = movie.shape  
    T = len(temporal_filter) 

    filtered_movie = np.zeros_like(movie)

    filtered_signal = convolve(movie, temporal_filter, mode='full')[:F]
    
    filtered_movie[:] = filtered_signal

    return filtered_movie

def linear_filter(sigma_x, sigma_y, A, sigma_c, sigma_s, A_c, A_s , noise_input, temporal_filter, type,rf_estimated):   

    T, Y, X = noise_input.shape 
    x = np.linspace(-(X-1)/2, (X-1)/2, X)
    y = np.linspace(-(Y-1)/2, (Y-1)/2, Y)
    noise_input = noise_input.astype(np.float32)
    
    if type == 'gaussian':
        spatial_rf = gaussian_2d(x, y, sigma_x, sigma_y, A, x0=0, y0=0) # Shape: (Y,X)
    if type == 'difference_of_gaussians':
        spatial_rf = difference_of_gaussians(x, y, sigma_c, sigma_s, A_c, A_s)  # Shape: (Y,X)
    if type == 'SFfitting':
        spatial_rf = spatial_filterSF(rf=rf_estimated,A=A)
    spatial_rf = spatial_rf.astype(np.float32)   
    spatial_filtered_movie = noise_input.reshape((T,Y*X)) @ spatial_rf.reshape((Y*X))  # Shape: (T,)
    filtered_movie = apply_temporal_filter_to_movie(spatial_filtered_movie, temporal_filter)

    return filtered_movie

def apply_nonlinearity(linear_output, method='static', **kwargs):
    if method == 'static':
        return np.maximum(0, linear_output)
    elif method == 'sigmoid':
        gain = kwargs.get('gain', 0.02)
        max_rate = kwargs.get('max_rate', 250.0)
        C = kwargs.get('y', -30)
        return max_rate * expit(gain * (linear_output + C))
    elif method == 'sigmoidgc':
        gain = kwargs.get('gain', 0.05)
        max_rate = kwargs.get('max_rate', 1500.0)
        C = kwargs.get('y', -37256.659)
        return max_rate / (0.04 + np.exp(-gain * (linear_output+165)))  + C
    elif method == 'threshold_linear':
        theta = kwargs.get('theta', 10)
        return np.maximum(0, linear_output - theta)
    elif method == 'threshold_lineargc':
        theta = kwargs.get('theta', 0)
        return np.maximum(0, linear_output - theta)
    elif method == 'powerlaw':
        gamma = kwargs.get('gamma', 0.5)
        return np.maximum(0, np.abs(linear_output)**gamma)
    elif method == 'exponential_saturation':
        alpha = kwargs.get('alpha', 0.1)
        beta = kwargs.get('beta', 1.0)
        return beta * (1 - np.exp(-alpha * linear_output))
    elif method == 'adaptive_gain':
        gain = kwargs.get('gain', 1.0)
        return gain * np.maximum(0, linear_output)
    else:
        raise ValueError("Unknown nonlinearity method")
    



# Gain control definition
def resample_and_generate_spikes(firing_rates, target_time_bin=1/1200):


    original_time_bin = 1 / 60

    upsampling_factor = int(original_time_bin / target_time_bin)
    if upsampling_factor < 1:
        raise ValueError("Target time bin must be smaller")

    expanded_firing_rates = np.repeat(firing_rates, upsampling_factor, axis=0)


    scaled_rates = expanded_firing_rates * target_time_bin


    spikes = np.random.poisson(scaled_rates)

    return spikes

def gain_control(Lout, B=0.005, tau=11.0):

    T = len(Lout)  
    v_t = np.zeros(T)  
    g_v = np.zeros(T)
    gain_controlled_Lout = np.zeros(T) 
    gain_controlled_Lout[0] = 1 * Lout[0]
    decay_kernel = B * np.exp(-np.arange(T) / tau)

    for t in range(T):
        v_t[t] = np.sum(gain_controlled_Lout[:t] * decay_kernel[:t][::-1]) 
        g_v[t] = 1 if v_t[t] < 0 else 1 / (1 + v_t[t]**4)
        gain_controlled_Lout[t] = g_v[t] * Lout[t]

    return gain_controlled_Lout, g_v


rf_estimated = np.load('rf_estimated.npy')
with open('spike_trainGC.pkl', 'rb') as f:
    spike_trainGC = pickle.load(f)


with open('spike_indices_n.pkl', 'rb') as f:
    spike_indices_n = pickle.load(f)

with open('spike_indices_c.pkl', 'rb') as f:
    spike_indices_c = pickle.load(f)



spike_indicesModified_n = spike_indices_n.copy()
spike_indicesModified_c = spike_indices_c.copy()
spike_indicesModified_n[4] = spike_indices_n[4]-800
spike_indicesModified_n[45] = spike_indices_n[45]-800
spike_indicesModified_c[34] = spike_indices_c[34]-800

# %% [markdown]
# # model PARAM

# %%
delay = 0.083 # s
# Parameter settting for model
temporal_filter_noise = np.load('temporal_filter5.npy')
reversed_temp_rfTemp = temporal_filter_noise[::-1]
stimuli_n = np.load('stimuli_n.npy')
stimuli_c = np.load('stimuli_c.npy')
# parameters for the LN-GC 
stimuli = stimuli_n
spike_indices = spike_indicesModified_n
t_sampling = np.linspace(0,1860,1860)


time_para = 5400 # time bin to generate spike
num_modeltrails = 60 #
# temporal filter 
# t_temporal = np.linspace(-500, 0, 30) 
# temp_rf = biphasic_temporal_filter(t_temporal, t_neg=60,t_pos=100, t_peak=400, sigma_neg=90, sigma_pos=20,rel_ampli=0.6)

# spatial filter
sigma_x, sigma_y = 70,70   #normal
sigma_c, sigma_s = 70, 140  #diff
A_c=0.4 # center
A_s=0.2 # surround

# gain control
# nonLinear filter
spatialtype = 'SFfitting'
gainGC = 0.04
max_rateGC = 1500
y_CGC = -37256.659

theta = 30
A     = 0.8923
B     = 0.000505
tau   = 8.13
pnratio = 0.631
gain = 0.00213
max_rate = 200
y = -800
reversed_temp_rf = np.concatenate((reversed_temp_rfTemp[0:8], reversed_temp_rfTemp[8:] * pnratio))

# %%
# model output
# LN model
spike_trainLN = []
LoutLN = linear_filter(sigma_x, sigma_y, A, sigma_c, sigma_s, A_c, A_s, stimuli, reversed_temp_rf, spatialtype, rf_estimated)
LNoutLN = apply_nonlinearity(apply_nonlinearity(LoutLN, method='sigmoid',gain = gain, max_rate = max_rate, y = y), method='threshold_linear',theta = theta)

time_bin = 1/time_para
for trial in range(num_modeltrails):
    spikingindx=(resample_and_generate_spikes(LNoutLN, time_bin))
    spike_trainLN.append(np.where(spikingindx > 0))


#LN model with gain control
spike_trainGC = []
LoutGC = linear_filter(sigma_x, sigma_y, A, sigma_c, sigma_s, A_c, A_s, stimuli, reversed_temp_rf, spatialtype,rf_estimated)
LoutGC, g = gain_control(LoutGC, B, tau)
LNoutGC = apply_nonlinearity(apply_nonlinearity(LoutGC, 'sigmoid',gain = gain, max_rate = max_rate, y = y), method='threshold_linear',theta = theta)
time_bin = 1/time_para
for trial in range(num_modeltrails):
    spikingindx=(resample_and_generate_spikes(LNoutGC, time_bin))
    spike_trainGC.append(np.where(spikingindx > 0))

# %% [markdown]
# # Spike distance and raster

# %%
spike_trains_n = []
spike_trains_model = []
spike_trains_nemd = []
spike_trains_modelemd = []
for trial_idx, spikes in enumerate(spike_indices):
    st_n = SpikeTrain(spikes.flatten() / 10 * ms, t_stop=31000)
    st_narray = spikes.flatten() / 10
    st_model = SpikeTrain(np.array(spike_trainGC[trial_idx]).flatten() /54*10 * ms, t_stop=31000)
    st_modelarray = np.array(spike_trainGC[trial_idx]).flatten() /54*10
    spike_trains_n.append(st_n)
    spike_trains_model.append(st_model)
    spike_trains_nemd.append(st_narray)
    spike_trains_modelemd.append(st_modelarray)

spike_trains = [spike_trains_n[i] for i in range(len(spike_trains_n)) if i % 2 == 1] + spike_trains_model[:30]
spike_trainsemd = [spike_trains_nemd[i] for i in range(len(spike_trains_nemd)) if i % 2 == 1] + spike_trains_modelemd[:30]
q = 1.0 / (100.0 * pq.ms)

# %%
emd_matrix = compute_emd_matrix(spike_trainsemd)
vp_f = victor_purpura_distance(spike_trains, q)

# %%
plot_matrixcat_and_stats(emd_matrix, title="Pairwise EMD Distance Matrix", n_real=30, n_model=30, group_size=30)
plot_matrixcat_and_stats(vp_f, title="Pairwise VP distance Distance Matrix", n_real=30, n_model=30, group_size=30)

# %%
# plot for natural stimuli and gain control stimuli

fig, (ax1, ax2, ax3, ax4, ax5,ax6,ax7) = plt.subplots(7, 1, figsize=(12, 16), sharex=True)


num_trials_n = len(spike_indices)
spikes_n = []
for spike_idx_n in range(num_trials_n):
    spikes_in_trial = spike_indices[spike_idx_n] / 10000 - delay
    spikes_n.extend(spikes_in_trial)
    
spikes_n = np.array(spikes_n)


num_trials_modeln = len(spike_trainLN)

spikes_modeln = []
for spike_idx_n in range(num_trials_modeln):
    spikes_in_trial = np.array(spike_trainLN[spike_idx_n]) /time_para
    spikes_modeln.extend(spikes_in_trial)
    ax1.vlines(spikes_in_trial, spike_idx_n, spike_idx_n + 1, 'k', linewidth=0.6)

ax1.set_ylabel('Trial Number')
ax1.set_title('simulating Natural Stimuli Spike Raster(without gain control)')
ax1.set_xlim(0, 31)  

ax2.plot(t_sampling/60, LNoutLN, 'k')
ax2.set_xlabel('Time (s)')
ax2.set_ylabel('Firing Rate (Hz)')
ax2.set_title('LN Instantaneous Firing Rate Evoked by Natural Stimuli(without gain control)')


spikes_modeln = []
for spike_idx_n in range(num_trials_modeln):
    spikes_in_trial = np.array(spike_trainGC[spike_idx_n]) /time_para
    spikes_modeln.extend(spikes_in_trial)
    ax5.vlines(spikes_in_trial, spike_idx_n, spike_idx_n + 1, 'firebrick', linewidth=0.6)

ax5.set_ylabel('Trial Number')
ax5.set_title('Simulating Natural Stimuli Spike Raster(Gain Control)')
ax5.set_xlim(0, 31)  

ax6.plot(t_sampling/60, LNoutGC, 'firebrick')
ax6.set_xlabel('Time (s)')
ax6.set_ylabel('Firing Rate (Hz)')
ax6.set_title('LNGC Instantaneous Firing Rate Evoked by Natural Stimuli(gain control)')

bin_width = 1/60 # s
bins = np.arange(0, 31 + bin_width, bin_width) 
counts_n, bin_edges = np.histogram(spikes_n, bins=bins)
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
num_trials_n = len(spike_indices)
spikes_n = []
for spike_idx_n in range(num_trials_n):
    spikes_in_trial = spike_indices[spike_idx_n] / 10000 - delay
    spikes_n.extend(spikes_in_trial)
    ax3.vlines(spikes_in_trial, spike_idx_n, spike_idx_n + 1, 'k', linewidth=0.6)




ax3.set_ylabel('Trial Number')
ax3.set_title('Natural Stimuli Spike Raster(real)')
ax3.set_xlim(0, 31)  

average_spike_count_n = counts_n / num_trials_n
firing_rate_n = average_spike_count_n / bin_width

ax4.plot(bin_centers, firing_rate_n, 'k')
ax4.set_xlabel('Time (s)')
ax4.set_ylabel('Firing Rate (Hz)')
ax4.set_title('Instantaneous Firing Rate Evoked by Natural Stimuli(real)')

ax7.plot(bin_centers, firing_rate_n, 'k',label='Experiemntal')
ax7.plot(t_sampling/60, LNoutGC, 'r',label='Model-LNGC')
# ax7.plot(t_sampling/60, LNoutLN, 'b',label='Model-LN')
ax7.set_xlabel('Time (s)')
ax7.set_ylabel('Firing Rate (Hz)')
ax7.set_title('Instantaneous Firing Rate comparison(Natural)')
ax7.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # optimization

# %%
# Load data and define fixed parameters.

theta = 30
A     = 0.8923
B     = 0.000505
tau   = 8.13
pnratio = 0.631
gain = 0.00213
max_rate = 200
y = -800
def objectiveEMD(params, train=True):
    try:
        A, B, tau, pnratio = params
        # Modify the receptive field using the pnratio.
        reversed_temp_rf_fit = np.concatenate((reversed_temp_rfTemp[0:8], reversed_temp_rfTemp[8:] * pnratio))
        
        # Generate model spike trains.
        spike_trainGCfit = []
        LoutGCfit = linear_filter(sigma_x, sigma_y, A, sigma_c, sigma_s, 
                                  A_c, A_s, stimuli, reversed_temp_rf_fit, 'SFfitting', rf_estimated)
        LoutGCfit, g = gain_control(LoutGCfit, B, tau)
        LNoutGCfit = apply_nonlinearity(
            apply_nonlinearity(LoutGCfit, 'sigmoid', gain=gain, max_rate=max_rate, y=y),
            method='threshold_linear', theta=theta
        )
        time_bin = 1 / time_para

        # Generate spike trains over 30 trials.
        for trial in range(30): 
            spikingindx = resample_and_generate_spikes(LNoutGCfit, time_bin)
            spike_trainGCfit.append(np.where(spikingindx > 0)[0])
        
        # Convert spike indices into model spike train arrays.
        spike_trains_modelemdfit = []
        for spikes in spike_trainGCfit:
            st_modelarray = np.array(spikes).flatten() / 54 * 10
            spike_trains_modelemdfit.append(st_modelarray)

        # Choose the reference (real) spike trains based on the flag.
        if train:
            reference_spike_trains = [spike_trains_nemd[i] for i in range(len(spike_trains_nemd)) if i % 2 == 0]
        else:
            reference_spike_trains = [spike_trains_nemd[i] for i in range(len(spike_trains_nemd)) if i % 2 == 1]
 
        # Combine reference spike trains with the model's spike trains.
        spike_trainsfit = reference_spike_trains + spike_trains_modelemdfit

        # Check for empty spike trains.
        for st in spike_trainsfit:
            if len(st) == 0:
                return 1e10

        score_matrix = compute_emd_matrix(spike_trainsfit)
        scores = block_means(score_matrix, 2, 30)
        score = scores[0, 1]
        return score

    except Exception as e:
        print("Error in objectiveEMD with params", params, ":", e)
        return 1e10

def objectiveVP(params, train=True):

    try:
        A, B, tau, pnratio = params
        # Adjust the temporal filter with the pnratio.
        reversed_temp_rf_fit = np.concatenate((reversed_temp_rfTemp[0:8], reversed_temp_rfTemp[8:] * pnratio))
        
        spike_trainGCvpfit = []
        spike_trains_modelvp = []
        LoutGCvpfit = linear_filter(sigma_x, sigma_y, A, sigma_c, sigma_s,
                                  A_c, A_s, stimuli, reversed_temp_rf_fit, 'SFfitting', rf_estimated)
        LoutGCvpfit, g = gain_control(LoutGCvpfit, B, tau)
        LNoutGCvpfit = apply_nonlinearity(
            apply_nonlinearity(LoutGCvpfit, 'sigmoid', gain=gain, max_rate=max_rate, y=y),
            method='threshold_linear', theta=theta)
        time_bin = 1 / time_para

        # Generate 30 model spike trains.
        for trial in range(30):
            spikingindx = resample_and_generate_spikes(LNoutGCvpfit, time_bin)
            spike_trainGCvpfit.append(np.where(spikingindx > 0)[0])
            st_modelvp = SpikeTrain(np.array(spike_trainGCvpfit[trial]).flatten() / 54 * 10 * ms,t_stop=31000)
            spike_trains_modelvp.append(st_modelvp)
 
        # Select the appropriate real data trials.
        if train:
            real_spike_trains = [spike_trains_n[i] for i in range(len(spike_trains_n)) if i % 2 == 0]
        else:
            real_spike_trains = [spike_trains_n[i] for i in range(len(spike_trains_n)) if i % 2 == 1]
        
     
        # Combine the real and model-generated spike trains.
        spike_trainsvpfit = real_spike_trains + spike_trains_modelvp
        
        # Check for empty spike trains.
        for st in spike_trainsvpfit:
            if len(st) == 0:
                return 1e10

        # Compute the Victor-Purpura distance and block means.
        vp_matrix = victor_purpura_distance(spike_trainsvpfit, q)
        scoresvp = block_means(vp_matrix, 2, 30)
        scorevp = scoresvp[0, 1]
        return scorevp

    except Exception as e:
        print("Error in objectiveVP with params", params, ":", e)
        return 1e10

# Define bounds for A, B, tau, and pnratio.
bounds = [(0.1, 1), (0.0005, 1), (8, 25), (0.5, 3)]

# Prepare lists to store iteration data.
iterations = []
errors_train = []
errors_eval = []

def callbackF(xk, convergence):
    # Record current iteration number.
    iteration = len(iterations) + 1
    # Compute errors on training and evaluation sets.
    train_error = objectiveEMD(xk, train=True)
    eval_error = objectiveEMD(xk, train=False)
    iterations.append(iteration)
    errors_train.append(train_error)
    errors_eval.append(eval_error)
    print(f"Iteration {iteration}: Training Error = {train_error}, Evaluation Error = {eval_error}")

# Run differential evolution using only the training set.
result_de = differential_evolution(
    lambda params: objectiveEMD(params, train=True),
    bounds,
    strategy="rand1bin",
    maxiter=8,
    mutation=(0.5, 1),
    recombination=0.95,
    disp=True,
    callback=callbackF,
)

optimal_A, optimal_B, optimal_tau, optimal_pnratio = result_de.x

print("Optimal parameters found:")
print("A       =", optimal_A)
print("B       =", optimal_B)
print("tau     =", optimal_tau)
print("pnratio =", optimal_pnratio)

# Plot both training and evaluation error curves over iterations.
plt.figure(figsize=(10, 6))
plt.plot(iterations, errors_train, label="Training Error", marker='o')
plt.plot(iterations, errors_eval, label="Evaluation Error", marker='o')
plt.xlabel("Iterations")
plt.ylabel("Error (Lower is Better)")
plt.title("Error vs. Iterations During Optimization")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 131
#     128     print(f"Iteration {iteration}: Training Error = {train_error}, Evaluation Error = {eval_error}")
#     130 # Run differential evolution using only the training set.
# --> 131 result_de = differential_evolution(
#     132     lambda params: objectiveEMD(params, train=True),
#     133     bounds,
#     134     strategy="rand1bin",
#     135     maxiter=8,
#     136     mutation=(0.5, 1),
#     137     recombination=0.95,
#     138     disp=True,
#     139     callback=callbackF,
#     140 )
#     142 optimal_A, optimal_B, optimal_tau, optimal_pnratio = result_de.x
#     144 print("Optimal parameters found:")
#
# File d:\anaconda\envs\elephant\Lib\site-packages\scipy\_lib\_util.py:440, in _transition_to_rng.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     433     message = (
#     434         "The NumPy global RNG was seeded by calling "
#     435         f"`np.random.seed`. Beginning in {end_version}, this "
#     436         "function will no longer use the global RNG."
#     437     ) + cmn_msg
#     438     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 440 return fun(*args, **kwargs)
#
# File d:\anaconda\envs\elephant\Lib\site-packages\scipy\optimize\_differentialevolution.py:501, in differential_evolution(func, bounds, args, strategy, maxiter, popsize, tol, mutation, recombination, rng, callback, disp, polish, init, atol, updating, workers, constraints, x0, integrality, vectorized)
#     484 # using a context manager means that any created Pool objects are
#     485 # cleared up.
#     486 with DifferentialEvolutionSolver(func, bounds, args=args,
#     487                                  strategy=strategy,
#     488                                  maxiter=maxiter,
#    (...)
#     499                                  integrality=integrality,
#     500                                  vectorized=vectorized) as solver:
# --> 501     ret = solver.solve()
#     503 return ret
#
# File d:\anaconda\envs\elephant\Lib\site-packages\scipy\optimize\_differentialevolution.py:1176, in DifferentialEvolutionSolver.solve(self)
#    1171     self.feasible, self.constraint_violation = (
#    1172         self._calculate_population_feasibilities(self.population))
#    1174     # only work out population energies for feasible solutions
#    1175     self.population_energies[self.feasible] = (
# -> 1176         self._calculate_population_energies(
#    1177             self.population[self.feasible]))
#    1179     self._promote_lowest_energy()
#    1181 # do the optimization.
#
# File d:\anaconda\envs\elephant\Lib\site-packages\scipy\optimize\_differentialevolution.py:1337, in DifferentialEvolutionSolver._calculate_population_energies(self, population)
#    1335 parameters_pop = self._scale_parameters(population)
#    1336 try:
# -> 1337     calc_energies = list(
#    1338         self._mapwrapper(self.func, parameters_pop[0:S])
#    1339     )
#    1340     calc_energies = np.squeeze(calc_energies)
#    1341 except (TypeError, ValueError) as e:
#    1342     # wrong number of arguments for _mapwrapper
#    1343     # or wrong length returned from the mapper
#
# File d:\anaconda\envs\elephant\Lib\site-packages\scipy\_lib\_util.py:657, in _FunctionWrapper.__call__(self, x)
#     656 def __call__(self, x):
# --> 657     return self.f(x, *self.args)
#
# Cell In[28], line 132, in <lambda>(params)
#     128     print(f"Iteration {iteration}: Training Error = {train_error}, Evaluation Error = {eval_error}")
#     130 # Run differential evolution using only the training set.
#     131 result_de = differential_evolution(
# --> 132     lambda params: objectiveEMD(params, train=True),
#     133     bounds,
#     134     strategy="rand1bin",
#     135     maxiter=8,
#     136     mutation=(0.5, 1),
#     137     recombination=0.95,
#     138     disp=True,
#     139     callback=callbackF,
#     140 )
#     142 optimal_A, optimal_B, optimal_tau, optimal_pnratio = result_de.x
#     144 print("Optimal parameters found:")
#
# Cell In[28], line 19, in objectiveEMD(params, train)
#      17 # Generate model spike trains.
#      18 spike_trainGCfit = []
# ---> 19 LoutGCfit = linear_filter(sigma_x, sigma_y, A, sigma_c, sigma_s,
#      20                           A_c, A_s, stimuli, reversed_temp_rf_fit, 'SFfitting', rf_estimated)
#      21 LoutGCfit, g = gain_control(LoutGCfit, B, tau)
#      22 LNoutGCfit = apply_nonlinearity(
#      23     apply_nonlinearity(LoutGCfit, 'sigmoid', gain=gain, max_rate=max_rate, y=y),
#      24     method='threshold_linear', theta=theta
#      25 )
#
# Cell In[21], line 274, in linear_filter(sigma_x, sigma_y, A, sigma_c, sigma_s, A_c, A_s, noise_input, temporal_filter, type, rf_estimated)
#     272 x = np.linspace(-(X-1)/2, (X-1)/2, X)
#     273 y = np.linspace(-(Y-1)/2, (Y-1)/2, Y)
# --> 274 noise_input = noise_input.astype(np.float32)
#     276 if type == 'gaussian':
#     277     spatial_rf = gaussian_2d(x, y, sigma_x, sigma_y, A, x0=0, y0=0) # Shape: (Y,X)
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(70, 16))
plt.plot(iterations, errors_train, label="Training Error", marker='o')
plt.plot(iterations, errors_eval, label="Evaluation Error", marker='o')
plt.xlabel("Iterations")
plt.ylabel("Error (Lower is Better)")
plt.title("Error vs. Iterations During Optimization")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # value for next optimization

# %%
theta = 30
A       = 0.97964
B       = 0.0005486
tau     = 8.695
pnratio = 0.6252
gain = 0.00213
max_rate = 200
y = -800

reversed_temp_rf_fit = np.concatenate((reversed_temp_rfTemp[0:8], reversed_temp_rfTemp[8:] * pnratio))

# Generate spike train
spike_trainGCfit = []
LoutGCfit = linear_filter(sigma_x, sigma_y, A, sigma_c, sigma_s, A_c, A_s, stimuli, reversed_temp_rf_fit, spatialtype, rf_estimated)
LoutGCfit, g = gain_control(LoutGCfit, B, tau)
LNoutGCfit = apply_nonlinearity(apply_nonlinearity(LoutGCfit, 'sigmoid', gain=gain, max_rate=max_rate, y=y), method='threshold_linear', theta=theta)
time_bin = 1 / time_para

for trial in range(30):  # Single trial for optimization
    spikingindx = resample_and_generate_spikes(LNoutGCfit, time_bin)
    spike_trainGCfit.append(np.where(spikingindx > 0))
spike_trains_modelemdfit = []
for trial_idx, spikes in enumerate(spike_trainGCfit):
    st_modelarray = np.array(spikes).flatten() /54*10
    spike_trains_modelemdfit.append(st_modelarray)

# Convert spike trains to arrays for EMD
spike_trainsfit = [spike_trains_nemd[i] for i in range(len(spike_trains_nemd)) if i % 2 == 1] + spike_trains_modelemdfit
# Compute EMD as the objective function
score = compute_emd_matrix(spike_trainsfit)
scores = block_means(score,2,30)

# %%
scores

# %% [markdown]
# # nonlinearity opt on VP distance

# %%
# A       = 0.6259386802009455
# B       = 0.0005191171052243981
# tau     = 11.322612574159745
# pnratio = 0.5296426963852245
def objectiveNLVP(params, train=True):
    """
    Optimize the non-linear parameters (gain, max_rate, y) while using fixed 
    linear parameters. The function generates 30 model spike trains and then 
    combines them with real spike trains chosen by interleaving: 
      - if train=True, use even-indexed real trials 
      - else, use odd-indexed real trials.
    
    Returns the Victor-Purpura distance (via block means) as the objective value.
    """
    try:
        # Unpack non-linear parameters.
        gain, max_rate, y,theta = params
        
        # Use fixed linear parameters from stage 1.
        # (Note: Ensure 'reversed_temp_rfTemp' and 'pnratio' are defined globally.)
        reversed_temp_rf_fit = np.concatenate(
            (reversed_temp_rfTemp[0:8], reversed_temp_rfTemp[8:] * pnratio)
        )
        
        # Run the linear filter and apply gain control.
        LoutGCvpfit = linear_filter(
            sigma_x, sigma_y, A, sigma_c, sigma_s,
            A_c, A_s, stimuli, reversed_temp_rf_fit, 'SFfitting', rf_estimated
        )
        LoutGCvpfit, g = gain_control(LoutGCvpfit, B, tau)
        
        # Apply a sigmoid nonlinearity followed by a threshold-linear function.
        LNoutGCvpfit = apply_nonlinearity(
            apply_nonlinearity(LoutGCvpfit, 'sigmoid', gain=gain, max_rate=max_rate, y=y),
            method='threshold_linear', theta=theta
        )
        time_bin = 1 / time_para
        
        # Penalize if the initial firing rate is too high.
        if LNoutGCvpfit[0] > 3:
            return 1e10
        
        # Generate model spike trains over 30 trials.
        spike_trainGCvpfit = []
        spike_trains_modelvp = []
        for trial in range(30):
            spikingindx = resample_and_generate_spikes(LNoutGCvpfit, time_bin)
            spike_train = np.where(spikingindx > 0)[0]
            spike_trainGCvpfit.append(spike_train)
            st_modelvp = SpikeTrain(
                np.array(spike_train).flatten() / 54 * 10 * ms, 
                t_stop=31000
            )
            spike_trains_modelvp.append(st_modelvp)
        
        # Select real spike trains via interleaving.
        # (Assumes spike_trains_n is a list of real spike trains.)
        if train:
            real_spike_trains = [spike_trains_n[i] for i in range(len(spike_trains_n)) if i % 2 == 0]
        else:
            real_spike_trains = [spike_trains_n[i] for i in range(len(spike_trains_n)) if i % 2 == 1]
        
        # Combine real and model spike trains.
        spike_trainsvpfit = real_spike_trains + spike_trains_modelvp
        
        # Check for empty spike trains.
        for st in spike_trainsvpfit:
            if len(st) == 0:
                return 1e10
        
        # Compute Victor-Purpura distance.
        vp_matrix = victor_purpura_distance(spike_trainsvpfit, q)
        scoresvp = block_means(vp_matrix, 2, len(real_spike_trains))
        scorevp = scoresvp[0, 1]
        return scorevp

    except Exception as e:
        print("Error in objectiveNLVP with params", params, ":", e)
        return 1e10

# Define bounds for the non-linear parameters.
bounds = [
    (0.001, 0.01),   # gain
    (150, 300),      # max_rate
    (-600, 400),
    (-200,200)     # y
]

# Prepare lists to store iteration data.
iterations = []
errors_train = []
errors_eval = []

def callbackFN(xk, convergence):
    """
    DE callback that computes and records both the training and evaluation 
    errors using the current best parameters (xk). Training error is computed 
    using even-indexed real trials; evaluation error uses odd-indexed trials.
    """
    iteration = len(iterations) + 1
    train_error = objectiveNLVP(xk, train=True)
    eval_error = objectiveNLVP(xk, train=False)
    iterations.append(iteration)
    errors_train.append(train_error)
    errors_eval.append(eval_error)
    print(f"Iteration {iteration}: Training Error = {train_error}, Evaluation Error = {eval_error}")

# Run differential evolution using the training set.
result_de = differential_evolution(
    lambda params: objectiveNLVP(params, train=True),
    bounds,
    strategy="rand2bin",  # Fast, broad search initially.
    maxiter=1000,          # Fast early convergence.
    mutation=(0.5, 1),    # Faster initial mutation.
    recombination=0.95,   # Encourage exploitation later.
    popsize=50,           # Smaller population for faster convergence.
    disp=True,
    callback=callbackFN,
)

print("Optimal non-linear parameters found:")
print("gain    =", result_de.x[0])
print("max_rate=", result_de.x[1])
print("y       =", result_de.x[2])

# Plot training and evaluation error curves over iterations.

plt.figure(figsize=(10, 6))
plt.plot(iterations, errors_train, label="Training Error (even trials)", marker='o')
plt.plot(iterations, errors_eval, label="Evaluation Error (odd trials)", marker='o')
plt.xlabel("Iterations")
plt.ylabel("Error (Lower is Better)")
plt.title("Non-linear Parameter Optimization: Error vs. Iterations")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # nonlinearity opt by PSTH MSE

# %%
# Define the combined nonlinear model.
def nonlinear_model(Lout, gain, max_rate, y, theta=30):

    pred_sigmoid = apply_nonlinearity(Lout, method='sigmoid', gain=gain, max_rate=max_rate, y=y)
    # Apply the threshold-linear nonlinearity with fixed theta.
    pred = apply_nonlinearity(pred_sigmoid, method='threshold_linear', theta=theta)
    return pred


# Define the objective (error) function (mean squared error) for optimization.
def mse_objective(params, Lout, firing_measured):
    gain, max_rate, y = params  # theta is fixed
    theta = 20
    pred = nonlinear_model(Lout, gain, max_rate, y, theta)
    mse = np.mean((pred - firing_measured) ** 2)
    return mse

# Set bounds for the parameters we are optimizing: gain, max_rate, and y.
bounds = [
    (0.00001, 0.03),   # gain: around 0.02
    (200, 300),     # max_rate: around 250
    (-800, 700)    # y: around -150
]

# Use differential evolution to optimize the parameters.
result = differential_evolution(
    mse_objective, 
    bounds,
    args=(LoutGC, firing_rate_n),
    strategy='best1bin', 
    maxiter=1000,
    popsize=15,
    tol=1e-6,
    mutation=(0.5, 1),
    recombination=0.7,
    disp=True
)

best_params = result.x
print("Optimized parameters (with theta fixed at 15):")
print("gain =", best_params[0])
print("max_rate =", best_params[1])
print("y =", best_params[2])
print("theta = 30")
print("MSE =", result.fun)

# Generate predictions using the best parameters and fixed theta=15.
predicted_firing = nonlinear_model(LoutGC, best_params[0], best_params[1], best_params[2], theta=30)

# Plot the measured (resampled) firing rate and the model prediction.
plt.figure(figsize=(10, 4))
plt.plot(t_sampling, firing_rate_n, 'k-', label='Measured (downsampled)')
plt.plot(t_sampling, predicted_firing, 'r--', label='Nonlinear model')
plt.xlabel('Time (s)')
plt.ylabel('Firing Rate')
plt.legend()
plt.title('Optimized Nonlinear Model via Differential Evolution')
plt.show()

# %%
# Define the objective (error) function (mean squared error) for optimization.
def mse_objective6(params, firing_measured):
    B, tau, gain, max_rate, y, theta  = params
    A = 1
    pnratio = 1

    # Modify the temporal receptive field using pnratio.
    reversed_temp_rf_fit = np.concatenate(
        (reversed_temp_rfTemp[0:8], reversed_temp_rfTemp[8:] * pnratio)
    )
    
    LoutGCfit = linear_filter(sigma_x, sigma_y, A, sigma_c, sigma_s,
                                A_c, A_s, stimuli, reversed_temp_rf_fit, 'SFfitting', rf_estimated)
    LoutGCfit, g = gain_control(LoutGCfit, B, tau)
    LNoutGCfit = apply_nonlinearity(
        apply_nonlinearity(LoutGCfit, 'sigmoid', gain=gain, max_rate=max_rate, y=y),
        method='threshold_linear', theta=theta)
    if LNoutGCfit[0] > 30:
        return 1e10

    mse = np.mean((LNoutGCfit - firing_measured) ** 2)
    return mse

# Set bounds for the parameters we are optimizing: gain, max_rate, and y.
bounds = [
    (0.00001, 1),      # B
    (3, 25),          # tau
    (0.0001, 0.1),    # gain
    (150, 300),       # max_rate
    (-1000, 800),       # y
    (-600,500)          # theta
]

# Use differential evolution to optimize the parameters.
result = differential_evolution(
    mse_objective6, 
    bounds,
    args=(firing_rate_n,),
    strategy='best1bin', 
    maxiter=1000,
    popsize=15,
    tol=1e-6,
    mutation=(0.5, 1),
    recombination=0.7,
    disp=True
)

optimal_params = result_de.x
print("Optimal parameters found:")
print("B       =", optimal_params[0])
print("tau     =", optimal_params[1])
print("gain    =", optimal_params[2])
print("max_rate=", optimal_params[3])
print("y       =", optimal_params[4])
print("theta   =", optimal_params[5])

# Generate predictions using the best parameters and fixed theta=15.
reversed_temp_rf_fit = np.concatenate((reversed_temp_rfTemp[0:8], reversed_temp_rfTemp[8:] * pnratio))

predicted_firing = linear_filter(sigma_x, sigma_y, A, sigma_c, sigma_s, A_c, A_s, stimuli, reversed_temp_rf_fit, 'SFfitting', rf_estimated)
predicted_firing, g = gain_control(LoutGCfit, optimal_params[0], optimal_params[1])
predicted_firing = apply_nonlinearity(apply_nonlinearity(LoutGCfit, 'sigmoid', gain=optimal_params[2], max_rate=optimal_params[3], y=optimal_params[4]),method='threshold_linear', theta=optimal_params[5])

# Plot the measured (resampled) firing rate and the model prediction.
plt.figure(figsize=(10, 4))
plt.plot(t_sampling, firing_rate_n, 'k-', label='Measured (downsampled)')
plt.plot(t_sampling, predicted_firing, 'r--', label='Nonlinear model')
plt.xlabel('Time (s)')
plt.ylabel('Firing Rate')
plt.legend()
plt.title('Optimized Nonlinear Model via Differential Evolution')
plt.show()
# Out:
# differential_evolution step 1: f(x)= 384.3389342532296
# differential_evolution step 2: f(x)= 384.3389342532296
# differential_evolution step 3: f(x)= 354.9753810500624
# differential_evolution step 4: f(x)= 339.88561094599197
# differential_evolution step 5: f(x)= 329.6983587830948
# differential_evolution step 6: f(x)= 329.6983587830948
# differential_evolution step 7: f(x)= 329.6983587830948
# differential_evolution step 8: f(x)= 329.6983587830948
# differential_evolution step 9: f(x)= 329.6983587830948
# differential_evolution step 10: f(x)= 329.6983587830948
# differential_evolution step 11: f(x)= 329.6983587830948
# differential_evolution step 12: f(x)= 329.6983587830948
# differential_evolution step 13: f(x)= 329.6983587830948
# differential_evolution step 14: f(x)= 329.26853420767844
# differential_evolution step 15: f(x)= 327.91141700952073
# differential_evolution step 16: f(x)= 325.0685937155642
# differential_evolution step 17: f(x)= 325.0685937155642
# differential_evolution step 18: f(x)= 325.0685937155642
# differential_evolution step 19: f(x)= 323.0928472422628
# differential_evolution step 20: f(x)= 323.0928472422628
# differential_evolution step 21: f(x)= 323.0928472422628
# differential_evolution step 22: f(x)= 323.0928472422628
# differential_evolution step 23: f(x)= 323.0928472422628
# differential_evolution step 24: f(x)= 323.0928472422628
# differential_evolution step 25: f(x)= 322.95955203503047
# differential_evolution step 26: f(x)= 322.95955203503047
# differential_evolution step 27: f(x)= 322.95955203503047
# differential_evolution step 28: f(x)= 322.95955203503047
# differential_evolution step 29: f(x)= 322.95955203503047
# differential_evolution step 30: f(x)= 322.95955203503047
# differential_evolution step 31: f(x)= 322.95955203503047
# differential_evolution step 32: f(x)= 322.95955203503047
# differential_evolution step 33: f(x)= 322.95955203503047
# differential_evolution step 34: f(x)= 322.69683462149686
# differential_evolution step 35: f(x)= 321.741358300232
# differential_evolution step 36: f(x)= 321.741358300232
# differential_evolution step 37: f(x)= 321.741358300232
# differential_evolution step 38: f(x)= 321.741358300232
# differential_evolution step 39: f(x)= 321.741358300232
# differential_evolution step 40: f(x)= 321.741358300232
# differential_evolution step 41: f(x)= 321.741358300232
# differential_evolution step 42: f(x)= 321.4914407081658
# differential_evolution step 43: f(x)= 321.4914407081658
# differential_evolution step 44: f(x)= 321.4914407081658
# differential_evolution step 45: f(x)= 321.3508109798975
# differential_evolution step 46: f(x)= 321.3508109798975
# differential_evolution step 47: f(x)= 321.3508109798975
# differential_evolution step 48: f(x)= 321.2517639764716
# differential_evolution step 49: f(x)= 321.2517639764716
# differential_evolution step 50: f(x)= 320.3050947156242
# differential_evolution step 51: f(x)= 320.3050947156242
# differential_evolution step 52: f(x)= 320.3050947156242
# differential_evolution step 53: f(x)= 320.3050947156242
# differential_evolution step 54: f(x)= 320.3050947156242
# differential_evolution step 55: f(x)= 320.3050947156242
# differential_evolution step 56: f(x)= 320.3050947156242
# differential_evolution step 57: f(x)= 320.27509833659497
# differential_evolution step 58: f(x)= 320.27509833659497
# differential_evolution step 59: f(x)= 320.27509833659497
# differential_evolution step 60: f(x)= 320.27509833659497
# differential_evolution step 61: f(x)= 320.27509833659497
# differential_evolution step 62: f(x)= 319.6264106455368
# differential_evolution step 63: f(x)= 319.6264106455368
# differential_evolution step 64: f(x)= 319.6264106455368
# differential_evolution step 65: f(x)= 319.6264106455368
# differential_evolution step 66: f(x)= 319.6264106455368
# differential_evolution step 67: f(x)= 319.6264106455368
# differential_evolution step 68: f(x)= 319.6264106455368
# differential_evolution step 69: f(x)= 319.6264106455368
# differential_evolution step 70: f(x)= 318.915599637104
# differential_evolution step 71: f(x)= 318.915599637104
# differential_evolution step 72: f(x)= 318.915599637104
# differential_evolution step 73: f(x)= 318.915599637104
# differential_evolution step 74: f(x)= 318.915599637104
# differential_evolution step 75: f(x)= 318.915599637104
# differential_evolution step 76: f(x)= 318.915599637104
# differential_evolution step 77: f(x)= 318.915599637104
# differential_evolution step 78: f(x)= 318.915599637104
# differential_evolution step 79: f(x)= 318.915599637104
# differential_evolution step 80: f(x)= 318.915599637104
# differential_evolution step 81: f(x)= 318.70845093284146
# differential_evolution step 82: f(x)= 318.70845093284146
# differential_evolution step 83: f(x)= 318.70845093284146
# differential_evolution step 84: f(x)= 318.70845093284146
# differential_evolution step 85: f(x)= 318.70845093284146
# differential_evolution step 86: f(x)= 318.70845093284146
# differential_evolution step 87: f(x)= 318.70845093284146
# differential_evolution step 88: f(x)= 318.70845093284146
# differential_evolution step 89: f(x)= 318.70845093284146
# differential_evolution step 90: f(x)= 318.70845093284146
# differential_evolution step 91: f(x)= 318.70845093284146
# differential_evolution step 92: f(x)= 318.70845093284146
# differential_evolution step 93: f(x)= 318.70845093284146
# differential_evolution step 94: f(x)= 318.70845093284146
# differential_evolution step 95: f(x)= 318.70845093284146
# differential_evolution step 96: f(x)= 318.70845093284146
# differential_evolution step 97: f(x)= 318.70845093284146
# differential_evolution step 98: f(x)= 318.70845093284146
# differential_evolution step 99: f(x)= 318.70845093284146
# differential_evolution step 100: f(x)= 318.70845093284146
# differential_evolution step 101: f(x)= 318.5400186616363
# differential_evolution step 102: f(x)= 318.5400186616363
# differential_evolution step 103: f(x)= 318.5400186616363
# differential_evolution step 104: f(x)= 318.5400186616363
# differential_evolution step 105: f(x)= 318.5400186616363
# differential_evolution step 106: f(x)= 318.5400186616363
# differential_evolution step 107: f(x)= 318.5400186616363
# differential_evolution step 108: f(x)= 317.74003146171685
# differential_evolution step 109: f(x)= 317.74003146171685
# differential_evolution step 110: f(x)= 317.74003146171685
# differential_evolution step 111: f(x)= 317.74003146171685
# differential_evolution step 112: f(x)= 317.59550743462387
# differential_evolution step 113: f(x)= 317.31974550843955
# differential_evolution step 114: f(x)= 317.31974550843955
# differential_evolution step 115: f(x)= 317.31974550843955
# differential_evolution step 116: f(x)= 317.31974550843955
# differential_evolution step 117: f(x)= 317.31974550843955
# differential_evolution step 118: f(x)= 317.31974550843955
# differential_evolution step 119: f(x)= 317.31974550843955
# differential_evolution step 120: f(x)= 317.31974550843955
# differential_evolution step 121: f(x)= 317.31974550843955
# differential_evolution step 122: f(x)= 317.31974550843955
# differential_evolution step 123: f(x)= 317.2957157378712
# differential_evolution step 124: f(x)= 317.2957157378712
# differential_evolution step 125: f(x)= 317.2957157378712
# differential_evolution step 126: f(x)= 317.2957157378712
# differential_evolution step 127: f(x)= 317.2957157378712
# differential_evolution step 128: f(x)= 317.2957157378712
# differential_evolution step 129: f(x)= 317.2957157378712
# differential_evolution step 130: f(x)= 317.2957157378712
# differential_evolution step 131: f(x)= 317.2957157378712
# differential_evolution step 132: f(x)= 317.2957157378712
# differential_evolution step 133: f(x)= 317.2957157378712
# differential_evolution step 134: f(x)= 317.2957157378712
# differential_evolution step 135: f(x)= 317.2957157378712
# differential_evolution step 136: f(x)= 317.2957157378712
# differential_evolution step 137: f(x)= 317.2957157378712
# differential_evolution step 138: f(x)= 317.2957157378712
# differential_evolution step 139: f(x)= 317.2957157378712
# differential_evolution step 140: f(x)= 317.2957157378712
# differential_evolution step 141: f(x)= 317.2957157378712
# differential_evolution step 142: f(x)= 317.2957157378712
# differential_evolution step 143: f(x)= 317.2957157378712
# differential_evolution step 144: f(x)= 317.2957157378712
# differential_evolution step 145: f(x)= 317.2957157378712
# differential_evolution step 146: f(x)= 317.2957157378712
# differential_evolution step 147: f(x)= 317.2957157378712
# differential_evolution step 148: f(x)= 317.2957157378712
# differential_evolution step 149: f(x)= 317.2129000925007
# differential_evolution step 150: f(x)= 317.2129000925007
# differential_evolution step 151: f(x)= 317.2129000925007
# differential_evolution step 152: f(x)= 317.2129000925007
# differential_evolution step 153: f(x)= 317.1768123055654
# differential_evolution step 154: f(x)= 317.1768123055654
# differential_evolution step 155: f(x)= 317.1768123055654
# differential_evolution step 156: f(x)= 317.1768123055654
# differential_evolution step 157: f(x)= 317.1198633003529
# differential_evolution step 158: f(x)= 317.1198633003529
# differential_evolution step 159: f(x)= 317.1198633003529
# differential_evolution step 160: f(x)= 317.1198633003529
# differential_evolution step 161: f(x)= 317.1198633003529
# differential_evolution step 162: f(x)= 317.10433666524443
# differential_evolution step 163: f(x)= 317.10433666524443
# differential_evolution step 164: f(x)= 317.10433666524443
# differential_evolution step 165: f(x)= 317.10433666524443
# differential_evolution step 166: f(x)= 317.10433666524443
# differential_evolution step 167: f(x)= 317.10174982728915
# differential_evolution step 168: f(x)= 317.10174982728915
# differential_evolution step 169: f(x)= 317.10174982728915
# differential_evolution step 170: f(x)= 317.10174982728915
# differential_evolution step 171: f(x)= 317.10174982728915
# differential_evolution step 172: f(x)= 317.10174982728915
# differential_evolution step 173: f(x)= 317.10174982728915
# differential_evolution step 174: f(x)= 317.10174982728915
# differential_evolution step 175: f(x)= 317.10174982728915
# differential_evolution step 176: f(x)= 317.10174982728915
# differential_evolution step 177: f(x)= 317.10174982728915
# differential_evolution step 178: f(x)= 317.10174982728915
# differential_evolution step 179: f(x)= 317.10174982728915
# differential_evolution step 180: f(x)= 317.10174982728915
# differential_evolution step 181: f(x)= 317.10174982728915
# differential_evolution step 182: f(x)= 317.10174982728915
# differential_evolution step 183: f(x)= 317.10174982728915
# differential_evolution step 184: f(x)= 317.10174982728915
# differential_evolution step 185: f(x)= 317.10174982728915
# differential_evolution step 186: f(x)= 317.10174982728915
# differential_evolution step 187: f(x)= 317.0945437680229
# differential_evolution step 188: f(x)= 317.0945437680229
# differential_evolution step 189: f(x)= 317.0945437680229
# differential_evolution step 190: f(x)= 317.0945437680229
# differential_evolution step 191: f(x)= 317.0945437680229
# differential_evolution step 192: f(x)= 317.0945437680229
# differential_evolution step 193: f(x)= 317.0945437680229
# differential_evolution step 194: f(x)= 317.0945437680229
# differential_evolution step 195: f(x)= 317.0945437680229
# differential_evolution step 196: f(x)= 317.0945437680229
# differential_evolution step 197: f(x)= 317.0945437680229
# differential_evolution step 198: f(x)= 317.0945437680229
# differential_evolution step 199: f(x)= 317.0945437680229
# differential_evolution step 200: f(x)= 317.0945437680229
# differential_evolution step 201: f(x)= 317.0945437680229
# differential_evolution step 202: f(x)= 317.0945437680229
# differential_evolution step 203: f(x)= 317.0945437680229
# differential_evolution step 204: f(x)= 317.0945437680229
# differential_evolution step 205: f(x)= 317.0945437680229
# differential_evolution step 206: f(x)= 317.0945437680229
# differential_evolution step 207: f(x)= 317.0945437680229
# differential_evolution step 208: f(x)= 317.0945437680229
# differential_evolution step 209: f(x)= 317.0945437680229
# differential_evolution step 210: f(x)= 317.0945392348264
# differential_evolution step 211: f(x)= 317.0945392348264
# differential_evolution step 212: f(x)= 317.0945392348264
# differential_evolution step 213: f(x)= 317.0945392348264
# differential_evolution step 214: f(x)= 317.0945392348264
# differential_evolution step 215: f(x)= 317.0945392348264
# differential_evolution step 216: f(x)= 317.0945392348264
# differential_evolution step 217: f(x)= 317.0945392348264
# differential_evolution step 218: f(x)= 317.0945392348264
# differential_evolution step 219: f(x)= 317.0945392348264
# differential_evolution step 220: f(x)= 317.0945392348264
# differential_evolution step 221: f(x)= 317.09381537240563
# differential_evolution step 222: f(x)= 317.09381537240563
# differential_evolution step 223: f(x)= 317.09381537240563
# differential_evolution step 224: f(x)= 317.09381537240563
# differential_evolution step 225: f(x)= 317.09381537240563
# differential_evolution step 226: f(x)= 317.09381537240563
# differential_evolution step 227: f(x)= 317.09381537240563
# differential_evolution step 228: f(x)= 317.09381537240563
# differential_evolution step 229: f(x)= 317.09381537240563
# differential_evolution step 230: f(x)= 317.09354208331126
# differential_evolution step 231: f(x)= 317.09354208331126
# differential_evolution step 232: f(x)= 317.09354208331126
# differential_evolution step 233: f(x)= 317.09354208331126
# differential_evolution step 234: f(x)= 317.09354208331126
# differential_evolution step 235: f(x)= 317.09354208331126
# differential_evolution step 236: f(x)= 317.0932718382997
# differential_evolution step 237: f(x)= 317.09317378335606
# differential_evolution step 238: f(x)= 317.09317378335606
# differential_evolution step 239: f(x)= 317.09317378335606
# differential_evolution step 240: f(x)= 317.09317378335606
# differential_evolution step 241: f(x)= 317.09317378335606
# differential_evolution step 242: f(x)= 317.09317378335606
# differential_evolution step 243: f(x)= 317.09317378335606
# differential_evolution step 244: f(x)= 317.093037038948
# differential_evolution step 245: f(x)= 317.093037038948
# differential_evolution step 246: f(x)= 317.093037038948
# differential_evolution step 247: f(x)= 317.093037038948
# differential_evolution step 248: f(x)= 317.093037038948
# differential_evolution step 249: f(x)= 317.093037038948
# differential_evolution step 250: f(x)= 317.0929800027805
# differential_evolution step 251: f(x)= 317.0929800027805
# differential_evolution step 252: f(x)= 317.0929800027805
# differential_evolution step 253: f(x)= 317.0929800027805
# differential_evolution step 254: f(x)= 317.0929800027805
# differential_evolution step 255: f(x)= 317.0929800027805
# differential_evolution step 256: f(x)= 317.0929800027805
# differential_evolution step 257: f(x)= 317.0929800027805
# differential_evolution step 258: f(x)= 317.0929800027805
# differential_evolution step 259: f(x)= 317.0929800027805
# differential_evolution step 260: f(x)= 317.0929800027805
# differential_evolution step 261: f(x)= 317.0929602136559
# differential_evolution step 262: f(x)= 317.0929602136559
# differential_evolution step 263: f(x)= 317.0929602136559
# differential_evolution step 264: f(x)= 317.0929602136559
# differential_evolution step 265: f(x)= 317.0929602136559
# differential_evolution step 266: f(x)= 317.0929444210117
# differential_evolution step 267: f(x)= 317.0929444210117
# differential_evolution step 268: f(x)= 317.0929444210117
# differential_evolution step 269: f(x)= 317.0929444210117
# differential_evolution step 270: f(x)= 317.09294274236936
# Polishing solution with 'L-BFGS-B'
# Optimal parameters found:
# B       = 0.252835921740061
# tau     = 11.032961542348582
# gain    = 0.02585034263881688
# max_rate= 172.75245265136448
# y       = 179.55739603310843
# theta   = 154.60655802129833
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 61
#      58 reversed_temp_rf_fit = np.concatenate((reversed_temp_rfTemp[0:8], reversed_temp_rfTemp[8:] * pnratio))
#      60 predicted_firing = linear_filter(sigma_x, sigma_y, A, sigma_c, sigma_s, A_c, A_s, stimuli, reversed_temp_rf_fit, 'SFfitting', rf_estimated)
# ---> 61 predicted_firing, g = gain_control(LoutGCfit, optimal_params[0], optimal_params[1])
#      62 predicted_firing = apply_nonlinearity(apply_nonlinearity(LoutGCfit, 'sigmoid', gain=optimal_params[2], max_rate=optimal_params[3], y=optimal_params[4]),method='threshold_linear', theta=optimal_params[5])
#      64 # Plot the measured (resampled) firing rate and the model prediction.
#
# NameError: name 'LoutGCfit' is not defined

# %% [markdown]
# # opt combined nonlinearity and nolinearity

# %%
def objectiveComposite(params, train=True):
    try:
        # Unpack all parameters
        B, tau, gain, max_rate, y, theta  = params
        A = 1
        pnratio = 1

        # Modify the temporal receptive field using pnratio.
        reversed_temp_rf_fit = np.concatenate(
            (reversed_temp_rfTemp[0:8], reversed_temp_rfTemp[8:] * pnratio)
        )
        
        # Run the model to generate the linear-nonlinear output with gain control.
        spike_trainGCfit = []
        spike_trains_modelvp = []
        spike_trains_model = []
        
        LoutGCfit = linear_filter(sigma_x, sigma_y, A, sigma_c, sigma_s,
                                  A_c, A_s, stimuli, reversed_temp_rf_fit, 'SFfitting', rf_estimated)
        LoutGCfit, g = gain_control(LoutGCfit, B, tau)
        LNoutGCfit = apply_nonlinearity(
            apply_nonlinearity(LoutGCfit, 'sigmoid', gain=gain, max_rate=max_rate, y=y),
            method='threshold_linear', theta=theta)
        time_bin = 1 / time_para
        if LNoutGCfit[0] > 30:
            return 1e10
        # Generate model spike trains over 30 trials.
        for trial in range(30): 
            spikingindx = resample_and_generate_spikes(LNoutGCfit, time_bin)
            spike_trainGCfit.append(np.where(spikingindx > 0))
            st_modelvp = SpikeTrain(np.array(spike_trainGCfit[trial]).flatten() / 54 * 10 * ms, t_stop=31000)
            spike_trains_modelvp.append(st_modelvp)
        
        # Convert spike indices into model spike train arrays (for EMD).
        for spikes in spike_trainGCfit:
            st_model = np.array(spikes).flatten() / 54 * 10
            spike_trains_model.append(st_model)
            
        # Check for empty spike trains.
        if any(len(st) == 0 for st in spike_trains_model):
            return 1e10
        if any(len(st) == 0 for st in spike_trains_modelvp):
            return 1e10

        # Select appropriate reference spike trains based on the train flag.
        if train:
            ref_spike_trains_EMD = [spike_trains_nemd[i] for i in range(len(spike_trains_nemd)) if i % 2 == 0]
            ref_spike_trains_VP  = [spike_trains_n[i] for i in range(len(spike_trains_n)) if i % 2 == 0]
        else:
            ref_spike_trains_EMD = [spike_trains_nemd[i] for i in range(len(spike_trains_nemd)) if i % 2 == 1]
            ref_spike_trains_VP  = [spike_trains_n[i] for i in range(len(spike_trains_n)) if i % 2 == 1]

        # Composite objective for EMD.
        spike_trains_EMD = ref_spike_trains_EMD + spike_trains_model
        score_matrix = compute_emd_matrix(spike_trains_EMD)
        score_EMD = block_means(score_matrix, 2, 30)
        
        # Composite objective for VP.
        spike_trainsvpfit = ref_spike_trains_VP + spike_trains_modelvp
        vp_matrix = victor_purpura_distance(spike_trainsvpfit, q)
        score_VP = block_means(vp_matrix, 2, 30)
        
        # Composite score: lower is better.
        composite_score = score_EMD[0, 1] / score_EMD[0, 0] + score_VP[0, 1] / score_VP[0, 0]
        return composite_score

    except Exception as e:
        print("Error in objectiveComposite with params", params, ":", e)
        return 1e10
    
def objective_wrapper(params):
    return objectiveComposite(params, train=True)
# Define bounds for all parameters:
bounds = [
    (0.00001, 1),      # B
    (3, 25),          # tau
    (0.0001, 0.1),    # gain
    (150, 300),       # max_rate
    (-1000, 800),       # y
    (-600,500)          # theta
]

# Prepare lists to store iteration data.
iterationsC = []
errors_trainC = []
errors_evalC = []

def callbackFC(xk, convergence):
    # Record current iteration number.
    iteration = len(iterationsC) + 1
    # Compute composite errors on training and evaluation sets.
    train_error = objectiveComposite(xk, train=True)
    eval_error = objectiveComposite(xk, train=False)
    iterationsC.append(iteration)
    errors_trainC.append(train_error)
    errors_evalC.append(eval_error)
    print(f"Iteration {iteration}: Training Error = {train_error}, Evaluation Error = {eval_error}")

# Run differential evolution using the training set for optimization.
result_de = differential_evolution(
    lambda params: objectiveComposite(params, train=True),
    bounds,
    strategy="rand1bin",   # Fast, broad search initially
    maxiter=800,          # Adjust iterations as needed
    popsize = 15,
    mutation=(0.5, 1),
    recombination=0.95,
    disp=True,
    callback=callbackFC,
)

optimal_params = result_de.x
print("Optimal parameters found:")
print("B       =", optimal_params[0])
print("tau     =", optimal_params[1])
print("gain    =", optimal_params[2])
print("max_rate=", optimal_params[3])
print("y       =", optimal_params[4])
print("theta   =", optimal_params[5])
# Out:
# differential_evolution step 1: f(x)= 5.421407048221032
# Iteration 1: Training Error = 5.445692207424666, Evaluation Error = 5.686400543516868
# differential_evolution step 2: f(x)= 5.421407048221032
# Iteration 2: Training Error = 5.484687792563454, Evaluation Error = 5.72488801516589
# differential_evolution step 3: f(x)= 5.231490481975356
# Iteration 3: Training Error = 5.46649392051901, Evaluation Error = 5.8502530786491915
# differential_evolution step 4: f(x)= 5.231490481975356
# Iteration 4: Training Error = 5.455177543434241, Evaluation Error = 5.878213577538654
# differential_evolution step 5: f(x)= 4.922449437575629
# Iteration 5: Training Error = 5.150689027917976, Evaluation Error = 5.252661401916585
# differential_evolution step 6: f(x)= 4.922449437575629
# Iteration 6: Training Error = 5.131294109238672, Evaluation Error = 5.2366118902526555
# differential_evolution step 7: f(x)= 4.922449437575629
# Iteration 7: Training Error = 5.076549341316575, Evaluation Error = 5.429223323804399
# differential_evolution step 8: f(x)= 4.922449437575629
# Iteration 8: Training Error = 5.081266523241041, Evaluation Error = 5.251509928628918
# differential_evolution step 9: f(x)= 4.922449437575629
# Iteration 9: Training Error = 5.138309503152378, Evaluation Error = 5.575091466848652
# differential_evolution step 10: f(x)= 4.922449437575629
# Iteration 10: Training Error = 5.202830522487295, Evaluation Error = 5.273131062136122
# differential_evolution step 11: f(x)= 4.922449437575629
# Iteration 11: Training Error = 5.049187882915138, Evaluation Error = 5.540860301846492
# differential_evolution step 12: f(x)= 4.922449437575629
# Iteration 12: Training Error = 4.9618899517562, Evaluation Error = 5.240849387097143
# differential_evolution step 13: f(x)= 4.922449437575629
# Iteration 13: Training Error = 5.024643210980027, Evaluation Error = 5.27408020986604
# differential_evolution step 14: f(x)= 4.922449437575629
# Iteration 14: Training Error = 5.065286000480793, Evaluation Error = 5.397943487126197
# differential_evolution step 15: f(x)= 4.922449437575629
# Iteration 15: Training Error = 5.298428136269413, Evaluation Error = 5.412828298074708
# differential_evolution step 16: f(x)= 4.922449437575629
# Iteration 16: Training Error = 5.153646288771544, Evaluation Error = 5.33845731975145
# differential_evolution step 17: f(x)= 4.922449437575629
# Iteration 17: Training Error = 5.033005726198006, Evaluation Error = 5.338287855213133
# differential_evolution step 18: f(x)= 4.922449437575629
# Iteration 18: Training Error = 5.178257068993203, Evaluation Error = 5.371376329124927
# differential_evolution step 19: f(x)= 4.922449437575629
# Iteration 19: Training Error = 5.021135029453809, Evaluation Error = 5.324337198213955
# differential_evolution step 20: f(x)= 4.829663201775846
# Iteration 20: Training Error = 4.96617634830293, Evaluation Error = 5.021138776243358
# differential_evolution step 21: f(x)= 4.829663201775846
# Iteration 21: Training Error = 5.032786614143213, Evaluation Error = 4.951644247295933
# differential_evolution step 22: f(x)= 4.829663201775846
# Iteration 22: Training Error = 4.970826356309953, Evaluation Error = 4.919995377551555
# differential_evolution step 23: f(x)= 4.829663201775846
# Iteration 23: Training Error = 4.96444379138766, Evaluation Error = 5.16801556420993
# differential_evolution step 24: f(x)= 4.793834207900342
# Iteration 24: Training Error = 4.59800629304328, Evaluation Error = 5.011393255437985
# differential_evolution step 25: f(x)= 4.648987355527384
# Iteration 25: Training Error = 4.739681253585726, Evaluation Error = 5.073025570571943
# differential_evolution step 26: f(x)= 4.648987355527384
# Iteration 26: Training Error = 4.917423368656381, Evaluation Error = 4.9926689849101304
# differential_evolution step 27: f(x)= 4.648987355527384
# Iteration 27: Training Error = 4.877015717746101, Evaluation Error = 4.861368068575738
# differential_evolution step 28: f(x)= 4.648987355527384
# Iteration 28: Training Error = 4.930134695877646, Evaluation Error = 4.811801108685735
# differential_evolution step 29: f(x)= 4.648987355527384
# Iteration 29: Training Error = 4.786406508404553, Evaluation Error = 5.06697718391178
# differential_evolution step 30: f(x)= 4.648987355527384
# Iteration 30: Training Error = 4.814621451164427, Evaluation Error = 4.805837848148395
# differential_evolution step 31: f(x)= 4.648987355527384
# Iteration 31: Training Error = 5.030464449202464, Evaluation Error = 4.951600269130781
# differential_evolution step 32: f(x)= 4.648987355527384
# Iteration 32: Training Error = 4.886895270804125, Evaluation Error = 5.089799137933291
# differential_evolution step 33: f(x)= 4.648987355527384
# Iteration 33: Training Error = 4.793186057928095, Evaluation Error = 5.013206901569747
# differential_evolution step 34: f(x)= 4.648987355527384
# Iteration 34: Training Error = 4.915844153151523, Evaluation Error = 4.846469895131339
# differential_evolution step 35: f(x)= 4.648987355527384
# Iteration 35: Training Error = 4.853654170446172, Evaluation Error = 5.1833019956173185
# differential_evolution step 36: f(x)= 4.6245486305634484
# Iteration 36: Training Error = 4.650771344172973, Evaluation Error = 4.845469078731531
# differential_evolution step 37: f(x)= 4.6245486305634484
# Iteration 37: Training Error = 4.874483269517153, Evaluation Error = 4.826506598009938
# differential_evolution step 38: f(x)= 4.6245486305634484
# Iteration 38: Training Error = 4.805694578850375, Evaluation Error = 4.902944394202912
# differential_evolution step 39: f(x)= 4.6245486305634484
# Iteration 39: Training Error = 4.8024568567483765, Evaluation Error = 5.017772396968876
# differential_evolution step 40: f(x)= 4.6245486305634484
# Iteration 40: Training Error = 4.9114890047683675, Evaluation Error = 4.867369357205774
# differential_evolution step 41: f(x)= 4.6245486305634484
# Iteration 41: Training Error = 4.880255861755553, Evaluation Error = 4.798234031480165
# differential_evolution step 42: f(x)= 4.6245486305634484
# Iteration 42: Training Error = 4.792568041778926, Evaluation Error = 4.727787757646249
# differential_evolution step 43: f(x)= 4.6245486305634484
# Iteration 43: Training Error = 4.789874440292638, Evaluation Error = 4.911024655625726
# differential_evolution step 44: f(x)= 4.6245486305634484
# Iteration 44: Training Error = 4.814549432991576, Evaluation Error = 5.035591682966444
# differential_evolution step 45: f(x)= 4.6245486305634484
# Iteration 45: Training Error = 4.899935478468571, Evaluation Error = 4.897450290391058
# differential_evolution step 46: f(x)= 4.6245486305634484
# Iteration 46: Training Error = 4.958373655844218, Evaluation Error = 4.776003299667208
# differential_evolution step 47: f(x)= 4.6245486305634484
# Iteration 47: Training Error = 4.760728227664502, Evaluation Error = 4.9461559640666035
# differential_evolution step 48: f(x)= 4.6245486305634484
# Iteration 48: Training Error = 4.84325718413583, Evaluation Error = 4.874480857862015
# differential_evolution step 49: f(x)= 4.6245486305634484
# Iteration 49: Training Error = 4.788357089809269, Evaluation Error = 4.862282739908716
# differential_evolution step 50: f(x)= 4.6245486305634484
# Iteration 50: Training Error = 4.614327244936389, Evaluation Error = 4.892107106032811
# differential_evolution step 51: f(x)= 4.6245486305634484
# Iteration 51: Training Error = 4.924558269805816, Evaluation Error = 4.999884474303782
# differential_evolution step 52: f(x)= 4.6245486305634484
# Iteration 52: Training Error = 4.788429349191753, Evaluation Error = 4.917376339665077
# differential_evolution step 53: f(x)= 4.6245486305634484
# Iteration 53: Training Error = 4.814363234435956, Evaluation Error = 4.745295629395039
# differential_evolution step 54: f(x)= 4.6245486305634484
# Iteration 54: Training Error = 4.735624265592891, Evaluation Error = 4.880809544018787
# differential_evolution step 55: f(x)= 4.6245486305634484
# Iteration 55: Training Error = 4.719573922650783, Evaluation Error = 5.074870654246748
# differential_evolution step 56: f(x)= 4.6245486305634484
# Iteration 56: Training Error = 4.792720966708714, Evaluation Error = 5.000360489003876
# differential_evolution step 57: f(x)= 4.6245486305634484
# Iteration 57: Training Error = 4.903231428550974, Evaluation Error = 5.2128737675406285
# differential_evolution step 58: f(x)= 4.6245486305634484
# Iteration 58: Training Error = 4.851164040259946, Evaluation Error = 5.027308926746365
# differential_evolution step 59: f(x)= 4.613232665155607
# Iteration 59: Training Error = 4.933847687750666, Evaluation Error = 5.188942239353128
# differential_evolution step 60: f(x)= 4.613232665155607
# Iteration 60: Training Error = 4.900147036800752, Evaluation Error = 4.881345204122401
# differential_evolution step 61: f(x)= 4.613232665155607
# Iteration 108: Training Error = 4.645582570802814, Evaluation Error = 4.834618338753307
# differential_evolution step 109: f(x)= 4.597565432018788
# Iteration 109: Training Error = 4.737910607645955, Evaluation Error = 4.802779422166701
# differential_evolution step 110: f(x)= 4.597565432018788
# Iteration 110: Training Error = 4.76062006013375, Evaluation Error = 4.880245840778285
# differential_evolution step 111: f(x)= 4.597565432018788
# Iteration 111: Training Error = 4.7913686340770845, Evaluation Error = 4.996338372209648
# differential_evolution step 112: f(x)= 4.597565432018788
# Iteration 112: Training Error = 4.4669629607254775, Evaluation Error = 4.970342938271363
# differential_evolution step 113: f(x)= 4.597565432018788
# Iteration 113: Training Error = 4.89314715387251, Evaluation Error = 4.928325553406202
# differential_evolution step 114: f(x)= 4.597565432018788
# Iteration 114: Training Error = 4.782162562213699, Evaluation Error = 4.880483156746574
# differential_evolution step 115: f(x)= 4.597565432018788
# Iteration 115: Training Error = 4.773483394354832, Evaluation Error = 4.962424852809839
# differential_evolution step 116: f(x)= 4.597565432018788
# Iteration 116: Training Error = 4.559205392791438, Evaluation Error = 4.805941254007843
# differential_evolution step 117: f(x)= 4.597565432018788
# Iteration 117: Training Error = 4.852221775637266, Evaluation Error = 5.03434667259479
# differential_evolution step 118: f(x)= 4.597565432018788
# Iteration 118: Training Error = 4.5444871192267815, Evaluation Error = 5.245817176827261
# differential_evolution step 119: f(x)= 4.597565432018788
# Iteration 119: Training Error = 4.814467314617329, Evaluation Error = 4.989780427432864
# differential_evolution step 120: f(x)= 4.597565432018788
# Iteration 120: Training Error = 4.671906489202259, Evaluation Error = 4.952646329093545
# differential_evolution step 121: f(x)= 4.597565432018788
# Iteration 121: Training Error = 4.649599941303469, Evaluation Error = 4.915943641466416
# differential_evolution step 122: f(x)= 4.597565432018788
# Iteration 122: Training Error = 4.739690940289755, Evaluation Error = 5.126598394099666
# differential_evolution step 123: f(x)= 4.597565432018788
# Iteration 123: Training Error = 4.718874988261069, Evaluation Error = 5.066776832222428
# differential_evolution step 124: f(x)= 4.597565432018788
# Iteration 124: Training Error = 4.904733829553026, Evaluation Error = 4.922497201910397
# differential_evolution step 125: f(x)= 4.597565432018788
# Iteration 125: Training Error = 4.646282637996821, Evaluation Error = 4.96641293169865
# differential_evolution step 126: f(x)= 4.597565432018788
# Iteration 126: Training Error = 4.712610524763617, Evaluation Error = 5.1266879911794305
# differential_evolution step 127: f(x)= 4.593413591250126
# Iteration 127: Training Error = 4.622315981908363, Evaluation Error = 4.776109598037468
# differential_evolution step 128: f(x)= 4.593413591250126
# Iteration 128: Training Error = 4.805780584715469, Evaluation Error = 4.939129603512333
# differential_evolution step 129: f(x)= 4.560517044855838
# Iteration 129: Training Error = 4.933299391066271, Evaluation Error = 4.871916230451963
# differential_evolution step 130: f(x)= 4.560517044855838
# Iteration 130: Training Error = 4.943849953823539, Evaluation Error = 4.9822474557465455
# differential_evolution step 131: f(x)= 4.560517044855838
# Iteration 131: Training Error = 4.749205264486655, Evaluation Error = 5.041009248816119
# Iteration 179: Training Error = 4.88338851282135, Evaluation Error = 4.964100597476637
# differential_evolution step 180: f(x)= 4.525357623723403
# Iteration 180: Training Error = 4.8399647377253245, Evaluation Error = 4.912923550683503
# differential_evolution step 181: f(x)= 4.525357623723403
# Iteration 181: Training Error = 4.732354256492306, Evaluation Error = 4.943137898681974
# differential_evolution step 182: f(x)= 4.525357623723403
# Iteration 182: Training Error = 4.80937904820694, Evaluation Error = 4.757728950207365
# differential_evolution step 183: f(x)= 4.525357623723403
# Iteration 183: Training Error = 4.755833639739169, Evaluation Error = 4.995987225038304
# differential_evolution step 184: f(x)= 4.525357623723403
# Iteration 184: Training Error = 4.748464487423188, Evaluation Error = 5.1314540170932155
# differential_evolution step 185: f(x)= 4.525357623723403
# Iteration 185: Training Error = 4.792559357101972, Evaluation Error = 5.092618750483986
# differential_evolution step 186: f(x)= 4.525357623723403
# Iteration 186: Training Error = 4.649192282405269, Evaluation Error = 5.113230722220792
# differential_evolution step 187: f(x)= 4.525357623723403
# Iteration 187: Training Error = 4.740464694664155, Evaluation Error = 5.031751072975538
# differential_evolution step 188: f(x)= 4.525357623723403
# Iteration 188: Training Error = 5.064112477709996, Evaluation Error = 4.885051350130679
# differential_evolution step 189: f(x)= 4.525357623723403
# Iteration 189: Training Error = 4.723774558726297, Evaluation Error = 4.964539953119301
# differential_evolution step 190: f(x)= 4.525357623723403
# Iteration 190: Training Error = 4.874673642063566, Evaluation Error = 4.7439309201076725
# differential_evolution step 191: f(x)= 4.525357623723403
# Iteration 191: Training Error = 4.9923902560543585, Evaluation Error = 4.934075544933802
# differential_evolution step 192: f(x)= 4.525357623723403
# Iteration 192: Training Error = 4.732717495478514, Evaluation Error = 4.905101588942147
# differential_evolution step 193: f(x)= 4.525357623723403
# Iteration 193: Training Error = 4.899016457845283, Evaluation Error = 4.958402726800827
# differential_evolution step 194: f(x)= 4.525357623723403
# Iteration 194: Training Error = 4.909937297746326, Evaluation Error = 4.989408223917921
# differential_evolution step 195: f(x)= 4.525357623723403
# Iteration 195: Training Error = 4.65745490767532, Evaluation Error = 5.035292333138855
# differential_evolution step 196: f(x)= 4.525357623723403
# Iteration 196: Training Error = 4.689520217933439, Evaluation Error = 5.073394755341886
# differential_evolution step 197: f(x)= 4.525357623723403
# Iteration 197: Training Error = 4.665384833698449, Evaluation Error = 4.79266103012715
# differential_evolution step 198: f(x)= 4.525357623723403
# Iteration 198: Training Error = 4.980956350190429, Evaluation Error = 5.165015175198562
# differential_evolution step 199: f(x)= 4.525357623723403
# Iteration 199: Training Error = 4.63785076396047, Evaluation Error = 4.642403335030966
# differential_evolution step 200: f(x)= 4.525357623723403
# Iteration 200: Training Error = 4.754287990770624, Evaluation Error = 5.086188794064936
# differential_evolution step 201: f(x)= 4.525357623723403
# Iteration 201: Training Error = 4.833811411332207, Evaluation Error = 5.004907017561308
# differential_evolution step 202: f(x)= 4.525357623723403
# Iteration 202: Training Error = 4.560701200992959, Evaluation Error = 4.876027916751271
# differential_evolution step 389: f(x)= 4.4374918841172475
# Iteration 389: Training Error = 4.889199556852355, Evaluation Error = 4.841746492537765
# differential_evolution step 390: f(x)= 4.4374918841172475
# Iteration 390: Training Error = 4.533197874483377, Evaluation Error = 4.804125439686043
# differential_evolution step 391: f(x)= 4.4374918841172475
# Iteration 391: Training Error = 4.582689952413232, Evaluation Error = 4.759814795592213
# differential_evolution step 392: f(x)= 4.4374918841172475
# Iteration 392: Training Error = 4.917787717003279, Evaluation Error = 4.954676869626409
# differential_evolution step 393: f(x)= 4.4374918841172475
# Iteration 393: Training Error = 4.55469197569677, Evaluation Error = 4.877749398207945
# differential_evolution step 394: f(x)= 4.4374918841172475
# Iteration 394: Training Error = 4.709071365568226, Evaluation Error = 4.921474242390444
# differential_evolution step 395: f(x)= 4.4374918841172475
# Iteration 395: Training Error = 4.73628087167925, Evaluation Error = 4.874440547380207
# differential_evolution step 396: f(x)= 4.4374918841172475
# Iteration 396: Training Error = 4.641124770736305, Evaluation Error = 5.049391541372386
# differential_evolution step 397: f(x)= 4.4374918841172475
# Iteration 397: Training Error = 4.886193981994869, Evaluation Error = 4.860439408141264
# differential_evolution step 398: f(x)= 4.4374918841172475
# Iteration 398: Training Error = 4.642785623007435, Evaluation Error = 4.697279445801154
# differential_evolution step 399: f(x)= 4.4374918841172475
# Iteration 399: Training Error = 4.919794953257827, Evaluation Error = 4.844925004791206
# differential_evolution step 400: f(x)= 4.4374918841172475
# Iteration 400: Training Error = 4.647966278252585, Evaluation Error = 4.990718400405788
# differential_evolution step 401: f(x)= 4.4374918841172475
# Iteration 401: Training Error = 4.642132538068284, Evaluation Error = 4.81170312923869
# differential_evolution step 402: f(x)= 4.4374918841172475
# Iteration 402: Training Error = 4.5655770241114775, Evaluation Error = 4.706088165266959
# differential_evolution step 403: f(x)= 4.4374918841172475
# Iteration 403: Training Error = 4.8786016038249995, Evaluation Error = 5.0528857285530435
# Polishing solution with 'L-BFGS-B'
# Optimal parameters found:
# B       = 0.252835921740061
# tau     = 11.032961542348582
# gain    = 0.02585034263881688
# max_rate= 172.75245265136448
# y       = 179.55739603310843
# theta   = 154.60655802129833

# %%
# Plot both training and evaluation error curves over iterations.
plt.figure(figsize=(10, 6))
plt.plot(iterationsC, errors_trainC, label="Training Error", marker='o')
plt.plot(iterationsC, errors_evalC, label="Evaluation Error", marker='o')
plt.xlabel("Iterations")
plt.ylabel("Error (Lower is Better)")
plt.title("Error vs. Iterations During Composite Optimization")
plt.legend()
plt.grid(True)
plt.show()

# %%
# B       = 0.37304849439689425
# tau     = 23.17564637791108
# gain    = 0.008955711208160765
# max_rate= 244.20270111740393
# y       = 256.7731021338907
# theta   = 203.11685951533403

# %%
# gain = 0.007405645934417652
# max_rate = 150.0
# y = -400
# A     = 0.8499933511498123
# B     = 0.0001957834788429702
# tau   = 9.995996093979702
# pnratio = 1.0328866599115238

# %%
# theta = 20
# A     = 0.25647146282835576
# B     = 3.7617576835791144e-05
# tau   = 22.270442267716334
# pnratio = 0.5687064327358631
# gain = 0.00584
# max_rate = 200
# y = -400

# %%
# Optimal parameters found:2
# A     = 0.8741020654095416
# B     = 0.0011924248002383453
# tau   = 8.053734308855226
# pnratio = 1.2453622960617898
# Objective score = 717.358520121614
