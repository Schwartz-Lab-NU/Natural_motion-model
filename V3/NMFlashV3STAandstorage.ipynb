# %% [markdown]
# # Load Data

# %%
dt = 1/60 # fps
delay = 3/60 # s
T = 50  # frames selected for STA

# %%
import datajoint as dj
import h5py
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import HTMLWriter
from matplotlib.animation import FuncAnimation
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D
from scipy.signal import convolve
from matplotlib.animation import HTMLWriter
from matplotlib.animation import FuncAnimation
import matplotlib.gridspec as gridspec
from scipy.interpolate import griddata
import pickle
import stimgenerate as sg
import matplotlib.patches as mpatches
import pandas as pd
import scipy.stats as stats
dj.conn()
# symphony = dj.VirtualModule(module_name='symphony', schema_name='sln_symphony')
# NM = symphony.Experiment.ProtNaturalMovingObjectV2ep() * symphony.Experiment.ProtNaturalMovingObjectV2bp() * symphony.SpikeTrain() &'file_name="101124B"'&'cur_motion_type="natural"'
# CM = symphony.Experiment.ProtNaturalMovingObjectV2ep() * symphony.Experiment.ProtNaturalMovingObjectV2bp() * symphony.SpikeTrain() &'file_name="101124B"'&'cur_motion_type="control"'
# spike_indices_n = NM.fetch('spike_indices')
# spike_indices_c = CM.fetch('spike_indices')
# spike_indices_n = spike_indices_n.tolist()
# spike_indices_c = spike_indices_c.tolist()
# for i in range(len(spike_indices_n)):
#     spike_indices_n[i] = np.transpose(spike_indices_n[i])
# for i in range(len(spike_indices_c)):
#     spike_indices_c[i] = np.transpose(spike_indices_c[i])
# Out:
# [2025-09-19 14:09:20,557][INFO]: Connecting Jiaming@vfsmdatajoint01.fsm.northwestern.edu:3306
# [2025-09-19 14:09:21,237][INFO]: Connected Jiaming@vfsmdatajoint01.fsm.northwestern.edu:3306
# DataJoint connection (connected) Jiaming@vfsmdatajoint01.fsm.northwestern.edu:3306

# %%
  
res_file = r"results/091825B_results.mat"
f = h5py.File(res_file)
        # f[f[f['results']['NaturalMovingObjectAndFlash'][0][0]]["cx"][0][0]][0]
for cell in f['results']['NaturalMovingObjectAndFlash'][1:]:
    if len(f[cell[0]]) <20:
        continue

    trajx_n = []    
    trajy_n = []    
    trajx_c = []    
    trajy_c = []
    motion_seed_n = []
    motion_seed_c = []    
    spike_indices_n = []
    spike_indices_c = []
    epoch_id_n = []
    epoch_id_c = []
    trans_x_n = []
    trans_y_n = []
    trans_x_c = []
    trans_y_c = []
    trajx_f = []
    trajy_f = []
    motion_seed_f = []
    spike_indices_f = []
    epoch_id_f = []

    trans_x_f = []
    trans_y_f = []
    
    for cx,cy,si,t,s,en,tx,ty in zip(f[cell[0]]['cx'][0][:], f[cell[0]]['cy'][0][:],f[cell[0]]['spike_indices'][0][:], f[cell[0]]['cur_motion_type'][0][:], f[cell[0]]['motion_seed'][0][:], f[cell[0]]['epoch_id'][0][:],f[cell[0]]['trans_x'][0][:],f[cell[0]]['trans_y'][0][:]):
        # if f[s][:][0] <201 or f[s][:][0] > 300:
        #     continue

        if "".join(np.vectorize(chr)(f[t][:]).flatten()) == 'natural':
            trajx_n.extend(f[cx][:])
            trajy_n.extend(f[cy][:])
            motion_seed_n.extend(f[s][:])
            spike_indices_n.append(f[si][:])
            epoch_id_n.append(f[en][:])
            trans_x_n.extend(f[tx][:])
            trans_y_n.extend(f[ty][:])
        if "".join(np.vectorize(chr)(f[t][:]).flatten()) == 'control':
            trajx_c.extend(f[cx][:])
            trajy_c.extend(f[cy][:])
            motion_seed_c.extend(f[s][:])
            spike_indices_c.append(f[si][:])
            epoch_id_c.append(f[en][:])
            trans_x_c.extend(f[tx][:])
            trans_y_c.extend(f[ty][:])
        if "".join(np.vectorize(chr)(f[t][:]).flatten()) == 'flash':
            trajx_f.extend(f[cx][:])
            trajy_f.extend(f[cy][:])
            motion_seed_f.extend(f[s][:])
            spike_indices_f.append(f[si][:])
            epoch_id_f.append(f[en][:])
            trans_x_f.extend(f[tx][:])
            trans_y_f.extend(f[ty][:])
    break # only use the first cell, for this example

# %%
len(spike_indices_n),len(spike_indices_c),len(spike_indices_f)
# Out:
# (679, 682, 685)

# %%
with open('results/spike_indices_nc2V3.pkl', 'wb') as f:
    pickle.dump(spike_indices_n, f)
with open('results/spike_indices_cc2V3.pkl', 'wb') as f:
    pickle.dump(spike_indices_c, f)
with open('results/spike_indices_fc2V3.pkl', 'wb') as f:
    pickle.dump(spike_indices_f, f)

# %%
trajx_n = np.asarray(trajx_n)
trajy_n = np.asarray(trajy_n)
trajx_c = np.asarray(trajx_c)
trajy_c = np.asarray(trajy_c)
trajx_f = np.asarray(trajx_f)
trajy_f = np.asarray(trajy_f)
trans_x_n = np.asarray(trans_x_n)
trans_y_n = np.asarray(trans_y_n)
trans_x_c = np.asarray(trans_x_c)
trans_y_c = np.asarray(trans_y_c)
trans_x_f = np.asarray(trans_x_f)
trans_y_f = np.asarray(trans_y_f)

trajx_n = trajx_n + trans_x_n
trajy_n = trajy_n + trans_y_n
trajx_c = trajx_c + trans_x_c
trajy_c = trajy_c + trans_y_c
trajx_f = trajx_f + trans_x_f
trajy_f = trajy_f + trans_y_f

# %%
trajx_n[0]
# Out:
# array([-48.1597664 , -48.38013879, -48.86352001, -50.05149823,
#        -51.40630794, -54.49573531, -56.36952701, -59.09912142,
#        -62.22687209, -65.75589151, -68.88132658, -72.29852817,
#        -75.68163136, -79.11356634, -82.03077637, -84.10090456,
#        -85.79267406, -87.47004557, -88.37005724, -88.66807717,
#        -90.02842946, -91.21371375, -91.74976727, -92.55482067,
#        -92.05523934, -92.2256019 , -92.31639972, -92.4174735 ,
#        -91.83999661, -91.34342945, -89.52828086, -88.20941175,
#        -86.50388258, -85.18802679, -84.01853022, -82.41667061,
#        -81.38993735, -80.37426902, -79.26367149, -78.42921572,
#        -77.92170355, -77.30767167, -76.78899378, -76.39296883,
#        -76.2394418 , -75.93864867, -75.67974212, -75.36485586,
#        -74.87332797, -74.25831165, -73.44159164, -72.81617438,
#        -72.43903482, -72.34952316, -72.18281352, -72.28259519,
#        -72.34474774, -72.3597052 , -72.32472748, -72.24008641,
#        -72.00450832, -71.84929004, -71.57855379, -71.37377667,
#        -71.75578427, -71.55930327, -71.09780587, -70.70236101,
#        -70.66192633, -70.78522296, -71.24724895, -71.53208247,
#        -72.29197095, -73.38244598, -74.11296957, -74.38738247,
#        -74.6417186 , -74.80363297, -75.06316501, -75.1733068 ,
#        -75.39196375, -74.71252234, -73.58182394, -72.07671096,
#        -71.11252562, -69.78872208, -68.73289082, -67.30759558,
#        -66.03910561, -65.15018163, -65.09369737, -65.14747268])

# %% [markdown]
# # Spike Raster

# %%
fig, (ax1, ax2,ax3) = plt.subplots(3, 1, figsize=(14, 12), sharex=True)

num_trials_n = len(spike_indices_n)
spikes_n = []
for spike_idx_n in range(num_trials_n):
    spikes_in_trial = spike_indices_n[spike_idx_n] / 10000 - delay
    spikes_n.extend(spikes_in_trial)
    ax1.vlines(spikes_in_trial, spike_idx_n, spike_idx_n + 1, 'firebrick', linewidth=1.5)


spikes_c = []
num_trials_c = len(spike_indices_c)
for spike_idx_c in range(num_trials_c):
    spikes_in_trial = spike_indices_c[spike_idx_c] / 10000 - delay
    spikes_c.extend(spikes_in_trial)
    ax2.vlines(spikes_in_trial, spike_idx_c, spike_idx_c + 1, 'k', linewidth=1.5)

spikes_f = []
num_trials_f = len(spike_indices_f)
for spike_idx_f in range(num_trials_f):
    spikes_in_trial = spike_indices_f[spike_idx_f] / 10000 - delay
    spikes_f.extend(spikes_in_trial)
    ax3.vlines(spikes_in_trial, spike_idx_f, spike_idx_f + 1, 'k', linewidth=1.5)


ax1.set_ylabel('Trial Number')
ax1.set_title('Natural Stimuli Spike Raster')
ax1.set_xlim(0, 1.5)  


ax2.set_ylabel('Trial Number')
ax2.set_title('Control Spike Raster')
ax2.set_xlim(0, 1.5)  

ax3.set_ylabel('Trial Number')
ax3.set_title('Flash Spike Raster')
ax3.set_xlim(0, 1.5)  

plt.tight_layout()
plt.show()

# %%
def compute_isis(spike_times):
    """
    Given a 1‑D array of spike times (in seconds) for one trial,
    return the inter‑spike intervals.
    """
    spike_times = np.asarray(spike_times).flatten()
    if len(spike_times) < 2:
        return np.array([])  # no ISI if fewer than 2 spikes
    return np.diff(spike_times)

def compute_cv(isis):
    """Coefficient of variation of ISIs."""
    isis = np.asarray(isis).flatten()
    if isis.size < 2 or np.mean(isis) == 0:
        return np.nan
    return np.std(isis) / np.mean(isis)

def compute_lv(isis):
    """Local Variation (Shinomoto et al. 2003)."""
    isis = np.asarray(isis).flatten()
    if isis.size < 2:
        return np.nan
    return np.mean( 3 * (isis[:-1] - isis[1:])**2 / ( (isis[:-1] + isis[1:])**2 ) )

def compute_spike_counts(spike_indices_list):
    """Number of spikes in each trial."""
    return np.array([ len(np.asarray(idx).flatten()) for idx in spike_indices_list ])

def compute_psth(spike_indices_list, delay=0, bin_size=0.01, t_start=0, t_end=1.5, fs=10000):

    bins = np.arange(t_start, t_end + bin_size, bin_size)
    n_trials = len(spike_indices_list)
    # Compute binned spike counts for each trial
    binned_counts = []
    for inds in spike_indices_list:
        spikes_sec = np.asarray(inds).flatten() / fs - delay
        counts, _ = np.histogram(spikes_sec, bins=bins)
        binned_counts.append(counts)
    binned_counts = np.array(binned_counts)  # shape: (n_trials, n_bins)
    # Normalize to spikes/sec for each trial
    psth_per_trial = binned_counts / bin_size
    # Mean and SEM across trials
    mean_psth = np.nanmean(psth_per_trial, axis=0)
    sem_psth = np.nanstd(psth_per_trial, axis=0) / np.sqrt(n_trials)
    centers = bins[:-1] + bin_size/2
    return centers, mean_psth, sem_psth

# ——— Example: process each condition ———

conditions = {
    "Natural":    spike_indices_n,
    "Control":    spike_indices_c,
    "Flash":      spike_indices_f,
}

results = {}

for name, spikes_lst in conditions.items():
    # 1) Spike counts
    counts = compute_spike_counts(spikes_lst)
    
    # 2) ISIs, CVs, LVs per trial
    isis_list = []
    cvs, lvs = [], []
    for idx in spikes_lst:
        t = np.asarray(idx).flatten() / 10000 - delay
        isi = compute_isis(t)
        isis_list.append(isi)
        cvs .append( compute_cv(isi) )
        lvs .append( compute_lv(isi) )
    
    cvs = np.array(cvs)
    lvs = np.array(lvs)
    
    # 3) PSTH with error bars
    bin_centers, mean_psth, sem_psth = compute_psth(spikes_lst,
                                                    delay=delay,
                                                    bin_size=0.01,  # 10 ms bins
                                                    t_start=0,
                                                    t_end=1.5,
                                                    fs=10000)
    
    results[name] = {
        "spike_counts": counts,
        "isis":         isis_list,
        "CV":           cvs,
        "LV":           lvs,
        "psth_t":       bin_centers,
        "psth_rate":    mean_psth,
        "psth_sem":     sem_psth
    }

# ——— Plot PSTHs with error bars ———


# Prepare summary statistics for table
summary_data = []
for name, res in results.items():
    mean_spikes = res['spike_counts'].mean()
    std_spikes = res['spike_counts'].std()
    mean_cv = np.nanmean(res['CV'])
    std_cv = np.nanstd(res['CV'])
    mean_lv = np.nanmean(res['LV'])
    std_lv = np.nanstd(res['LV'])
    # ISI summary: mean and std of all ISIs pooled across all trials
    all_isis = np.concatenate([isi for isi in res['isis'] if len(isi) > 0])
    if all_isis.size > 0:
        mean_isi = np.mean(all_isis)
        std_isi = np.std(all_isis)
        isi_str = f"{mean_isi*1000:.1f} ± {std_isi*1000:.1f}"  # ms
    else:
        isi_str = "n/a"
    summary_data.append([
        f"{mean_spikes/1.5:.1f} ± {std_spikes/1.5:.1f}",
        f"{mean_cv:.2f} ± {std_cv:.2f}",
        f"{mean_lv:.2f} ± {std_lv:.2f}",
        isi_str
    ])

summary_df = pd.DataFrame(
    summary_data,
    index=list(results.keys()),
    columns=["Mean FR (± std)", "CV (± std)", "LV (± std)", "ISI (ms, ± std)"]
)

# Plot PSTH with error bars and add table
fig, ax = plt.subplots(figsize=(8, 6))
for name, res in results.items():
    t = res["psth_t"]
    mean_rate = res["psth_rate"]
    sem_rate = res["psth_sem"]
    ax.plot(t, mean_rate, label=name)
    ax.fill_between(t, mean_rate - sem_rate, mean_rate + sem_rate, alpha=0.3)
    ax.axvline(0.5, color='black', linestyle='--')
ax.set_title('PSTH ± SEM(V3)', fontsize=28)
ax.set_xlabel("Time (s)")
ax.set_ylabel("Firing rate (spikes/s)")
ax.legend()

# Add table below the plot
table = plt.table(
    cellText=summary_df.values,
    rowLabels=summary_df.index,
    colLabels=summary_df.columns,
    cellLoc='center',
    rowLoc='center',
    loc='bottom',
    bbox=[0.0, -0.55, 1, 0.35]
)
table.auto_set_font_size(False)
table.set_fontsize(12)
table.scale(1, 1.5)

plt.subplots_adjust(left=0.2, bottom=0.4)
plt.show()

# %% [markdown]
# # STA

# %%
all_vc = []
all_ac = []
all_r_c = []


for trial_idx in range(len(trajx_c)):
    dpc_x = np.diff(trajx_c[trial_idx])
    dpc_y = np.diff(trajy_c[trial_idx])
    vc_x = dpc_x / dt
    vc_y = dpc_y / dt
    vc = np.sqrt(vc_x**2 + vc_y**2)
    dvc_x = np.diff(vc_x)
    dvc_y = np.diff(vc_y)
    ac_x = dvc_x / dt
    ac_y = dvc_y / dt
    ac = np.sqrt(ac_x**2 + ac_y**2)
    r_c = np.sqrt(trajx_c[trial_idx]**2 + trajy_c[trial_idx]**2)
    
    all_vc.append(vc)
    all_ac.append(ac)
    all_r_c.append(r_c)
    
all_vc = np.array(all_vc) 
all_ac = np.array(all_ac)
all_r_c = np.array(all_r_c)



all_vn = []
all_an = []
all_r_n = []



for trial_idx in range(len(trajx_n)):
    dpn_x = np.diff(trajx_n[trial_idx])
    dpn_y = np.diff(trajy_n[trial_idx])
    vn_x = dpn_x / dt
    vn_y = dpn_y / dt
    vn = np.sqrt(vn_x**2 + vn_y**2)
    dvn_x = np.diff(vn_x)
    dvn_y = np.diff(vn_y)
    an_x = dvn_x / dt
    an_y = dvn_y / dt
    an = np.sqrt(an_x**2 + an_y**2)
    r_n = np.sqrt(trajx_n[trial_idx]**2 + trajy_n[trial_idx]**2)
    
    all_vn.append(vn)
    all_an.append(an)
    all_r_n.append(r_n)



all_vn = np.array(all_vn)
all_an = np.array(all_an)
all_r_n = np.array(all_r_n)

all_vf = []
all_af = []
all_r_f = []

for trial_idx in range(len(trajx_f)):
    dpf_x = np.diff(trajx_f[trial_idx])
    dpf_y = np.diff(trajy_f[trial_idx])
    vf_x = dpf_x / dt
    vf_y = dpf_y / dt
    vf = np.sqrt(vf_x**2 + vf_y**2)
    dvf_x = np.diff(vf_x)
    dvf_y = np.diff(vf_y)
    af_x = dvf_x / dt
    af_y = dvf_y / dt
    af = np.sqrt(af_x**2 + af_y**2)
    r_f = np.sqrt(trajx_f[trial_idx]**2 + trajy_f[trial_idx]**2)
    all_vf.append(vf)
    all_af.append(af)
    all_r_f.append(r_f)

all_vf = np.array(all_vf)
all_af = np.array(all_af)
all_r_f = np.array(all_r_f)




mean_vc = np.nanmean(all_vc,1)  
mean_ac = np.nanmean(all_ac,1)
mean_vn = np.nanmean(all_vn,1)  
mean_an = np.nanmean(all_an,1)
mean_vf = np.nanmean(all_vf,1)
mean_af = np.nanmean(all_af,1)

all_vc -= mean_vc.reshape(-1,1)
all_ac -= mean_ac.reshape(-1,1)
all_vn -= mean_vn.reshape(-1,1)
all_an -= mean_an.reshape(-1,1)
all_vf -= mean_vf.reshape(-1,1)
all_af -= mean_af.reshape(-1,1)
all_ac = np.concatenate([all_ac, np.full((all_ac.shape[0], 3), np.nan)],axis=1)
all_vc = np.concatenate([all_vc, np.full((all_vc.shape[0], 2), np.nan)],axis=1)
all_an = np.concatenate([all_an, np.full((all_an.shape[0], 3), np.nan)],axis=1)
all_vn = np.concatenate([all_vn, np.full((all_vn.shape[0], 2), np.nan)],axis=1)
all_vf = np.concatenate([all_vf, np.full((all_vf.shape[0], 2), np.nan)],axis=1)
all_af = np.concatenate([all_af, np.full((all_af.shape[0], 2), np.nan)],axis=1)
trajx_c = np.concatenate([trajx_c, np.full((trajx_c.shape[0], 1), np.nan)],axis=1)
trajy_c = np.concatenate([trajy_c, np.full((trajy_c.shape[0], 1), np.nan)],axis=1)
trajx_n = np.concatenate([trajx_n, np.full((trajx_n.shape[0], 1), np.nan)],axis=1)
trajy_n = np.concatenate([trajy_n, np.full((trajy_n.shape[0], 1), np.nan)],axis=1)
trajx_f = np.concatenate([trajx_f, np.full((trajx_f.shape[0], 1), np.nan)],axis=1)
trajy_f = np.concatenate([trajy_f, np.full((trajy_f.shape[0], 1), np.nan)],axis=1)
all_r_c = np.concatenate([all_r_c, np.full((all_r_c.shape[0], 1), np.nan)],axis=1)
all_r_n = np.concatenate([all_r_n, np.full((all_r_n.shape[0], 1), np.nan)],axis=1)
all_r_f = np.concatenate([all_r_f, np.full((all_r_f.shape[0], 1), np.nan)],axis=1)

# %%
time_window = np.linspace(-T * dt, -dt, T)

d_n = np.zeros((T, len(spike_indices_n), max([len(spikes) for spikes in spike_indices_n])))
d_c = np.zeros((T, len(spike_indices_c), max([len(spikes) for spikes in spike_indices_c])))
d_f = np.zeros((T, len(spike_indices_f), max([len(spikes) for spikes in spike_indices_f])))

sta_v_n = np.full((T, len(spike_indices_n), max([len(spikes) for spikes in spike_indices_n])), np.nan)
sta_a_n = np.full((T, len(spike_indices_n), max([len(spikes) for spikes in spike_indices_n])), np.nan)
sta_x_n = np.full((T, len(spike_indices_n), max([len(spikes) for spikes in spike_indices_n])), np.nan)
sta_y_n = np.full((T, len(spike_indices_n), max([len(spikes) for spikes in spike_indices_n])), np.nan)
sta_r_n = np.full((T, len(spike_indices_n), max([len(spikes) for spikes in spike_indices_n])), np.nan)

sta_v_c = np.full((T, len(spike_indices_c), max([len(spikes) for spikes in spike_indices_c])), np.nan)
sta_a_c = np.full((T, len(spike_indices_c), max([len(spikes) for spikes in spike_indices_c])), np.nan)
sta_x_c = np.full((T, len(spike_indices_c), max([len(spikes) for spikes in spike_indices_c])), np.nan)
sta_y_c = np.full((T, len(spike_indices_c), max([len(spikes) for spikes in spike_indices_c])), np.nan)
sta_r_c = np.full((T, len(spike_indices_c), max([len(spikes) for spikes in spike_indices_c])), np.nan)

sta_v_f = np.full((T, len(spike_indices_f), max([len(spikes) for spikes in spike_indices_f])), np.nan)
sta_a_f = np.full((T, len(spike_indices_f), max([len(spikes) for spikes in spike_indices_f])), np.nan)
sta_x_f = np.full((T, len(spike_indices_f), max([len(spikes) for spikes in spike_indices_f])), np.nan)
sta_y_f = np.full((T, len(spike_indices_f), max([len(spikes) for spikes in spike_indices_f])), np.nan)
sta_r_f = np.full((T, len(spike_indices_f), max([len(spikes) for spikes in spike_indices_f])), np.nan)

for trial_idx, spikes in enumerate(spike_indices_n):
    # Only keep spike indices > 5000

    valid_mask = spikes > 5000
    spikes = spikes[valid_mask]

    spike_indices = (spikes.flatten() / 10000 / dt).astype(int)
    for spike_idx, si in enumerate(spike_indices):
        i0 = si - T
        sta_v_n[max(-i0 + 1, 0):, trial_idx, spike_idx] = all_vn[trial_idx][max(i0 - 1, 0):max(si - 1, 0)]
        sta_a_n[max(-i0 + 2, 0):, trial_idx, spike_idx] = all_an[trial_idx][max(i0 - 2, 0):max(si - 2, 0)]
        sta_x_n[max(-i0, 0):, trial_idx, spike_idx] = trajx_n[trial_idx][max(i0, 0):si]
        sta_y_n[max(-i0, 0):, trial_idx, spike_idx] = trajy_n[trial_idx][max(i0, 0):si]
        sta_r_n[max(-i0, 0):, trial_idx, spike_idx] = all_r_n[trial_idx][max(i0, 0):si]
        d_n[max(-i0, 0):, trial_idx, spike_idx] += 1

for trial_idx, spikes in enumerate(spike_indices_c):
    
    valid_mask = spikes > 5000
    spikes = spikes[valid_mask]
    spike_indices = (spikes.flatten() / 10000 / dt).astype(int)
    for spike_idx, si in enumerate(spike_indices):
        i0 = si - T
        sta_v_c[max(-i0 + 1, 0):, trial_idx, spike_idx] = all_vc[trial_idx][max(i0 - 1, 0):max(si - 1, 0)]
        sta_a_c[max(-i0 + 2, 0):, trial_idx, spike_idx] = all_ac[trial_idx][max(i0 - 2, 0):max(si - 2, 0)]
        sta_x_c[max(-i0, 0):, trial_idx, spike_idx] = trajx_c[trial_idx][max(i0, 0):si]
        sta_y_c[max(-i0, 0):, trial_idx, spike_idx] = trajy_c[trial_idx][max(i0, 0):si]
        sta_r_c[max(-i0, 0):, trial_idx, spike_idx] = all_r_c[trial_idx][max(i0, 0):si]
        d_c[max(-i0, 0):, trial_idx, spike_idx] += 1

for trial_idx, spikes in enumerate(spike_indices_f):

    valid_mask = spikes > 5000
    spikes = spikes[valid_mask]
    spike_indices = (spikes.flatten() / 10000 / dt).astype(int)
    for spike_idx, si in enumerate(spike_indices):
        i0 = si - T
        sta_v_f[max(-i0 + 1, 0):, trial_idx, spike_idx] = all_vf[trial_idx][max(i0 - 1, 0):max(si - 1, 0)]
        sta_a_f[max(-i0 + 2, 0):, trial_idx, spike_idx] = all_af[trial_idx][max(i0 - 2, 0):max(si - 2, 0)]
        sta_x_f[max(-i0, 0):, trial_idx, spike_idx] = trajx_f[trial_idx][max(i0, 0):si]
        sta_y_f[max(-i0, 0):, trial_idx, spike_idx] = trajy_f[trial_idx][max(i0, 0):si]
        sta_r_f[max(-i0, 0):, trial_idx, spike_idx] = all_r_f[trial_idx][max(i0, 0):si]
        d_f[max(-i0, 0):, trial_idx, spike_idx] += 1

sta_v_n /= d_n
sta_a_n /= d_n
sta_x_n /= d_n
sta_y_n /= d_n
sta_r_n /= d_n

sta_v_c /= d_c
sta_a_c /= d_c
sta_x_c /= d_c
sta_y_c /= d_c
sta_r_c /= d_c

sta_v_f /= d_f
sta_a_f /= d_f
sta_x_f /= d_f
sta_y_f /= d_f
sta_r_f /= d_f

avg_sta_v_n = np.nanmean(sta_v_n, axis=(2))
avg_sta_a_n = np.nanmean(sta_a_n, axis=(2))
avg_sta_x_n = np.nanmean(sta_x_n, axis=(2))
avg_sta_y_n = np.nanmean(sta_y_n, axis=(2))
avg_sta_r_n = np.nanmean(sta_r_n, axis=(2))

avg_sta_v_c = np.nanmean(sta_v_c, axis=(2))
avg_sta_a_c = np.nanmean(sta_a_c, axis=(2))
avg_sta_x_c = np.nanmean(sta_x_c, axis=(2))
avg_sta_y_c = np.nanmean(sta_y_c, axis=(2))
avg_sta_r_c = np.nanmean(sta_r_c, axis=(2))

avg_sta_v_f = np.nanmean(sta_v_f, axis=(2))
avg_sta_a_f = np.nanmean(sta_a_f, axis=(2))
avg_sta_x_f = np.nanmean(sta_x_f, axis=(2))
avg_sta_y_f = np.nanmean(sta_y_f, axis=(2))
avg_sta_r_f = np.nanmean(sta_r_f, axis=(2))
# Out:
# C:\Users\Komeijiiiii\AppData\Local\Temp\ipykernel_42888\452097538.py:87: RuntimeWarning: Mean of empty slice
#   avg_sta_v_n = np.nanmean(sta_v_n, axis=(2))
# C:\Users\Komeijiiiii\AppData\Local\Temp\ipykernel_42888\452097538.py:88: RuntimeWarning: Mean of empty slice
#   avg_sta_a_n = np.nanmean(sta_a_n, axis=(2))
# C:\Users\Komeijiiiii\AppData\Local\Temp\ipykernel_42888\452097538.py:89: RuntimeWarning: Mean of empty slice
#   avg_sta_x_n = np.nanmean(sta_x_n, axis=(2))
# C:\Users\Komeijiiiii\AppData\Local\Temp\ipykernel_42888\452097538.py:90: RuntimeWarning: Mean of empty slice
#   avg_sta_y_n = np.nanmean(sta_y_n, axis=(2))
# C:\Users\Komeijiiiii\AppData\Local\Temp\ipykernel_42888\452097538.py:91: RuntimeWarning: Mean of empty slice
#   avg_sta_r_n = np.nanmean(sta_r_n, axis=(2))
# C:\Users\Komeijiiiii\AppData\Local\Temp\ipykernel_42888\452097538.py:93: RuntimeWarning: Mean of empty slice
#   avg_sta_v_c = np.nanmean(sta_v_c, axis=(2))
# C:\Users\Komeijiiiii\AppData\Local\Temp\ipykernel_42888\452097538.py:94: RuntimeWarning: Mean of empty slice
#   avg_sta_a_c = np.nanmean(sta_a_c, axis=(2))
# C:\Users\Komeijiiiii\AppData\Local\Temp\ipykernel_42888\452097538.py:95: RuntimeWarning: Mean of empty slice
#   avg_sta_x_c = np.nanmean(sta_x_c, axis=(2))
# C:\Users\Komeijiiiii\AppData\Local\Temp\ipykernel_42888\452097538.py:96: RuntimeWarning: Mean of empty slice
#   avg_sta_y_c = np.nanmean(sta_y_c, axis=(2))
# C:\Users\Komeijiiiii\AppData\Local\Temp\ipykernel_42888\452097538.py:97: RuntimeWarning: Mean of empty slice
#   avg_sta_r_c = np.nanmean(sta_r_c, axis=(2))
# C:\Users\Komeijiiiii\AppData\Local\Temp\ipykernel_42888\452097538.py:99: RuntimeWarning: Mean of empty slice
#   avg_sta_v_f = np.nanmean(sta_v_f, axis=(2))
# C:\Users\Komeijiiiii\AppData\Local\Temp\ipykernel_42888\452097538.py:100: RuntimeWarning: Mean of empty slice
#   avg_sta_a_f = np.nanmean(sta_a_f, axis=(2))
# C:\Users\Komeijiiiii\AppData\Local\Temp\ipykernel_42888\452097538.py:101: RuntimeWarning: Mean of empty slice
#   avg_sta_x_f = np.nanmean(sta_x_f, axis=(2))
# C:\Users\Komeijiiiii\AppData\Local\Temp\ipykernel_42888\452097538.py:102: RuntimeWarning: Mean of empty slice
#   avg_sta_y_f = np.nanmean(sta_y_f, axis=(2))
# C:\Users\Komeijiiiii\AppData\Local\Temp\ipykernel_42888\452097538.py:103: RuntimeWarning: Mean of empty slice
#   avg_sta_r_f = np.nanmean(sta_r_f, axis=(2))

# %%
time_points = np.arange(-49,1) 

def plot_heatmap_pcolormesh(ax, data_2d, var_name, time_arr, n_dbins=800, fontsize=28, vmin=None, vmax=None):
    # 1) mask NaNs
    mask = ~np.isnan(data_2d)
    tf = np.tile(time_arr, data_2d.shape[1])[mask.ravel()]
    df = data_2d.ravel()[mask.ravel()]

    # 2) build bin‐edges
    t_edges = np.linspace(time_arr.min(), time_arr.max(), data_2d.shape[0] + 1)
    d_edges = np.linspace(df.min(), df.max(), n_dbins + 1)

    # 3) 2D histogram
    counts, _, _ = np.histogram2d(tf, df, bins=[t_edges, d_edges])

    # 4) mesh it out
    T, D = np.meshgrid(t_edges*100/6, d_edges)
    pcm = ax.pcolormesh(T, D, counts.T,
                        cmap='turbo',
                        shading='auto',
                        vmin=vmin, vmax=vmax)

    ax.set_title(var_name, fontsize=fontsize)
    ax.set_xlabel("Time (ms)", fontsize=fontsize)
    ax.set_ylabel(var_name, fontsize=fontsize)
    ax.tick_params(axis='both', which='major', labelsize=fontsize-6)
    # Add colorbar for each subplot
    cbar = plt.colorbar(pcm, ax=ax, pad=0.02, aspect=30)
    cbar.ax.tick_params(labelsize=fontsize-8)
    cbar.set_label('Count', fontsize=fontsize-4)

# Prepare data and names (NO FLASH)
data_list = [avg_sta_v_n, avg_sta_v_c, avg_sta_a_n, avg_sta_a_c, avg_sta_x_n, avg_sta_x_c, avg_sta_y_n, avg_sta_y_c, avg_sta_r_n, avg_sta_r_c]
name_list = [
    "Velocity(Natural)", "Velocity(Control)",
    "Acceleration(Natural)", "Acceleration(Control)",
    "X Position(Natural)", "X Position(Control)",
    "Y Position(Natural)", "Y Position(Control)",
    "Radius(Natural)", "Radius(Control)"
]

# Compute vmin/vmax for each "natural" variable and use for corresponding "control"
# Indices: 0,2,4,6,8 are "natural"; 1,3,5,7,9 are "control"
natural_indices = [0, 2, 4, 6, 8]
control_indices = [1, 3, 5, 7, 9]

vmin_list = [None] * len(data_list)
vmax_list = [None] * len(data_list)

for n_idx, c_idx in zip(natural_indices, control_indices):
    # Compute vmin/vmax for natural
    data_n = data_list[n_idx]
    mask_n = ~np.isnan(data_n)
    tf_n = np.tile(time_points, data_n.shape[1])[mask_n.ravel()]
    df_n = data_n.ravel()[mask_n.ravel()]
    t_edges = np.linspace(time_points.min(), time_points.max(), data_n.shape[0] + 1)
    d_edges = np.linspace(df_n.min(), df_n.max(), 201)
    counts_n, _, _ = np.histogram2d(tf_n, df_n, bins=[t_edges, d_edges])


    vmin = counts_n.min()
    vmax = counts_n.max()
    vmin_list[n_idx] = vmin
    vmax_list[n_idx] = vmax
    # Use same vmin/vmax for control
    vmin_list[c_idx] = vmin
    vmax_list[c_idx] = vmax

fig, axes = plt.subplots(5, 2,
                         figsize=(22, 32),
                         sharey='row')
for i, (ax, data, label) in enumerate(zip(axes.flat, data_list, name_list)):
    plot_heatmap_pcolormesh(ax, data, label, time_points, fontsize=28, vmin=vmin_list[i], vmax=vmax_list[i])
plt.tight_layout()
plt.show()

# %%
avg_sta_v_n = np.nanmean(sta_v_n, axis=(1,2))
avg_sta_a_n = np.nanmean(sta_a_n, axis=(1,2))
avg_sta_x_n = np.nanmean(sta_x_n, axis=(1,2))
avg_sta_y_n = np.nanmean(sta_y_n, axis=(1,2))
avg_sta_r_n = np.nanmean(sta_r_n, axis=(1,2))

avg_sta_v_c = np.nanmean(sta_v_c, axis=(1,2))
avg_sta_a_c = np.nanmean(sta_a_c, axis=(1,2))
avg_sta_x_c = np.nanmean(sta_x_c, axis=(1,2))
avg_sta_y_c = np.nanmean(sta_y_c, axis=(1,2))
avg_sta_r_c = np.nanmean(sta_r_c, axis=(1,2))

avg_sta_v_f = np.nanmean(sta_v_f, axis=(1,2))
avg_sta_a_f = np.nanmean(sta_a_f, axis=(1,2))
avg_sta_x_f = np.nanmean(sta_x_f, axis=(1,2))
avg_sta_y_f = np.nanmean(sta_y_f, axis=(1,2))
avg_sta_r_f = np.nanmean(sta_r_f, axis=(1,2))


# Plot STA for velocity and acceleration
time_window = np.linspace(-T * dt, -dt, T)

sem_x_n = np.nanstd(sta_x_n.reshape(T, -1), axis=1) / np.sqrt(np.nansum(d_n, axis=(1,2)))
sem_x_c = np.nanstd(sta_x_c.reshape(T, -1), axis=1) / np.sqrt(np.nansum(d_c, axis=(1,2)))
sem_x_f = np.nanstd(sta_x_f.reshape(T, -1), axis=1) / np.sqrt(np.nansum(d_f, axis=(1,2)))
sem_y_n = np.nanstd(sta_y_n.reshape(T, -1), axis=1) / np.sqrt(np.nansum(d_n, axis=(1,2)))
sem_y_c = np.nanstd(sta_y_c.reshape(T, -1), axis=1) / np.sqrt(np.nansum(d_c, axis=(1,2)))
sem_y_f = np.nanstd(sta_y_f.reshape(T, -1), axis=1) / np.sqrt(np.nansum(d_f, axis=(1,2)))
sem_r_n = np.nanstd(sta_r_n.reshape(T, -1), axis=1) / np.sqrt(np.nansum(d_n, axis=(1,2)))
sem_r_c = np.nanstd(sta_r_c.reshape(T, -1), axis=1) / np.sqrt(np.nansum(d_c, axis=(1,2)))
sem_r_f = np.nanstd(sta_r_f.reshape(T, -1), axis=1) / np.sqrt(np.nansum(d_f, axis=(1,2)))

sem_v_n = np.nanstd(sta_v_n.reshape(T, -1), axis=1) / np.sqrt(np.nansum(d_n, axis=(1,2)))
sem_v_c = np.nanstd(sta_v_c.reshape(T, -1), axis=1) / np.sqrt(np.nansum(d_c, axis=(1,2)))
sem_v_f = np.nanstd(sta_v_f.reshape(T, -1), axis=1) / np.sqrt(np.nansum(d_f, axis=(1,2)))

sem_a_n = np.nanstd(sta_a_n.reshape(T, -1), axis=1) / np.sqrt(np.nansum(d_n, axis=(1,2)))
sem_a_c = np.nanstd(sta_a_c.reshape(T, -1), axis=1) / np.sqrt(np.nansum(d_c, axis=(1,2)))
sem_a_f = np.nanstd(sta_a_f.reshape(T, -1), axis=1) / np.sqrt(np.nansum(d_f, axis=(1,2)))

# Set font sizes
title_fontsize = 28
label_fontsize = 22
tick_fontsize = 18
legend_fontsize = 18

plt.figure(figsize=(18, 20))
plt.suptitle('V3 Spike-Triggered Average (STA ± 2 SEM)', fontsize=title_fontsize + 4, y=1.02)

# Position
plt.subplot(3, 1, 1)
plt.plot(time_window, avg_sta_r_n, label='Natural Stimuli (R)', color='tomato')
plt.fill_between(time_window,  avg_sta_r_n - 2 * sem_r_n,  avg_sta_r_n + 2 * sem_r_n,color='tomato', alpha=0.2)
plt.plot(time_window, avg_sta_r_c, label='Control Stimuli (R)', color='k')
plt.fill_between(time_window,  avg_sta_r_c - 2 * sem_r_c,  avg_sta_r_c + 2 * sem_r_c,color='k', alpha=0.2)
# plt.plot(time_window, avg_sta_r_f, label='Flash Stimuli (R)', color='yellow')
# plt.fill_between(time_window,  avg_sta_r_f - 2 * sem_r_f,  avg_sta_r_f + 2 * sem_r_f,color='yellow', alpha=0.2)
plt.plot(time_window, avg_sta_x_n, label='Natural Stimuli (X)', color='darkred')
plt.fill_between(time_window,  avg_sta_x_n - 2 * sem_x_n,  avg_sta_x_n + 2 * sem_x_n,color='darkred', alpha=0.2)
plt.plot(time_window, avg_sta_x_c, label='Control Stimuli (X)', color='green')
plt.fill_between(time_window,  avg_sta_x_c - 2 * sem_x_c,  avg_sta_x_c + 2 * sem_x_c,color='green', alpha=0.2)
# plt.plot(time_window, avg_sta_x_f, label='Flash Stimuli (X)', color='yellow')
# plt.fill_between(time_window,  avg_sta_x_f - 2 * sem_x_f,  avg_sta_x_f + 2 * sem_x_f,color='yellow', alpha=0.2)
plt.plot(time_window, avg_sta_y_n, label='Natural Stimuli (Y)', color='firebrick')
plt.fill_between(time_window,  avg_sta_y_n - 2 * sem_y_n,  avg_sta_y_n + 2 * sem_y_n,color='firebrick', alpha=0.2)
plt.plot(time_window, avg_sta_y_c, label='Control Stimuli (Y)', color='blue')
plt.fill_between(time_window,  avg_sta_y_c - 2 * sem_y_c,  avg_sta_y_c + 2 * sem_y_c,color='blue', alpha=0.2)
# plt.plot(time_window, avg_sta_y_f, label='Flash Stimuli (Y)', color='yellow')
# plt.fill_between(time_window,  avg_sta_y_f - 2 * sem_y_f,  avg_sta_y_f + 2 * sem_y_f,color='yellow', alpha=0.2)

plt.xlabel('Time Before Spike (s)', fontsize=label_fontsize)
plt.ylabel('Average position(μm)', fontsize=label_fontsize)
plt.title('Position', fontsize=title_fontsize)
plt.legend(fontsize=legend_fontsize)
plt.grid(True)
plt.xticks(fontsize=tick_fontsize)
plt.yticks(fontsize=tick_fontsize)

# Velocity
plt.subplot(3, 1, 2)
plt.plot(time_window, avg_sta_v_n, label='Natural Stimuli (Speed)', color='red')
plt.fill_between(time_window,  avg_sta_v_n - 2 * sem_v_n,  avg_sta_v_n + 2 * sem_v_n,color='red', alpha=0.2)
plt.plot(time_window, avg_sta_v_c, label='Control Stimuli (Speed)', color='k')
plt.fill_between(time_window,  avg_sta_v_c - 2 * sem_v_c,  avg_sta_v_c + 2 * sem_v_c,color='k', alpha=0.2)
plt.xlabel('Time Before Spike (s)', fontsize=label_fontsize)
plt.ylabel('Average Speed (μm/s)', fontsize=label_fontsize)
plt.title('Velocity', fontsize=title_fontsize)
plt.legend(fontsize=legend_fontsize)
plt.grid(True)
plt.xticks(fontsize=tick_fontsize)
plt.yticks(fontsize=tick_fontsize)

# Acceleration
plt.subplot(3, 1, 3)
plt.plot(time_window, avg_sta_a_n, label='Natural Stimuli (Acceleration)', color='red')
plt.fill_between(time_window,  avg_sta_a_n - 2 * sem_a_n, avg_sta_a_n + 2 * sem_a_n,color='red', alpha=0.2)
plt.plot(time_window, avg_sta_a_c, label='Control Stimuli (Acceleration)', color='k')
plt.fill_between(time_window, avg_sta_a_c - 2 * sem_a_c, avg_sta_a_c + 2 * sem_a_c,color='k', alpha=0.2)
plt.xlabel('Time Before Spike (s)', fontsize=label_fontsize)
plt.ylabel('Average Acceleration (μm/s²)', fontsize=label_fontsize)
plt.title('Acceleration', fontsize=title_fontsize)
plt.legend(fontsize=legend_fontsize)
plt.grid(True)
plt.xticks(fontsize=tick_fontsize)
plt.yticks(fontsize=tick_fontsize)

plt.tight_layout()
plt.show()

# %% [markdown]
# # LN-GC model

# %% [markdown]
# # stimuli generation

# %%
# stimuli_c=[]
# for i in range(trajx_c.shape[0]):
#     stimuli_c.append(sg.generate_stimuli(trajx_c[i], trajy_c[i], board_size=900, diameter=30,fps = 60,pretime =0,tailtime =0,type='natural',preframes=30,tailframes=60,stimframes=60))
# stimuli_n=[]
# for i in range(trajx_n.shape[0]):
#     stimuli_n.append(sg.generate_stimuli(trajx_n[i], trajy_n[i], board_size=900, diameter=30,fps = 60,pretime =0,tailtime =0,type='natural',preframes=30,tailframes=60,stimframes=60))

# %%
n_cells   = trajx_c.shape[0] 
n_frames  = 93
H = W     = 401
dtype     = 'uint8'

with h5py.File('results/stimulic2_cV3.h5', 'w') as f:
    # 1) movie dataset  (chunk = one full movie for fast per‑cell IO)
    dset = f.create_dataset(
        'stimuli',
        shape      =(n_cells, n_frames, H, W),
        dtype      = 'uint8',
        chunks     =(1, n_frames, H, W),
        compression='gzip',
        shuffle    = True
    )
    # 2) epoch‑ID dataset  (1‑D uint64)
    f.create_dataset(
        'epoch_id',
        data       = np.asarray(epoch_id_c, dtype='uint16')
    )

    # 3) fill the movies, one cell at a time
    for i in range(n_cells):
        movie = sg.generate_stimuli(
            trajx_c[i], trajy_c[i],
            board_size = H-1,
            diameter   = 30,
            fps        = 60,
            pretime    = 0, tailtime = 0,
            type       ='natural',
            preframes  = 30, tailframes = 32, stimframes = 30
        )
        dset[i] = movie            # direct disk write → no RAM spike
        print(f'cell {i:3d} written  epoch_id={epoch_id_c[i]}')
# Out:
# cell   0 written  epoch_id=[[1751.]]
# cell   1 written  epoch_id=[[1754.]]
# cell   2 written  epoch_id=[[1758.]]
# cell   3 written  epoch_id=[[1759.]]
# cell   4 written  epoch_id=[[1762.]]
# cell   5 written  epoch_id=[[1764.]]
# cell   6 written  epoch_id=[[1765.]]
# cell   7 written  epoch_id=[[1770.]]
# cell   8 written  epoch_id=[[1773.]]
# cell   9 written  epoch_id=[[1776.]]
# cell  10 written  epoch_id=[[1777.]]
# cell  11 written  epoch_id=[[1779.]]
# cell  12 written  epoch_id=[[1780.]]
# cell  13 written  epoch_id=[[1786.]]
# cell  14 written  epoch_id=[[1797.]]
# cell  15 written  epoch_id=[[1803.]]
# cell  16 written  epoch_id=[[1804.]]
# cell  17 written  epoch_id=[[1805.]]
# cell  18 written  epoch_id=[[1809.]]
# cell  19 written  epoch_id=[[1810.]]
# cell  20 written  epoch_id=[[1811.]]
# cell  21 written  epoch_id=[[1813.]]
# cell  22 written  epoch_id=[[1818.]]
# cell  23 written  epoch_id=[[1821.]]
# cell  24 written  epoch_id=[[1825.]]
# cell  25 written  epoch_id=[[1827.]]
# cell  26 written  epoch_id=[[1829.]]
# cell  27 written  epoch_id=[[1831.]]
# cell  28 written  epoch_id=[[1837.]]
# cell  29 written  epoch_id=[[1838.]]
# cell  30 written  epoch_id=[[1839.]]
# cell  31 written  epoch_id=[[1842.]]
# cell  32 written  epoch_id=[[1844.]]
# cell  33 written  epoch_id=[[1847.]]
# cell  34 written  epoch_id=[[1849.]]
# cell  35 written  epoch_id=[[1852.]]
# cell  36 written  epoch_id=[[1855.]]
# cell  37 written  epoch_id=[[1856.]]
# cell  38 written  epoch_id=[[1861.]]
# cell  39 written  epoch_id=[[1862.]]
# cell  40 written  epoch_id=[[1870.]]
# cell  41 written  epoch_id=[[1872.]]
# cell  42 written  epoch_id=[[1874.]]
# cell  43 written  epoch_id=[[1875.]]
# cell  44 written  epoch_id=[[1880.]]
# cell  45 written  epoch_id=[[1881.]]
# cell  46 written  epoch_id=[[1885.]]
# cell  47 written  epoch_id=[[1898.]]
# cell  48 written  epoch_id=[[1899.]]
# cell  49 written  epoch_id=[[1900.]]
# cell  50 written  epoch_id=[[1902.]]
# cell  51 written  epoch_id=[[1907.]]
# cell  52 written  epoch_id=[[1909.]]
# cell  53 written  epoch_id=[[1912.]]
# cell  54 written  epoch_id=[[1914.]]
# cell  55 written  epoch_id=[[1918.]]
# cell  56 written  epoch_id=[[1920.]]
# cell  57 written  epoch_id=[[1921.]]
# cell  58 written  epoch_id=[[1922.]]
# cell  59 written  epoch_id=[[1925.]]
# cell  60 written  epoch_id=[[1928.]]
# cell  61 written  epoch_id=[[1932.]]
# cell  62 written  epoch_id=[[1934.]]
# cell  63 written  epoch_id=[[1937.]]
# cell  64 written  epoch_id=[[1940.]]
# cell  65 written  epoch_id=[[1946.]]
# cell  66 written  epoch_id=[[1948.]]
# cell  67 written  epoch_id=[[1952.]]
# cell  68 written  epoch_id=[[1954.]]
# cell  69 written  epoch_id=[[1957.]]
# cell  70 written  epoch_id=[[1960.]]
# cell  71 written  epoch_id=[[1963.]]
# cell  72 written  epoch_id=[[1969.]]
# cell  73 written  epoch_id=[[1972.]]
# cell  74 written  epoch_id=[[1974.]]
# cell  75 written  epoch_id=[[1976.]]
# cell  76 written  epoch_id=[[1980.]]
# cell  77 written  epoch_id=[[1981.]]
# cell  78 written  epoch_id=[[1983.]]
# cell  79 written  epoch_id=[[1985.]]
# cell  80 written  epoch_id=[[1991.]]
# cell  81 written  epoch_id=[[1993.]]
# cell  82 written  epoch_id=[[1994.]]
# cell  83 written  epoch_id=[[1998.]]
# cell  84 written  epoch_id=[[1999.]]
# cell  85 written  epoch_id=[[2001.]]
# cell  86 written  epoch_id=[[2002.]]
# cell  87 written  epoch_id=[[2012.]]
# cell  88 written  epoch_id=[[2013.]]
# cell  89 written  epoch_id=[[2014.]]
# cell  90 written  epoch_id=[[2015.]]
# cell  91 written  epoch_id=[[2021.]]
# cell  92 written  epoch_id=[[2024.]]
# cell  93 written  epoch_id=[[2026.]]
# cell  94 written  epoch_id=[[2028.]]
# cell  95 written  epoch_id=[[2030.]]
# cell  96 written  epoch_id=[[2037.]]
# cell  97 written  epoch_id=[[2038.]]
# cell  98 written  epoch_id=[[2043.]]
# cell  99 written  epoch_id=[[2045.]]
# cell 100 written  epoch_id=[[2048.]]
# cell 101 written  epoch_id=[[2050.]]
# cell 102 written  epoch_id=[[2053.]]
# cell 103 written  epoch_id=[[2057.]]
# cell 104 written  epoch_id=[[2059.]]
# cell 105 written  epoch_id=[[2062.]]
# cell 106 written  epoch_id=[[2063.]]
# cell 107 written  epoch_id=[[2065.]]
# cell 108 written  epoch_id=[[2066.]]
# cell 109 written  epoch_id=[[2067.]]
# cell 110 written  epoch_id=[[2070.]]
# cell 111 written  epoch_id=[[2073.]]
# cell 112 written  epoch_id=[[2076.]]
# cell 113 written  epoch_id=[[2080.]]
# cell 114 written  epoch_id=[[2081.]]
# cell 115 written  epoch_id=[[2082.]]
# cell 116 written  epoch_id=[[2086.]]
# cell 117 written  epoch_id=[[2087.]]
# cell 118 written  epoch_id=[[2094.]]
# cell 119 written  epoch_id=[[2095.]]
# cell 120 written  epoch_id=[[2102.]]
# cell 121 written  epoch_id=[[2105.]]
# cell 122 written  epoch_id=[[2106.]]
# cell 123 written  epoch_id=[[2107.]]
# cell 124 written  epoch_id=[[2108.]]
# cell 125 written  epoch_id=[[2110.]]
# cell 126 written  epoch_id=[[2111.]]
# cell 127 written  epoch_id=[[2114.]]
# cell 128 written  epoch_id=[[2118.]]
# cell 129 written  epoch_id=[[2119.]]
# cell 130 written  epoch_id=[[2123.]]
# cell 131 written  epoch_id=[[2126.]]
# cell 132 written  epoch_id=[[2128.]]
# cell 133 written  epoch_id=[[2136.]]
# cell 134 written  epoch_id=[[2143.]]
# cell 135 written  epoch_id=[[2145.]]
# cell 136 written  epoch_id=[[2151.]]
# cell 137 written  epoch_id=[[2152.]]
# cell 138 written  epoch_id=[[2166.]]
# cell 139 written  epoch_id=[[2169.]]
# cell 140 written  epoch_id=[[2171.]]
# cell 141 written  epoch_id=[[2175.]]
# cell 142 written  epoch_id=[[2178.]]
# cell 143 written  epoch_id=[[2180.]]
# cell 144 written  epoch_id=[[2181.]]
# cell 145 written  epoch_id=[[2183.]]
# cell 146 written  epoch_id=[[2185.]]
# cell 147 written  epoch_id=[[2189.]]
# cell 148 written  epoch_id=[[2191.]]
# cell 149 written  epoch_id=[[2195.]]
# cell 150 written  epoch_id=[[2196.]]
# cell 151 written  epoch_id=[[2197.]]
# cell 152 written  epoch_id=[[2199.]]
# cell 153 written  epoch_id=[[2202.]]
# cell 154 written  epoch_id=[[2208.]]
# cell 155 written  epoch_id=[[2210.]]
# cell 156 written  epoch_id=[[2213.]]
# cell 157 written  epoch_id=[[2216.]]
# cell 158 written  epoch_id=[[2220.]]
# cell 159 written  epoch_id=[[2227.]]
# cell 160 written  epoch_id=[[2230.]]
# cell 161 written  epoch_id=[[2234.]]
# cell 162 written  epoch_id=[[2236.]]
# cell 163 written  epoch_id=[[2239.]]
# cell 164 written  epoch_id=[[2240.]]
# cell 165 written  epoch_id=[[2244.]]
# cell 166 written  epoch_id=[[2248.]]
# cell 167 written  epoch_id=[[2252.]]
# cell 168 written  epoch_id=[[2254.]]
# cell 169 written  epoch_id=[[2256.]]
# cell 170 written  epoch_id=[[2263.]]
# cell 171 written  epoch_id=[[2265.]]
# cell 172 written  epoch_id=[[2266.]]
# cell 173 written  epoch_id=[[2267.]]
# cell 174 written  epoch_id=[[2273.]]
# cell 175 written  epoch_id=[[2277.]]
# cell 176 written  epoch_id=[[2280.]]
# cell 177 written  epoch_id=[[2289.]]
# cell 178 written  epoch_id=[[2291.]]
# cell 179 written  epoch_id=[[2297.]]
# cell 180 written  epoch_id=[[2300.]]
# cell 181 written  epoch_id=[[2306.]]
# cell 182 written  epoch_id=[[2311.]]
# cell 183 written  epoch_id=[[2315.]]
# cell 184 written  epoch_id=[[2316.]]
# cell 185 written  epoch_id=[[2318.]]
# cell 186 written  epoch_id=[[2320.]]
# cell 187 written  epoch_id=[[2324.]]
# cell 188 written  epoch_id=[[2325.]]
# cell 189 written  epoch_id=[[2328.]]
# cell 190 written  epoch_id=[[2330.]]
# cell 191 written  epoch_id=[[2331.]]
# cell 192 written  epoch_id=[[2335.]]
# cell 193 written  epoch_id=[[2336.]]
# cell 194 written  epoch_id=[[2338.]]
# cell 195 written  epoch_id=[[2341.]]
# cell 196 written  epoch_id=[[2342.]]
# cell 197 written  epoch_id=[[2347.]]
# cell 198 written  epoch_id=[[2348.]]
# cell 199 written  epoch_id=[[2351.]]
# cell 200 written  epoch_id=[[2352.]]
# cell 201 written  epoch_id=[[2354.]]
# cell 202 written  epoch_id=[[2355.]]
# cell 203 written  epoch_id=[[2360.]]
# cell 204 written  epoch_id=[[2363.]]
# cell 205 written  epoch_id=[[2364.]]
# cell 206 written  epoch_id=[[2367.]]
# cell 207 written  epoch_id=[[2371.]]
# cell 208 written  epoch_id=[[2372.]]
# cell 209 written  epoch_id=[[2378.]]
# cell 210 written  epoch_id=[[2382.]]
# cell 211 written  epoch_id=[[2384.]]
# cell 212 written  epoch_id=[[2386.]]
# cell 213 written  epoch_id=[[2387.]]
# cell 214 written  epoch_id=[[2388.]]
# cell 215 written  epoch_id=[[2392.]]
# cell 216 written  epoch_id=[[2395.]]
# cell 217 written  epoch_id=[[2402.]]
# cell 218 written  epoch_id=[[2405.]]
# cell 219 written  epoch_id=[[2408.]]
# cell 220 written  epoch_id=[[2409.]]
# cell 221 written  epoch_id=[[2413.]]
# cell 222 written  epoch_id=[[2422.]]
# cell 223 written  epoch_id=[[2427.]]
# cell 224 written  epoch_id=[[2428.]]
# cell 225 written  epoch_id=[[2429.]]
# cell 226 written  epoch_id=[[2430.]]
# cell 227 written  epoch_id=[[2432.]]
# cell 228 written  epoch_id=[[2433.]]
# cell 229 written  epoch_id=[[2435.]]
# cell 230 written  epoch_id=[[2442.]]
# cell 231 written  epoch_id=[[2445.]]
# cell 232 written  epoch_id=[[2448.]]
# cell 233 written  epoch_id=[[2457.]]
# cell 234 written  epoch_id=[[2461.]]
# cell 235 written  epoch_id=[[2467.]]
# cell 236 written  epoch_id=[[2468.]]
# cell 237 written  epoch_id=[[2470.]]
# cell 238 written  epoch_id=[[2474.]]
# cell 239 written  epoch_id=[[2475.]]
# cell 240 written  epoch_id=[[2476.]]
# cell 241 written  epoch_id=[[2479.]]
# cell 242 written  epoch_id=[[2480.]]
# cell 243 written  epoch_id=[[2482.]]
# cell 244 written  epoch_id=[[2486.]]
# cell 245 written  epoch_id=[[2487.]]
# cell 246 written  epoch_id=[[2493.]]
# cell 247 written  epoch_id=[[2498.]]
# cell 248 written  epoch_id=[[2502.]]
# cell 249 written  epoch_id=[[2503.]]
# cell 250 written  epoch_id=[[2508.]]
# cell 251 written  epoch_id=[[2510.]]
# cell 252 written  epoch_id=[[2513.]]
# cell 253 written  epoch_id=[[2515.]]
# cell 254 written  epoch_id=[[2518.]]
# cell 255 written  epoch_id=[[2519.]]
# cell 256 written  epoch_id=[[2522.]]
# cell 257 written  epoch_id=[[2524.]]
# cell 258 written  epoch_id=[[2527.]]
# cell 259 written  epoch_id=[[2528.]]
# cell 260 written  epoch_id=[[2533.]]
# cell 261 written  epoch_id=[[2537.]]
# cell 262 written  epoch_id=[[2540.]]
# cell 263 written  epoch_id=[[2541.]]
# cell 264 written  epoch_id=[[2543.]]
# cell 265 written  epoch_id=[[2545.]]
# cell 266 written  epoch_id=[[2546.]]
# cell 267 written  epoch_id=[[2547.]]
# cell 268 written  epoch_id=[[2552.]]
# cell 269 written  epoch_id=[[2554.]]
# cell 270 written  epoch_id=[[2556.]]
# cell 271 written  epoch_id=[[2558.]]
# cell 272 written  epoch_id=[[2559.]]
# cell 273 written  epoch_id=[[2562.]]
# cell 274 written  epoch_id=[[2574.]]
# cell 275 written  epoch_id=[[2575.]]
# cell 276 written  epoch_id=[[2576.]]
# cell 277 written  epoch_id=[[2577.]]
# cell 278 written  epoch_id=[[2583.]]
# cell 279 written  epoch_id=[[2584.]]
# cell 280 written  epoch_id=[[2592.]]
# cell 281 written  epoch_id=[[2604.]]
# cell 282 written  epoch_id=[[2609.]]
# cell 283 written  epoch_id=[[2614.]]
# cell 284 written  epoch_id=[[2616.]]
# cell 285 written  epoch_id=[[2619.]]
# cell 286 written  epoch_id=[[2622.]]
# cell 287 written  epoch_id=[[2623.]]
# cell 288 written  epoch_id=[[2624.]]
# cell 289 written  epoch_id=[[2628.]]
# cell 290 written  epoch_id=[[2632.]]
# cell 291 written  epoch_id=[[2636.]]
# cell 292 written  epoch_id=[[2637.]]
# cell 293 written  epoch_id=[[2638.]]
# cell 294 written  epoch_id=[[2640.]]
# cell 295 written  epoch_id=[[2642.]]
# cell 296 written  epoch_id=[[2643.]]
# cell 297 written  epoch_id=[[2645.]]
# cell 298 written  epoch_id=[[2647.]]
# cell 299 written  epoch_id=[[2651.]]
# cell 300 written  epoch_id=[[2652.]]
# cell 301 written  epoch_id=[[2654.]]
# cell 302 written  epoch_id=[[2657.]]
# cell 303 written  epoch_id=[[2660.]]
# cell 304 written  epoch_id=[[2661.]]
# cell 305 written  epoch_id=[[2673.]]
# cell 306 written  epoch_id=[[2677.]]
# cell 307 written  epoch_id=[[2679.]]
# cell 308 written  epoch_id=[[2682.]]
# cell 309 written  epoch_id=[[2683.]]
# cell 310 written  epoch_id=[[2692.]]
# cell 311 written  epoch_id=[[2694.]]
# cell 312 written  epoch_id=[[2695.]]
# cell 313 written  epoch_id=[[2698.]]
# cell 314 written  epoch_id=[[2706.]]
# cell 315 written  epoch_id=[[2708.]]
# cell 316 written  epoch_id=[[2710.]]
# cell 317 written  epoch_id=[[2712.]]
# cell 318 written  epoch_id=[[2716.]]
# cell 319 written  epoch_id=[[2718.]]
# cell 320 written  epoch_id=[[2722.]]
# cell 321 written  epoch_id=[[2723.]]
# cell 322 written  epoch_id=[[2724.]]
# cell 323 written  epoch_id=[[2728.]]
# cell 324 written  epoch_id=[[2730.]]
# cell 325 written  epoch_id=[[2731.]]
# cell 326 written  epoch_id=[[2735.]]
# cell 327 written  epoch_id=[[2738.]]
# cell 328 written  epoch_id=[[2739.]]
# cell 329 written  epoch_id=[[2740.]]
# cell 330 written  epoch_id=[[2741.]]
# cell 331 written  epoch_id=[[2744.]]
# cell 332 written  epoch_id=[[2747.]]
# cell 333 written  epoch_id=[[2748.]]
# cell 334 written  epoch_id=[[2749.]]
# cell 335 written  epoch_id=[[2750.]]
# cell 336 written  epoch_id=[[2754.]]
# cell 337 written  epoch_id=[[2758.]]
# cell 338 written  epoch_id=[[2766.]]
# cell 339 written  epoch_id=[[2768.]]
# cell 340 written  epoch_id=[[2770.]]
# cell 341 written  epoch_id=[[2775.]]
# cell 342 written  epoch_id=[[2776.]]
# cell 343 written  epoch_id=[[2777.]]
# cell 344 written  epoch_id=[[2778.]]
# cell 345 written  epoch_id=[[2782.]]
# cell 346 written  epoch_id=[[2788.]]
# cell 347 written  epoch_id=[[2790.]]
# cell 348 written  epoch_id=[[2794.]]
# cell 349 written  epoch_id=[[2799.]]
# cell 350 written  epoch_id=[[2801.]]
# cell 351 written  epoch_id=[[2802.]]
# cell 352 written  epoch_id=[[2805.]]
# cell 353 written  epoch_id=[[2810.]]
# cell 354 written  epoch_id=[[2811.]]
# cell 355 written  epoch_id=[[2814.]]
# cell 356 written  epoch_id=[[2816.]]
# cell 357 written  epoch_id=[[2817.]]
# cell 358 written  epoch_id=[[2819.]]
# cell 359 written  epoch_id=[[2820.]]
# cell 360 written  epoch_id=[[2824.]]
# cell 361 written  epoch_id=[[2826.]]
# cell 362 written  epoch_id=[[2833.]]
# cell 363 written  epoch_id=[[2835.]]
# cell 364 written  epoch_id=[[2841.]]
# cell 365 written  epoch_id=[[2846.]]
# cell 366 written  epoch_id=[[2849.]]
# cell 367 written  epoch_id=[[2853.]]
# cell 368 written  epoch_id=[[2859.]]
# cell 369 written  epoch_id=[[2860.]]
# cell 370 written  epoch_id=[[2864.]]
# cell 371 written  epoch_id=[[2868.]]
# cell 372 written  epoch_id=[[2874.]]
# cell 373 written  epoch_id=[[2875.]]
# cell 374 written  epoch_id=[[2878.]]
# cell 375 written  epoch_id=[[2879.]]
# cell 376 written  epoch_id=[[2887.]]
# cell 377 written  epoch_id=[[2888.]]
# cell 378 written  epoch_id=[[2891.]]
# cell 379 written  epoch_id=[[2894.]]
# cell 380 written  epoch_id=[[2897.]]
# cell 381 written  epoch_id=[[2900.]]
# cell 382 written  epoch_id=[[2905.]]
# cell 383 written  epoch_id=[[2907.]]
# cell 384 written  epoch_id=[[2908.]]
# cell 385 written  epoch_id=[[2910.]]
# cell 386 written  epoch_id=[[2911.]]
# cell 387 written  epoch_id=[[2913.]]
# cell 388 written  epoch_id=[[2915.]]
# cell 389 written  epoch_id=[[2918.]]
# cell 390 written  epoch_id=[[2922.]]
# cell 391 written  epoch_id=[[2924.]]
# cell 392 written  epoch_id=[[2929.]]
# cell 393 written  epoch_id=[[2930.]]
# cell 394 written  epoch_id=[[2931.]]
# cell 395 written  epoch_id=[[2932.]]
# cell 396 written  epoch_id=[[2937.]]
# cell 397 written  epoch_id=[[2938.]]
# cell 398 written  epoch_id=[[2939.]]
# cell 399 written  epoch_id=[[2942.]]
# cell 400 written  epoch_id=[[2946.]]
# cell 401 written  epoch_id=[[2949.]]
# cell 402 written  epoch_id=[[2956.]]
# cell 403 written  epoch_id=[[2958.]]
# cell 404 written  epoch_id=[[2964.]]
# cell 405 written  epoch_id=[[2966.]]
# cell 406 written  epoch_id=[[2967.]]
# cell 407 written  epoch_id=[[2973.]]
# cell 408 written  epoch_id=[[2976.]]
# cell 409 written  epoch_id=[[2979.]]
# cell 410 written  epoch_id=[[2984.]]
# cell 411 written  epoch_id=[[2985.]]
# cell 412 written  epoch_id=[[2986.]]
# cell 413 written  epoch_id=[[2988.]]
# cell 414 written  epoch_id=[[2993.]]
# cell 415 written  epoch_id=[[2995.]]
# cell 416 written  epoch_id=[[2996.]]
# cell 417 written  epoch_id=[[2997.]]
# cell 418 written  epoch_id=[[2999.]]
# cell 419 written  epoch_id=[[3005.]]
# cell 420 written  epoch_id=[[3018.]]
# cell 421 written  epoch_id=[[3021.]]
# cell 422 written  epoch_id=[[3023.]]
# cell 423 written  epoch_id=[[3028.]]
# cell 424 written  epoch_id=[[3029.]]
# cell 425 written  epoch_id=[[3030.]]
# cell 426 written  epoch_id=[[3034.]]
# cell 427 written  epoch_id=[[3039.]]
# cell 428 written  epoch_id=[[3041.]]
# cell 429 written  epoch_id=[[3042.]]
# cell 430 written  epoch_id=[[3045.]]
# cell 431 written  epoch_id=[[3046.]]
# cell 432 written  epoch_id=[[3048.]]
# cell 433 written  epoch_id=[[3055.]]
# cell 434 written  epoch_id=[[3056.]]
# cell 435 written  epoch_id=[[3057.]]
# cell 436 written  epoch_id=[[3060.]]
# cell 437 written  epoch_id=[[3061.]]
# cell 438 written  epoch_id=[[3068.]]
# cell 439 written  epoch_id=[[3070.]]
# cell 440 written  epoch_id=[[3072.]]
# cell 441 written  epoch_id=[[3073.]]
# cell 442 written  epoch_id=[[3082.]]
# cell 443 written  epoch_id=[[3083.]]
# cell 444 written  epoch_id=[[3088.]]
# cell 445 written  epoch_id=[[3095.]]
# cell 446 written  epoch_id=[[3099.]]
# cell 447 written  epoch_id=[[3100.]]
# cell 448 written  epoch_id=[[3106.]]
# cell 449 written  epoch_id=[[3111.]]
# cell 450 written  epoch_id=[[3113.]]
# cell 451 written  epoch_id=[[3118.]]
# cell 452 written  epoch_id=[[3120.]]
# cell 453 written  epoch_id=[[3124.]]
# cell 454 written  epoch_id=[[3125.]]
# cell 455 written  epoch_id=[[3126.]]
# cell 456 written  epoch_id=[[3128.]]
# cell 457 written  epoch_id=[[3129.]]
# cell 458 written  epoch_id=[[3133.]]
# cell 459 written  epoch_id=[[3140.]]
# cell 460 written  epoch_id=[[3143.]]
# cell 461 written  epoch_id=[[3146.]]
# cell 462 written  epoch_id=[[3148.]]
# cell 463 written  epoch_id=[[3149.]]
# cell 464 written  epoch_id=[[3151.]]
# cell 465 written  epoch_id=[[3156.]]
# cell 466 written  epoch_id=[[3157.]]
# cell 467 written  epoch_id=[[3159.]]
# cell 468 written  epoch_id=[[3160.]]
# cell 469 written  epoch_id=[[3162.]]
# cell 470 written  epoch_id=[[3163.]]
# cell 471 written  epoch_id=[[3164.]]
# cell 472 written  epoch_id=[[3167.]]
# cell 473 written  epoch_id=[[3169.]]
# cell 474 written  epoch_id=[[3170.]]
# cell 475 written  epoch_id=[[3177.]]
# cell 476 written  epoch_id=[[3180.]]
# cell 477 written  epoch_id=[[3183.]]
# cell 478 written  epoch_id=[[3188.]]
# cell 479 written  epoch_id=[[3191.]]
# cell 480 written  epoch_id=[[3192.]]
# cell 481 written  epoch_id=[[3198.]]
# cell 482 written  epoch_id=[[3203.]]
# cell 483 written  epoch_id=[[3204.]]
# cell 484 written  epoch_id=[[3208.]]
# cell 485 written  epoch_id=[[3210.]]
# cell 486 written  epoch_id=[[3211.]]
# cell 487 written  epoch_id=[[3213.]]
# cell 488 written  epoch_id=[[3216.]]
# cell 489 written  epoch_id=[[3219.]]
# cell 490 written  epoch_id=[[3223.]]
# cell 491 written  epoch_id=[[3231.]]
# cell 492 written  epoch_id=[[3233.]]
# cell 493 written  epoch_id=[[3235.]]
# cell 494 written  epoch_id=[[3237.]]
# cell 495 written  epoch_id=[[3240.]]
# cell 496 written  epoch_id=[[3245.]]
# cell 497 written  epoch_id=[[3246.]]
# cell 498 written  epoch_id=[[3247.]]
# cell 499 written  epoch_id=[[3248.]]
# cell 500 written  epoch_id=[[3251.]]
# cell 501 written  epoch_id=[[3257.]]
# cell 502 written  epoch_id=[[3258.]]
# cell 503 written  epoch_id=[[3261.]]
# cell 504 written  epoch_id=[[3268.]]
# cell 505 written  epoch_id=[[3269.]]
# cell 506 written  epoch_id=[[3270.]]
# cell 507 written  epoch_id=[[3272.]]
# cell 508 written  epoch_id=[[3273.]]
# cell 509 written  epoch_id=[[3275.]]
# cell 510 written  epoch_id=[[3276.]]
# cell 511 written  epoch_id=[[3282.]]
# cell 512 written  epoch_id=[[3283.]]
# cell 513 written  epoch_id=[[3286.]]
# cell 514 written  epoch_id=[[3289.]]
# cell 515 written  epoch_id=[[3294.]]
# cell 516 written  epoch_id=[[3296.]]
# cell 517 written  epoch_id=[[3299.]]
# cell 518 written  epoch_id=[[3302.]]
# cell 519 written  epoch_id=[[3303.]]
# cell 520 written  epoch_id=[[3306.]]
# cell 521 written  epoch_id=[[3307.]]
# cell 522 written  epoch_id=[[3308.]]
# cell 523 written  epoch_id=[[3310.]]
# cell 524 written  epoch_id=[[3314.]]
# cell 525 written  epoch_id=[[3319.]]
# cell 526 written  epoch_id=[[3327.]]
# cell 527 written  epoch_id=[[3329.]]
# cell 528 written  epoch_id=[[3330.]]
# cell 529 written  epoch_id=[[3336.]]
# cell 530 written  epoch_id=[[3340.]]
# cell 531 written  epoch_id=[[3341.]]
# cell 532 written  epoch_id=[[3344.]]
# cell 533 written  epoch_id=[[3348.]]
# cell 534 written  epoch_id=[[3349.]]
# cell 535 written  epoch_id=[[3350.]]
# cell 536 written  epoch_id=[[3358.]]
# cell 537 written  epoch_id=[[3362.]]
# cell 538 written  epoch_id=[[3365.]]
# cell 539 written  epoch_id=[[3366.]]
# cell 540 written  epoch_id=[[3368.]]
# cell 541 written  epoch_id=[[3371.]]
# cell 542 written  epoch_id=[[3374.]]
# cell 543 written  epoch_id=[[3377.]]
# cell 544 written  epoch_id=[[3379.]]
# cell 545 written  epoch_id=[[3383.]]
# cell 546 written  epoch_id=[[3384.]]
# cell 547 written  epoch_id=[[3385.]]
# cell 548 written  epoch_id=[[3386.]]
# cell 549 written  epoch_id=[[3391.]]
# cell 550 written  epoch_id=[[3392.]]
# cell 551 written  epoch_id=[[3398.]]
# cell 552 written  epoch_id=[[3407.]]
# cell 553 written  epoch_id=[[3408.]]
# cell 554 written  epoch_id=[[3409.]]
# cell 555 written  epoch_id=[[3411.]]
# cell 556 written  epoch_id=[[3416.]]
# cell 557 written  epoch_id=[[3419.]]
# cell 558 written  epoch_id=[[3420.]]
# cell 559 written  epoch_id=[[3425.]]
# cell 560 written  epoch_id=[[3430.]]
# cell 561 written  epoch_id=[[3432.]]
# cell 562 written  epoch_id=[[3434.]]
# cell 563 written  epoch_id=[[3436.]]
# cell 564 written  epoch_id=[[3438.]]
# cell 565 written  epoch_id=[[3441.]]
# cell 566 written  epoch_id=[[3447.]]
# cell 567 written  epoch_id=[[3456.]]
# cell 568 written  epoch_id=[[3458.]]
# cell 569 written  epoch_id=[[3467.]]
# cell 570 written  epoch_id=[[3468.]]
# cell 571 written  epoch_id=[[3469.]]
# cell 572 written  epoch_id=[[3472.]]
# cell 573 written  epoch_id=[[3474.]]
# cell 574 written  epoch_id=[[3476.]]
# cell 575 written  epoch_id=[[3480.]]
# cell 576 written  epoch_id=[[3485.]]
# cell 577 written  epoch_id=[[3487.]]
# cell 578 written  epoch_id=[[3489.]]
# cell 579 written  epoch_id=[[3492.]]
# cell 580 written  epoch_id=[[3494.]]
# cell 581 written  epoch_id=[[3498.]]
# cell 582 written  epoch_id=[[3500.]]
# cell 583 written  epoch_id=[[3503.]]
# cell 584 written  epoch_id=[[3507.]]
# cell 585 written  epoch_id=[[3513.]]
# cell 586 written  epoch_id=[[3516.]]
# cell 587 written  epoch_id=[[3519.]]
# cell 588 written  epoch_id=[[3522.]]
# cell 589 written  epoch_id=[[3525.]]
# cell 590 written  epoch_id=[[3526.]]
# cell 591 written  epoch_id=[[3530.]]
# cell 592 written  epoch_id=[[3532.]]
# cell 593 written  epoch_id=[[3538.]]
# cell 594 written  epoch_id=[[3541.]]
# cell 595 written  epoch_id=[[3542.]]
# cell 596 written  epoch_id=[[3544.]]
# cell 597 written  epoch_id=[[3552.]]
# cell 598 written  epoch_id=[[3558.]]
# cell 599 written  epoch_id=[[3559.]]
# cell 600 written  epoch_id=[[3561.]]
# cell 601 written  epoch_id=[[3562.]]
# cell 602 written  epoch_id=[[3565.]]
# cell 603 written  epoch_id=[[3567.]]
# cell 604 written  epoch_id=[[3573.]]
# cell 605 written  epoch_id=[[3578.]]
# cell 606 written  epoch_id=[[3579.]]
# cell 607 written  epoch_id=[[3582.]]
# cell 608 written  epoch_id=[[3585.]]
# cell 609 written  epoch_id=[[3587.]]
# cell 610 written  epoch_id=[[3589.]]
# cell 611 written  epoch_id=[[3592.]]
# cell 612 written  epoch_id=[[3593.]]
# cell 613 written  epoch_id=[[3594.]]
# cell 614 written  epoch_id=[[3603.]]
# cell 615 written  epoch_id=[[3604.]]
# cell 616 written  epoch_id=[[3605.]]
# cell 617 written  epoch_id=[[3608.]]
# cell 618 written  epoch_id=[[3610.]]
# cell 619 written  epoch_id=[[3612.]]
# cell 620 written  epoch_id=[[3613.]]
# cell 621 written  epoch_id=[[3615.]]
# cell 622 written  epoch_id=[[3616.]]
# cell 623 written  epoch_id=[[3617.]]
# cell 624 written  epoch_id=[[3622.]]
# cell 625 written  epoch_id=[[3631.]]
# cell 626 written  epoch_id=[[3633.]]
# cell 627 written  epoch_id=[[3634.]]
# cell 628 written  epoch_id=[[3636.]]
# cell 629 written  epoch_id=[[3638.]]
# cell 630 written  epoch_id=[[3640.]]
# cell 631 written  epoch_id=[[3642.]]
# cell 632 written  epoch_id=[[3644.]]
# cell 633 written  epoch_id=[[3648.]]
# cell 634 written  epoch_id=[[3650.]]
# cell 635 written  epoch_id=[[3652.]]
# cell 636 written  epoch_id=[[3654.]]
# cell 637 written  epoch_id=[[3659.]]
# cell 638 written  epoch_id=[[3661.]]
# cell 639 written  epoch_id=[[3663.]]
# cell 640 written  epoch_id=[[3664.]]
# cell 641 written  epoch_id=[[3665.]]
# cell 642 written  epoch_id=[[3667.]]
# cell 643 written  epoch_id=[[3673.]]
# cell 644 written  epoch_id=[[3680.]]
# cell 645 written  epoch_id=[[3681.]]
# cell 646 written  epoch_id=[[3684.]]
# cell 647 written  epoch_id=[[3691.]]
# cell 648 written  epoch_id=[[3692.]]
# cell 649 written  epoch_id=[[3696.]]
# cell 650 written  epoch_id=[[3703.]]
# cell 651 written  epoch_id=[[3706.]]
# cell 652 written  epoch_id=[[3708.]]
# cell 653 written  epoch_id=[[3710.]]
# cell 654 written  epoch_id=[[3718.]]
# cell 655 written  epoch_id=[[3719.]]
# cell 656 written  epoch_id=[[3720.]]
# cell 657 written  epoch_id=[[3724.]]
# cell 658 written  epoch_id=[[3730.]]
# cell 659 written  epoch_id=[[3732.]]
# cell 660 written  epoch_id=[[3733.]]
# cell 661 written  epoch_id=[[3734.]]
# cell 662 written  epoch_id=[[3745.]]
# cell 663 written  epoch_id=[[3746.]]
# cell 664 written  epoch_id=[[3748.]]
# cell 665 written  epoch_id=[[3750.]]
# cell 666 written  epoch_id=[[3753.]]
# cell 667 written  epoch_id=[[3754.]]
# cell 668 written  epoch_id=[[3755.]]
# cell 669 written  epoch_id=[[3756.]]
# cell 670 written  epoch_id=[[3758.]]
# cell 671 written  epoch_id=[[3759.]]
# cell 672 written  epoch_id=[[3760.]]
# cell 673 written  epoch_id=[[3764.]]
# cell 674 written  epoch_id=[[3765.]]
# cell 675 written  epoch_id=[[3766.]]
# cell 676 written  epoch_id=[[3768.]]
# cell 677 written  epoch_id=[[3775.]]
# cell 678 written  epoch_id=[[3777.]]
# cell 679 written  epoch_id=[[3785.]]
# cell 680 written  epoch_id=[[3788.]]
# cell 681 written  epoch_id=[[3789.]]

# %%
n_cells   = trajx_f.shape[0] 
n_frames  = 93

dtype     = 'uint8'

with h5py.File('results/stimulic2_fV3.h5', 'w') as f:
    # 1) movie dataset  (chunk = one full movie for fast per‑cell IO)
    dset = f.create_dataset(
        'stimuli',
        shape      =(n_cells, n_frames, H, W),
        dtype      = 'uint8',
        chunks     =(1, n_frames, H, W),
        compression='gzip',
        shuffle    = True
    )
    # 2) epoch‑ID dataset  (1‑D uint64)
    f.create_dataset(
        'epoch_id',
        data       = np.asarray(epoch_id_f, dtype='uint16')
    )
    # 3) fill the movies, one cell at a time
    for i in range(n_cells):
        movie = sg.generate_stimuli(
            trajx_f[i], trajy_f[i],
            board_size = H-1,
            diameter   = 30,
            fps        = 60,
            pretime    = 0, tailtime = 0,
            type       ='natural',
            preframes  = 30, tailframes = 32, stimframes = 30
        )
        dset[i] = movie            # direct disk write → no RAM spike
        print(f'cell {i:3d} written  epoch_id={epoch_id_f[i]}')
# Out:
# cell   0 written  epoch_id=[[1750.]]
# cell   1 written  epoch_id=[[1755.]]
# cell   2 written  epoch_id=[[1760.]]
# cell   3 written  epoch_id=[[1761.]]
# cell   4 written  epoch_id=[[1763.]]
# cell   5 written  epoch_id=[[1767.]]
# cell   6 written  epoch_id=[[1768.]]
# cell   7 written  epoch_id=[[1775.]]
# cell   8 written  epoch_id=[[1778.]]
# cell   9 written  epoch_id=[[1782.]]
# cell  10 written  epoch_id=[[1783.]]
# cell  11 written  epoch_id=[[1784.]]
# cell  12 written  epoch_id=[[1787.]]
# cell  13 written  epoch_id=[[1790.]]
# cell  14 written  epoch_id=[[1791.]]
# cell  15 written  epoch_id=[[1792.]]
# cell  16 written  epoch_id=[[1793.]]
# cell  17 written  epoch_id=[[1798.]]
# cell  18 written  epoch_id=[[1799.]]
# cell  19 written  epoch_id=[[1802.]]
# cell  20 written  epoch_id=[[1806.]]
# cell  21 written  epoch_id=[[1808.]]
# cell  22 written  epoch_id=[[1814.]]
# cell  23 written  epoch_id=[[1815.]]
# cell  24 written  epoch_id=[[1817.]]
# cell  25 written  epoch_id=[[1820.]]
# cell  26 written  epoch_id=[[1822.]]
# cell  27 written  epoch_id=[[1823.]]
# cell  28 written  epoch_id=[[1824.]]
# cell  29 written  epoch_id=[[1828.]]
# cell  30 written  epoch_id=[[1833.]]
# cell  31 written  epoch_id=[[1835.]]
# cell  32 written  epoch_id=[[1843.]]
# cell  33 written  epoch_id=[[1851.]]
# cell  34 written  epoch_id=[[1860.]]
# cell  35 written  epoch_id=[[1863.]]
# cell  36 written  epoch_id=[[1867.]]
# cell  37 written  epoch_id=[[1868.]]
# cell  38 written  epoch_id=[[1871.]]
# cell  39 written  epoch_id=[[1878.]]
# cell  40 written  epoch_id=[[1879.]]
# cell  41 written  epoch_id=[[1882.]]
# cell  42 written  epoch_id=[[1884.]]
# cell  43 written  epoch_id=[[1888.]]
# cell  44 written  epoch_id=[[1889.]]
# cell  45 written  epoch_id=[[1893.]]
# cell  46 written  epoch_id=[[1897.]]
# cell  47 written  epoch_id=[[1901.]]
# cell  48 written  epoch_id=[[1903.]]
# cell  49 written  epoch_id=[[1906.]]
# cell  50 written  epoch_id=[[1910.]]
# cell  51 written  epoch_id=[[1911.]]
# cell  52 written  epoch_id=[[1913.]]
# cell  53 written  epoch_id=[[1917.]]
# cell  54 written  epoch_id=[[1923.]]
# cell  55 written  epoch_id=[[1924.]]
# cell  56 written  epoch_id=[[1926.]]
# cell  57 written  epoch_id=[[1927.]]
# cell  58 written  epoch_id=[[1929.]]
# cell  59 written  epoch_id=[[1930.]]
# cell  60 written  epoch_id=[[1933.]]
# cell  61 written  epoch_id=[[1935.]]
# cell  62 written  epoch_id=[[1941.]]
# cell  63 written  epoch_id=[[1942.]]
# cell  64 written  epoch_id=[[1943.]]
# cell  65 written  epoch_id=[[1944.]]
# cell  66 written  epoch_id=[[1945.]]
# cell  67 written  epoch_id=[[1947.]]
# cell  68 written  epoch_id=[[1949.]]
# cell  69 written  epoch_id=[[1955.]]
# cell  70 written  epoch_id=[[1961.]]
# cell  71 written  epoch_id=[[1962.]]
# cell  72 written  epoch_id=[[1964.]]
# cell  73 written  epoch_id=[[1965.]]
# cell  74 written  epoch_id=[[1966.]]
# cell  75 written  epoch_id=[[1968.]]
# cell  76 written  epoch_id=[[1971.]]
# cell  77 written  epoch_id=[[1973.]]
# cell  78 written  epoch_id=[[1977.]]
# cell  79 written  epoch_id=[[1978.]]
# cell  80 written  epoch_id=[[1979.]]
# cell  81 written  epoch_id=[[1984.]]
# cell  82 written  epoch_id=[[1987.]]
# cell  83 written  epoch_id=[[1988.]]
# cell  84 written  epoch_id=[[1992.]]
# cell  85 written  epoch_id=[[1996.]]
# cell  86 written  epoch_id=[[2004.]]
# cell  87 written  epoch_id=[[2007.]]
# cell  88 written  epoch_id=[[2009.]]
# cell  89 written  epoch_id=[[2010.]]
# cell  90 written  epoch_id=[[2011.]]
# cell  91 written  epoch_id=[[2022.]]
# cell  92 written  epoch_id=[[2027.]]
# cell  93 written  epoch_id=[[2033.]]
# cell  94 written  epoch_id=[[2041.]]
# cell  95 written  epoch_id=[[2047.]]
# cell  96 written  epoch_id=[[2049.]]
# cell  97 written  epoch_id=[[2051.]]
# cell  98 written  epoch_id=[[2054.]]
# cell  99 written  epoch_id=[[2055.]]
# cell 100 written  epoch_id=[[2058.]]
# cell 101 written  epoch_id=[[2061.]]
# cell 102 written  epoch_id=[[2068.]]
# cell 103 written  epoch_id=[[2075.]]
# cell 104 written  epoch_id=[[2077.]]
# cell 105 written  epoch_id=[[2078.]]
# cell 106 written  epoch_id=[[2093.]]
# cell 107 written  epoch_id=[[2096.]]
# cell 108 written  epoch_id=[[2097.]]
# cell 109 written  epoch_id=[[2101.]]
# cell 110 written  epoch_id=[[2109.]]
# cell 111 written  epoch_id=[[2112.]]
# cell 112 written  epoch_id=[[2113.]]
# cell 113 written  epoch_id=[[2120.]]
# cell 114 written  epoch_id=[[2124.]]
# cell 115 written  epoch_id=[[2125.]]
# cell 116 written  epoch_id=[[2129.]]
# cell 117 written  epoch_id=[[2130.]]
# cell 118 written  epoch_id=[[2131.]]
# cell 119 written  epoch_id=[[2132.]]
# cell 120 written  epoch_id=[[2135.]]
# cell 121 written  epoch_id=[[2137.]]
# cell 122 written  epoch_id=[[2138.]]
# cell 123 written  epoch_id=[[2140.]]
# cell 124 written  epoch_id=[[2142.]]
# cell 125 written  epoch_id=[[2144.]]
# cell 126 written  epoch_id=[[2146.]]
# cell 127 written  epoch_id=[[2147.]]
# cell 128 written  epoch_id=[[2148.]]
# cell 129 written  epoch_id=[[2149.]]
# cell 130 written  epoch_id=[[2150.]]
# cell 131 written  epoch_id=[[2154.]]
# cell 132 written  epoch_id=[[2157.]]
# cell 133 written  epoch_id=[[2158.]]
# cell 134 written  epoch_id=[[2160.]]
# cell 135 written  epoch_id=[[2161.]]
# cell 136 written  epoch_id=[[2163.]]
# cell 137 written  epoch_id=[[2164.]]
# cell 138 written  epoch_id=[[2165.]]
# cell 139 written  epoch_id=[[2168.]]
# cell 140 written  epoch_id=[[2170.]]
# cell 141 written  epoch_id=[[2176.]]
# cell 142 written  epoch_id=[[2177.]]
# cell 143 written  epoch_id=[[2179.]]
# cell 144 written  epoch_id=[[2182.]]
# cell 145 written  epoch_id=[[2186.]]
# cell 146 written  epoch_id=[[2187.]]
# cell 147 written  epoch_id=[[2190.]]
# cell 148 written  epoch_id=[[2192.]]
# cell 149 written  epoch_id=[[2193.]]
# cell 150 written  epoch_id=[[2194.]]
# cell 151 written  epoch_id=[[2200.]]
# cell 152 written  epoch_id=[[2201.]]
# cell 153 written  epoch_id=[[2203.]]
# cell 154 written  epoch_id=[[2205.]]
# cell 155 written  epoch_id=[[2206.]]
# cell 156 written  epoch_id=[[2209.]]
# cell 157 written  epoch_id=[[2211.]]
# cell 158 written  epoch_id=[[2217.]]
# cell 159 written  epoch_id=[[2218.]]
# cell 160 written  epoch_id=[[2222.]]
# cell 161 written  epoch_id=[[2232.]]
# cell 162 written  epoch_id=[[2235.]]
# cell 163 written  epoch_id=[[2241.]]
# cell 164 written  epoch_id=[[2242.]]
# cell 165 written  epoch_id=[[2243.]]
# cell 166 written  epoch_id=[[2245.]]
# cell 167 written  epoch_id=[[2246.]]
# cell 168 written  epoch_id=[[2247.]]
# cell 169 written  epoch_id=[[2249.]]
# cell 170 written  epoch_id=[[2250.]]
# cell 171 written  epoch_id=[[2255.]]
# cell 172 written  epoch_id=[[2258.]]
# cell 173 written  epoch_id=[[2259.]]
# cell 174 written  epoch_id=[[2260.]]
# cell 175 written  epoch_id=[[2262.]]
# cell 176 written  epoch_id=[[2268.]]
# cell 177 written  epoch_id=[[2269.]]
# cell 178 written  epoch_id=[[2270.]]
# cell 179 written  epoch_id=[[2271.]]
# cell 180 written  epoch_id=[[2272.]]
# cell 181 written  epoch_id=[[2274.]]
# cell 182 written  epoch_id=[[2275.]]
# cell 183 written  epoch_id=[[2281.]]
# cell 184 written  epoch_id=[[2285.]]
# cell 185 written  epoch_id=[[2287.]]
# cell 186 written  epoch_id=[[2288.]]
# cell 187 written  epoch_id=[[2290.]]
# cell 188 written  epoch_id=[[2292.]]
# cell 189 written  epoch_id=[[2295.]]
# cell 190 written  epoch_id=[[2298.]]
# cell 191 written  epoch_id=[[2310.]]
# cell 192 written  epoch_id=[[2313.]]
# cell 193 written  epoch_id=[[2319.]]
# cell 194 written  epoch_id=[[2321.]]
# cell 195 written  epoch_id=[[2326.]]
# cell 196 written  epoch_id=[[2333.]]
# cell 197 written  epoch_id=[[2340.]]
# cell 198 written  epoch_id=[[2343.]]
# cell 199 written  epoch_id=[[2349.]]
# cell 200 written  epoch_id=[[2353.]]
# cell 201 written  epoch_id=[[2356.]]
# cell 202 written  epoch_id=[[2357.]]
# cell 203 written  epoch_id=[[2362.]]
# cell 204 written  epoch_id=[[2366.]]
# cell 205 written  epoch_id=[[2368.]]
# cell 206 written  epoch_id=[[2370.]]
# cell 207 written  epoch_id=[[2374.]]
# cell 208 written  epoch_id=[[2377.]]
# cell 209 written  epoch_id=[[2379.]]
# cell 210 written  epoch_id=[[2381.]]
# cell 211 written  epoch_id=[[2383.]]
# cell 212 written  epoch_id=[[2385.]]
# cell 213 written  epoch_id=[[2393.]]
# cell 214 written  epoch_id=[[2394.]]
# cell 215 written  epoch_id=[[2398.]]
# cell 216 written  epoch_id=[[2399.]]
# cell 217 written  epoch_id=[[2400.]]
# cell 218 written  epoch_id=[[2401.]]
# cell 219 written  epoch_id=[[2403.]]
# cell 220 written  epoch_id=[[2411.]]
# cell 221 written  epoch_id=[[2412.]]
# cell 222 written  epoch_id=[[2418.]]
# cell 223 written  epoch_id=[[2419.]]
# cell 224 written  epoch_id=[[2420.]]
# cell 225 written  epoch_id=[[2424.]]
# cell 226 written  epoch_id=[[2425.]]
# cell 227 written  epoch_id=[[2426.]]
# cell 228 written  epoch_id=[[2431.]]
# cell 229 written  epoch_id=[[2434.]]
# cell 230 written  epoch_id=[[2437.]]
# cell 231 written  epoch_id=[[2438.]]
# cell 232 written  epoch_id=[[2440.]]
# cell 233 written  epoch_id=[[2443.]]
# cell 234 written  epoch_id=[[2446.]]
# cell 235 written  epoch_id=[[2451.]]
# cell 236 written  epoch_id=[[2452.]]
# cell 237 written  epoch_id=[[2453.]]
# cell 238 written  epoch_id=[[2455.]]
# cell 239 written  epoch_id=[[2458.]]
# cell 240 written  epoch_id=[[2459.]]
# cell 241 written  epoch_id=[[2462.]]
# cell 242 written  epoch_id=[[2464.]]
# cell 243 written  epoch_id=[[2469.]]
# cell 244 written  epoch_id=[[2471.]]
# cell 245 written  epoch_id=[[2472.]]
# cell 246 written  epoch_id=[[2473.]]
# cell 247 written  epoch_id=[[2477.]]
# cell 248 written  epoch_id=[[2481.]]
# cell 249 written  epoch_id=[[2483.]]
# cell 250 written  epoch_id=[[2489.]]
# cell 251 written  epoch_id=[[2492.]]
# cell 252 written  epoch_id=[[2496.]]
# cell 253 written  epoch_id=[[2497.]]
# cell 254 written  epoch_id=[[2501.]]
# cell 255 written  epoch_id=[[2504.]]
# cell 256 written  epoch_id=[[2505.]]
# cell 257 written  epoch_id=[[2514.]]
# cell 258 written  epoch_id=[[2521.]]
# cell 259 written  epoch_id=[[2526.]]
# cell 260 written  epoch_id=[[2530.]]
# cell 261 written  epoch_id=[[2534.]]
# cell 262 written  epoch_id=[[2536.]]
# cell 263 written  epoch_id=[[2539.]]
# cell 264 written  epoch_id=[[2542.]]
# cell 265 written  epoch_id=[[2548.]]
# cell 266 written  epoch_id=[[2550.]]
# cell 267 written  epoch_id=[[2551.]]
# cell 268 written  epoch_id=[[2557.]]
# cell 269 written  epoch_id=[[2560.]]
# cell 270 written  epoch_id=[[2565.]]
# cell 271 written  epoch_id=[[2566.]]
# cell 272 written  epoch_id=[[2568.]]
# cell 273 written  epoch_id=[[2572.]]
# cell 274 written  epoch_id=[[2582.]]
# cell 275 written  epoch_id=[[2585.]]
# cell 276 written  epoch_id=[[2586.]]
# cell 277 written  epoch_id=[[2587.]]
# cell 278 written  epoch_id=[[2588.]]
# cell 279 written  epoch_id=[[2589.]]
# cell 280 written  epoch_id=[[2590.]]
# cell 281 written  epoch_id=[[2591.]]
# cell 282 written  epoch_id=[[2595.]]
# cell 283 written  epoch_id=[[2597.]]
# cell 284 written  epoch_id=[[2598.]]
# cell 285 written  epoch_id=[[2599.]]
# cell 286 written  epoch_id=[[2600.]]
# cell 287 written  epoch_id=[[2605.]]
# cell 288 written  epoch_id=[[2606.]]
# cell 289 written  epoch_id=[[2607.]]
# cell 290 written  epoch_id=[[2608.]]
# cell 291 written  epoch_id=[[2613.]]
# cell 292 written  epoch_id=[[2617.]]
# cell 293 written  epoch_id=[[2618.]]
# cell 294 written  epoch_id=[[2621.]]
# cell 295 written  epoch_id=[[2625.]]
# cell 296 written  epoch_id=[[2631.]]
# cell 297 written  epoch_id=[[2633.]]
# cell 298 written  epoch_id=[[2639.]]
# cell 299 written  epoch_id=[[2641.]]
# cell 300 written  epoch_id=[[2649.]]
# cell 301 written  epoch_id=[[2650.]]
# cell 302 written  epoch_id=[[2655.]]
# cell 303 written  epoch_id=[[2656.]]
# cell 304 written  epoch_id=[[2658.]]
# cell 305 written  epoch_id=[[2659.]]
# cell 306 written  epoch_id=[[2666.]]
# cell 307 written  epoch_id=[[2667.]]
# cell 308 written  epoch_id=[[2668.]]
# cell 309 written  epoch_id=[[2671.]]
# cell 310 written  epoch_id=[[2676.]]
# cell 311 written  epoch_id=[[2678.]]
# cell 312 written  epoch_id=[[2681.]]
# cell 313 written  epoch_id=[[2684.]]
# cell 314 written  epoch_id=[[2685.]]
# cell 315 written  epoch_id=[[2687.]]
# cell 316 written  epoch_id=[[2690.]]
# cell 317 written  epoch_id=[[2693.]]
# cell 318 written  epoch_id=[[2703.]]
# cell 319 written  epoch_id=[[2704.]]
# cell 320 written  epoch_id=[[2713.]]
# cell 321 written  epoch_id=[[2717.]]
# cell 322 written  epoch_id=[[2719.]]
# cell 323 written  epoch_id=[[2720.]]
# cell 324 written  epoch_id=[[2721.]]
# cell 325 written  epoch_id=[[2725.]]
# cell 326 written  epoch_id=[[2732.]]
# cell 327 written  epoch_id=[[2734.]]
# cell 328 written  epoch_id=[[2736.]]
# cell 329 written  epoch_id=[[2743.]]
# cell 330 written  epoch_id=[[2745.]]
# cell 331 written  epoch_id=[[2746.]]
# cell 332 written  epoch_id=[[2751.]]
# cell 333 written  epoch_id=[[2752.]]
# cell 334 written  epoch_id=[[2756.]]
# cell 335 written  epoch_id=[[2759.]]
# cell 336 written  epoch_id=[[2760.]]
# cell 337 written  epoch_id=[[2762.]]
# cell 338 written  epoch_id=[[2763.]]
# cell 339 written  epoch_id=[[2764.]]
# cell 340 written  epoch_id=[[2765.]]
# cell 341 written  epoch_id=[[2769.]]
# cell 342 written  epoch_id=[[2771.]]
# cell 343 written  epoch_id=[[2783.]]
# cell 344 written  epoch_id=[[2784.]]
# cell 345 written  epoch_id=[[2785.]]
# cell 346 written  epoch_id=[[2787.]]
# cell 347 written  epoch_id=[[2792.]]
# cell 348 written  epoch_id=[[2793.]]
# cell 349 written  epoch_id=[[2795.]]
# cell 350 written  epoch_id=[[2800.]]
# cell 351 written  epoch_id=[[2804.]]
# cell 352 written  epoch_id=[[2806.]]
# cell 353 written  epoch_id=[[2807.]]
# cell 354 written  epoch_id=[[2809.]]
# cell 355 written  epoch_id=[[2812.]]
# cell 356 written  epoch_id=[[2813.]]
# cell 357 written  epoch_id=[[2823.]]
# cell 358 written  epoch_id=[[2825.]]
# cell 359 written  epoch_id=[[2827.]]
# cell 360 written  epoch_id=[[2828.]]
# cell 361 written  epoch_id=[[2829.]]
# cell 362 written  epoch_id=[[2832.]]
# cell 363 written  epoch_id=[[2836.]]
# cell 364 written  epoch_id=[[2837.]]
# cell 365 written  epoch_id=[[2840.]]
# cell 366 written  epoch_id=[[2842.]]
# cell 367 written  epoch_id=[[2844.]]
# cell 368 written  epoch_id=[[2845.]]
# cell 369 written  epoch_id=[[2850.]]
# cell 370 written  epoch_id=[[2852.]]
# cell 371 written  epoch_id=[[2855.]]
# cell 372 written  epoch_id=[[2857.]]
# cell 373 written  epoch_id=[[2858.]]
# cell 374 written  epoch_id=[[2863.]]
# cell 375 written  epoch_id=[[2866.]]
# cell 376 written  epoch_id=[[2871.]]
# cell 377 written  epoch_id=[[2873.]]
# cell 378 written  epoch_id=[[2876.]]
# cell 379 written  epoch_id=[[2880.]]
# cell 380 written  epoch_id=[[2882.]]
# cell 381 written  epoch_id=[[2883.]]
# cell 382 written  epoch_id=[[2885.]]
# cell 383 written  epoch_id=[[2886.]]
# cell 384 written  epoch_id=[[2892.]]
# cell 385 written  epoch_id=[[2896.]]
# cell 386 written  epoch_id=[[2901.]]
# cell 387 written  epoch_id=[[2902.]]
# cell 388 written  epoch_id=[[2904.]]
# cell 389 written  epoch_id=[[2909.]]
# cell 390 written  epoch_id=[[2917.]]
# cell 391 written  epoch_id=[[2920.]]
# cell 392 written  epoch_id=[[2927.]]
# cell 393 written  epoch_id=[[2928.]]
# cell 394 written  epoch_id=[[2933.]]
# cell 395 written  epoch_id=[[2934.]]
# cell 396 written  epoch_id=[[2940.]]
# cell 397 written  epoch_id=[[2943.]]
# cell 398 written  epoch_id=[[2947.]]
# cell 399 written  epoch_id=[[2950.]]
# cell 400 written  epoch_id=[[2952.]]
# cell 401 written  epoch_id=[[2954.]]
# cell 402 written  epoch_id=[[2957.]]
# cell 403 written  epoch_id=[[2959.]]
# cell 404 written  epoch_id=[[2960.]]
# cell 405 written  epoch_id=[[2963.]]
# cell 406 written  epoch_id=[[2965.]]
# cell 407 written  epoch_id=[[2968.]]
# cell 408 written  epoch_id=[[2969.]]
# cell 409 written  epoch_id=[[2970.]]
# cell 410 written  epoch_id=[[2978.]]
# cell 411 written  epoch_id=[[2980.]]
# cell 412 written  epoch_id=[[2981.]]
# cell 413 written  epoch_id=[[2982.]]
# cell 414 written  epoch_id=[[2987.]]
# cell 415 written  epoch_id=[[2998.]]
# cell 416 written  epoch_id=[[3003.]]
# cell 417 written  epoch_id=[[3004.]]
# cell 418 written  epoch_id=[[3007.]]
# cell 419 written  epoch_id=[[3009.]]
# cell 420 written  epoch_id=[[3012.]]
# cell 421 written  epoch_id=[[3016.]]
# cell 422 written  epoch_id=[[3017.]]
# cell 423 written  epoch_id=[[3019.]]
# cell 424 written  epoch_id=[[3020.]]
# cell 425 written  epoch_id=[[3024.]]
# cell 426 written  epoch_id=[[3025.]]
# cell 427 written  epoch_id=[[3026.]]
# cell 428 written  epoch_id=[[3031.]]
# cell 429 written  epoch_id=[[3032.]]
# cell 430 written  epoch_id=[[3033.]]
# cell 431 written  epoch_id=[[3035.]]
# cell 432 written  epoch_id=[[3037.]]
# cell 433 written  epoch_id=[[3038.]]
# cell 434 written  epoch_id=[[3044.]]
# cell 435 written  epoch_id=[[3047.]]
# cell 436 written  epoch_id=[[3049.]]
# cell 437 written  epoch_id=[[3050.]]
# cell 438 written  epoch_id=[[3051.]]
# cell 439 written  epoch_id=[[3053.]]
# cell 440 written  epoch_id=[[3054.]]
# cell 441 written  epoch_id=[[3059.]]
# cell 442 written  epoch_id=[[3063.]]
# cell 443 written  epoch_id=[[3064.]]
# cell 444 written  epoch_id=[[3066.]]
# cell 445 written  epoch_id=[[3069.]]
# cell 446 written  epoch_id=[[3076.]]
# cell 447 written  epoch_id=[[3078.]]
# cell 448 written  epoch_id=[[3079.]]
# cell 449 written  epoch_id=[[3081.]]
# cell 450 written  epoch_id=[[3084.]]
# cell 451 written  epoch_id=[[3087.]]
# cell 452 written  epoch_id=[[3089.]]
# cell 453 written  epoch_id=[[3091.]]
# cell 454 written  epoch_id=[[3094.]]
# cell 455 written  epoch_id=[[3101.]]
# cell 456 written  epoch_id=[[3102.]]
# cell 457 written  epoch_id=[[3108.]]
# cell 458 written  epoch_id=[[3109.]]
# cell 459 written  epoch_id=[[3114.]]
# cell 460 written  epoch_id=[[3115.]]
# cell 461 written  epoch_id=[[3116.]]
# cell 462 written  epoch_id=[[3117.]]
# cell 463 written  epoch_id=[[3119.]]
# cell 464 written  epoch_id=[[3132.]]
# cell 465 written  epoch_id=[[3134.]]
# cell 466 written  epoch_id=[[3135.]]
# cell 467 written  epoch_id=[[3136.]]
# cell 468 written  epoch_id=[[3137.]]
# cell 469 written  epoch_id=[[3138.]]
# cell 470 written  epoch_id=[[3141.]]
# cell 471 written  epoch_id=[[3142.]]
# cell 472 written  epoch_id=[[3150.]]
# cell 473 written  epoch_id=[[3155.]]
# cell 474 written  epoch_id=[[3161.]]
# cell 475 written  epoch_id=[[3166.]]
# cell 476 written  epoch_id=[[3173.]]
# cell 477 written  epoch_id=[[3175.]]
# cell 478 written  epoch_id=[[3178.]]
# cell 479 written  epoch_id=[[3182.]]
# cell 480 written  epoch_id=[[3186.]]
# cell 481 written  epoch_id=[[3187.]]
# cell 482 written  epoch_id=[[3189.]]
# cell 483 written  epoch_id=[[3199.]]
# cell 484 written  epoch_id=[[3201.]]
# cell 485 written  epoch_id=[[3202.]]
# cell 486 written  epoch_id=[[3207.]]
# cell 487 written  epoch_id=[[3212.]]
# cell 488 written  epoch_id=[[3215.]]
# cell 489 written  epoch_id=[[3217.]]
# cell 490 written  epoch_id=[[3220.]]
# cell 491 written  epoch_id=[[3222.]]
# cell 492 written  epoch_id=[[3224.]]
# cell 493 written  epoch_id=[[3225.]]
# cell 494 written  epoch_id=[[3227.]]
# cell 495 written  epoch_id=[[3229.]]
# cell 496 written  epoch_id=[[3232.]]
# cell 497 written  epoch_id=[[3234.]]
# cell 498 written  epoch_id=[[3236.]]
# cell 499 written  epoch_id=[[3241.]]
# cell 500 written  epoch_id=[[3242.]]
# cell 501 written  epoch_id=[[3249.]]
# cell 502 written  epoch_id=[[3252.]]
# cell 503 written  epoch_id=[[3254.]]
# cell 504 written  epoch_id=[[3259.]]
# cell 505 written  epoch_id=[[3263.]]
# cell 506 written  epoch_id=[[3264.]]
# cell 507 written  epoch_id=[[3267.]]
# cell 508 written  epoch_id=[[3271.]]
# cell 509 written  epoch_id=[[3274.]]
# cell 510 written  epoch_id=[[3277.]]
# cell 511 written  epoch_id=[[3278.]]
# cell 512 written  epoch_id=[[3281.]]
# cell 513 written  epoch_id=[[3284.]]
# cell 514 written  epoch_id=[[3288.]]
# cell 515 written  epoch_id=[[3291.]]
# cell 516 written  epoch_id=[[3293.]]
# cell 517 written  epoch_id=[[3298.]]
# cell 518 written  epoch_id=[[3300.]]
# cell 519 written  epoch_id=[[3304.]]
# cell 520 written  epoch_id=[[3305.]]
# cell 521 written  epoch_id=[[3313.]]
# cell 522 written  epoch_id=[[3315.]]
# cell 523 written  epoch_id=[[3318.]]
# cell 524 written  epoch_id=[[3320.]]
# cell 525 written  epoch_id=[[3321.]]
# cell 526 written  epoch_id=[[3324.]]
# cell 527 written  epoch_id=[[3328.]]
# cell 528 written  epoch_id=[[3332.]]
# cell 529 written  epoch_id=[[3333.]]
# cell 530 written  epoch_id=[[3338.]]
# cell 531 written  epoch_id=[[3339.]]
# cell 532 written  epoch_id=[[3342.]]
# cell 533 written  epoch_id=[[3345.]]
# cell 534 written  epoch_id=[[3353.]]
# cell 535 written  epoch_id=[[3359.]]
# cell 536 written  epoch_id=[[3363.]]
# cell 537 written  epoch_id=[[3364.]]
# cell 538 written  epoch_id=[[3367.]]
# cell 539 written  epoch_id=[[3372.]]
# cell 540 written  epoch_id=[[3373.]]
# cell 541 written  epoch_id=[[3378.]]
# cell 542 written  epoch_id=[[3380.]]
# cell 543 written  epoch_id=[[3387.]]
# cell 544 written  epoch_id=[[3393.]]
# cell 545 written  epoch_id=[[3396.]]
# cell 546 written  epoch_id=[[3397.]]
# cell 547 written  epoch_id=[[3399.]]
# cell 548 written  epoch_id=[[3400.]]
# cell 549 written  epoch_id=[[3403.]]
# cell 550 written  epoch_id=[[3405.]]
# cell 551 written  epoch_id=[[3406.]]
# cell 552 written  epoch_id=[[3410.]]
# cell 553 written  epoch_id=[[3414.]]
# cell 554 written  epoch_id=[[3417.]]
# cell 555 written  epoch_id=[[3422.]]
# cell 556 written  epoch_id=[[3423.]]
# cell 557 written  epoch_id=[[3426.]]
# cell 558 written  epoch_id=[[3427.]]
# cell 559 written  epoch_id=[[3428.]]
# cell 560 written  epoch_id=[[3433.]]
# cell 561 written  epoch_id=[[3435.]]
# cell 562 written  epoch_id=[[3439.]]
# cell 563 written  epoch_id=[[3440.]]
# cell 564 written  epoch_id=[[3443.]]
# cell 565 written  epoch_id=[[3446.]]
# cell 566 written  epoch_id=[[3450.]]
# cell 567 written  epoch_id=[[3451.]]
# cell 568 written  epoch_id=[[3452.]]
# cell 569 written  epoch_id=[[3453.]]
# cell 570 written  epoch_id=[[3455.]]
# cell 571 written  epoch_id=[[3459.]]
# cell 572 written  epoch_id=[[3461.]]
# cell 573 written  epoch_id=[[3462.]]
# cell 574 written  epoch_id=[[3465.]]
# cell 575 written  epoch_id=[[3470.]]
# cell 576 written  epoch_id=[[3471.]]
# cell 577 written  epoch_id=[[3473.]]
# cell 578 written  epoch_id=[[3477.]]
# cell 579 written  epoch_id=[[3479.]]
# cell 580 written  epoch_id=[[3488.]]
# cell 581 written  epoch_id=[[3490.]]
# cell 582 written  epoch_id=[[3491.]]
# cell 583 written  epoch_id=[[3493.]]
# cell 584 written  epoch_id=[[3495.]]
# cell 585 written  epoch_id=[[3497.]]
# cell 586 written  epoch_id=[[3501.]]
# cell 587 written  epoch_id=[[3502.]]
# cell 588 written  epoch_id=[[3506.]]
# cell 589 written  epoch_id=[[3508.]]
# cell 590 written  epoch_id=[[3510.]]
# cell 591 written  epoch_id=[[3512.]]
# cell 592 written  epoch_id=[[3518.]]
# cell 593 written  epoch_id=[[3521.]]
# cell 594 written  epoch_id=[[3523.]]
# cell 595 written  epoch_id=[[3527.]]
# cell 596 written  epoch_id=[[3529.]]
# cell 597 written  epoch_id=[[3531.]]
# cell 598 written  epoch_id=[[3534.]]
# cell 599 written  epoch_id=[[3537.]]
# cell 600 written  epoch_id=[[3540.]]
# cell 601 written  epoch_id=[[3546.]]
# cell 602 written  epoch_id=[[3548.]]
# cell 603 written  epoch_id=[[3550.]]
# cell 604 written  epoch_id=[[3551.]]
# cell 605 written  epoch_id=[[3554.]]
# cell 606 written  epoch_id=[[3555.]]
# cell 607 written  epoch_id=[[3557.]]
# cell 608 written  epoch_id=[[3563.]]
# cell 609 written  epoch_id=[[3568.]]
# cell 610 written  epoch_id=[[3569.]]
# cell 611 written  epoch_id=[[3570.]]
# cell 612 written  epoch_id=[[3576.]]
# cell 613 written  epoch_id=[[3577.]]
# cell 614 written  epoch_id=[[3581.]]
# cell 615 written  epoch_id=[[3583.]]
# cell 616 written  epoch_id=[[3588.]]
# cell 617 written  epoch_id=[[3590.]]
# cell 618 written  epoch_id=[[3599.]]
# cell 619 written  epoch_id=[[3600.]]
# cell 620 written  epoch_id=[[3602.]]
# cell 621 written  epoch_id=[[3609.]]
# cell 622 written  epoch_id=[[3611.]]
# cell 623 written  epoch_id=[[3614.]]
# cell 624 written  epoch_id=[[3619.]]
# cell 625 written  epoch_id=[[3623.]]
# cell 626 written  epoch_id=[[3624.]]
# cell 627 written  epoch_id=[[3629.]]
# cell 628 written  epoch_id=[[3632.]]
# cell 629 written  epoch_id=[[3637.]]
# cell 630 written  epoch_id=[[3643.]]
# cell 631 written  epoch_id=[[3646.]]
# cell 632 written  epoch_id=[[3647.]]
# cell 633 written  epoch_id=[[3649.]]
# cell 634 written  epoch_id=[[3655.]]
# cell 635 written  epoch_id=[[3657.]]
# cell 636 written  epoch_id=[[3660.]]
# cell 637 written  epoch_id=[[3666.]]
# cell 638 written  epoch_id=[[3668.]]
# cell 639 written  epoch_id=[[3669.]]
# cell 640 written  epoch_id=[[3671.]]
# cell 641 written  epoch_id=[[3674.]]
# cell 642 written  epoch_id=[[3677.]]
# cell 643 written  epoch_id=[[3678.]]
# cell 644 written  epoch_id=[[3682.]]
# cell 645 written  epoch_id=[[3683.]]
# cell 646 written  epoch_id=[[3685.]]
# cell 647 written  epoch_id=[[3686.]]
# cell 648 written  epoch_id=[[3688.]]
# cell 649 written  epoch_id=[[3689.]]
# cell 650 written  epoch_id=[[3690.]]
# cell 651 written  epoch_id=[[3693.]]
# cell 652 written  epoch_id=[[3694.]]
# cell 653 written  epoch_id=[[3695.]]
# cell 654 written  epoch_id=[[3697.]]
# cell 655 written  epoch_id=[[3699.]]
# cell 656 written  epoch_id=[[3700.]]
# cell 657 written  epoch_id=[[3701.]]
# cell 658 written  epoch_id=[[3702.]]
# cell 659 written  epoch_id=[[3704.]]
# cell 660 written  epoch_id=[[3714.]]
# cell 661 written  epoch_id=[[3715.]]
# cell 662 written  epoch_id=[[3716.]]
# cell 663 written  epoch_id=[[3721.]]
# cell 664 written  epoch_id=[[3723.]]
# cell 665 written  epoch_id=[[3728.]]
# cell 666 written  epoch_id=[[3729.]]
# cell 667 written  epoch_id=[[3738.]]
# cell 668 written  epoch_id=[[3739.]]
# cell 669 written  epoch_id=[[3742.]]
# cell 670 written  epoch_id=[[3747.]]
# cell 671 written  epoch_id=[[3749.]]
# cell 672 written  epoch_id=[[3751.]]
# cell 673 written  epoch_id=[[3757.]]
# cell 674 written  epoch_id=[[3761.]]
# cell 675 written  epoch_id=[[3767.]]
# cell 676 written  epoch_id=[[3770.]]
# cell 677 written  epoch_id=[[3774.]]
# cell 678 written  epoch_id=[[3776.]]
# cell 679 written  epoch_id=[[3779.]]
# cell 680 written  epoch_id=[[3781.]]
# cell 681 written  epoch_id=[[3782.]]
# cell 682 written  epoch_id=[[3784.]]
# cell 683 written  epoch_id=[[3787.]]
# cell 684 written  epoch_id=[[3794.]]

# %%
n_cells   = trajx_n.shape[0] 
n_frames  = 93

dtype     = 'uint8'

with h5py.File('results/stimulic2_nV3.h5', 'w') as f:
    # 1) movie dataset  (chunk = one full movie for fast per‑cell IO)
    dset = f.create_dataset(
        'stimuli',
        shape      =(n_cells, n_frames, H, W),
        dtype      = 'uint8',
        chunks     =(1, n_frames, H, W),
        compression='gzip',
        shuffle    = True
    )
    # 2) epoch‑ID dataset  (1‑D uint64)
    f.create_dataset(
        'epoch_id',
        data       = np.asarray(epoch_id_n, dtype='uint16')
    )

    # 3) fill the movies, one cell at a time
    for i in range(n_cells):
        movie = sg.generate_stimuli(
            trajx_n[i], trajy_n[i],
            board_size = H-1,
            diameter   = 30,
            fps        = 60,
            pretime    = 0, tailtime = 0,
            type       ='natural',
            preframes  = 30, tailframes = 32, stimframes = 30
        )
        dset[i] = movie            # direct disk write → no RAM spike
        print(f'cell {i:3d} written  epoch_id={epoch_id_n[i]}')
# Out:
# cell   0 written  epoch_id=[[1752.]]
# cell   1 written  epoch_id=[[1753.]]
# cell   2 written  epoch_id=[[1756.]]
# cell   3 written  epoch_id=[[1757.]]
# cell   4 written  epoch_id=[[1766.]]
# cell   5 written  epoch_id=[[1769.]]
# cell   6 written  epoch_id=[[1771.]]
# cell   7 written  epoch_id=[[1772.]]
# cell   8 written  epoch_id=[[1774.]]
# cell   9 written  epoch_id=[[1781.]]
# cell  10 written  epoch_id=[[1785.]]
# cell  11 written  epoch_id=[[1788.]]
# cell  12 written  epoch_id=[[1789.]]
# cell  13 written  epoch_id=[[1794.]]
# cell  14 written  epoch_id=[[1795.]]
# cell  15 written  epoch_id=[[1796.]]
# cell  16 written  epoch_id=[[1800.]]
# cell  17 written  epoch_id=[[1801.]]
# cell  18 written  epoch_id=[[1807.]]
# cell  19 written  epoch_id=[[1812.]]
# cell  20 written  epoch_id=[[1816.]]
# cell  21 written  epoch_id=[[1819.]]
# cell  22 written  epoch_id=[[1826.]]
# cell  23 written  epoch_id=[[1830.]]
# cell  24 written  epoch_id=[[1832.]]
# cell  25 written  epoch_id=[[1834.]]
# cell  26 written  epoch_id=[[1836.]]
# cell  27 written  epoch_id=[[1840.]]
# cell  28 written  epoch_id=[[1841.]]
# cell  29 written  epoch_id=[[1845.]]
# cell  30 written  epoch_id=[[1846.]]
# cell  31 written  epoch_id=[[1848.]]
# cell  32 written  epoch_id=[[1850.]]
# cell  33 written  epoch_id=[[1853.]]
# cell  34 written  epoch_id=[[1854.]]
# cell  35 written  epoch_id=[[1857.]]
# cell  36 written  epoch_id=[[1858.]]
# cell  37 written  epoch_id=[[1859.]]
# cell  38 written  epoch_id=[[1864.]]
# cell  39 written  epoch_id=[[1865.]]
# cell  40 written  epoch_id=[[1866.]]
# cell  41 written  epoch_id=[[1869.]]
# cell  42 written  epoch_id=[[1873.]]
# cell  43 written  epoch_id=[[1876.]]
# cell  44 written  epoch_id=[[1877.]]
# cell  45 written  epoch_id=[[1883.]]
# cell  46 written  epoch_id=[[1886.]]
# cell  47 written  epoch_id=[[1887.]]
# cell  48 written  epoch_id=[[1890.]]
# cell  49 written  epoch_id=[[1891.]]
# cell  50 written  epoch_id=[[1892.]]
# cell  51 written  epoch_id=[[1894.]]
# cell  52 written  epoch_id=[[1895.]]
# cell  53 written  epoch_id=[[1896.]]
# cell  54 written  epoch_id=[[1904.]]
# cell  55 written  epoch_id=[[1905.]]
# cell  56 written  epoch_id=[[1908.]]
# cell  57 written  epoch_id=[[1915.]]
# cell  58 written  epoch_id=[[1916.]]
# cell  59 written  epoch_id=[[1919.]]
# cell  60 written  epoch_id=[[1931.]]
# cell  61 written  epoch_id=[[1936.]]
# cell  62 written  epoch_id=[[1938.]]
# cell  63 written  epoch_id=[[1939.]]
# cell  64 written  epoch_id=[[1950.]]
# cell  65 written  epoch_id=[[1951.]]
# cell  66 written  epoch_id=[[1953.]]
# cell  67 written  epoch_id=[[1956.]]
# cell  68 written  epoch_id=[[1958.]]
# cell  69 written  epoch_id=[[1959.]]
# cell  70 written  epoch_id=[[1967.]]
# cell  71 written  epoch_id=[[1970.]]
# cell  72 written  epoch_id=[[1975.]]
# cell  73 written  epoch_id=[[1982.]]
# cell  74 written  epoch_id=[[1986.]]
# cell  75 written  epoch_id=[[1989.]]
# cell  76 written  epoch_id=[[1990.]]
# cell  77 written  epoch_id=[[1995.]]
# cell  78 written  epoch_id=[[1997.]]
# cell  79 written  epoch_id=[[2000.]]
# cell  80 written  epoch_id=[[2003.]]
# cell  81 written  epoch_id=[[2005.]]
# cell  82 written  epoch_id=[[2006.]]
# cell  83 written  epoch_id=[[2008.]]
# cell  84 written  epoch_id=[[2016.]]
# cell  85 written  epoch_id=[[2017.]]
# cell  86 written  epoch_id=[[2018.]]
# cell  87 written  epoch_id=[[2019.]]
# cell  88 written  epoch_id=[[2020.]]
# cell  89 written  epoch_id=[[2023.]]
# cell  90 written  epoch_id=[[2025.]]
# cell  91 written  epoch_id=[[2029.]]
# cell  92 written  epoch_id=[[2031.]]
# cell  93 written  epoch_id=[[2032.]]
# cell  94 written  epoch_id=[[2034.]]
# cell  95 written  epoch_id=[[2035.]]
# cell  96 written  epoch_id=[[2036.]]
# cell  97 written  epoch_id=[[2039.]]
# cell  98 written  epoch_id=[[2040.]]
# cell  99 written  epoch_id=[[2042.]]
# cell 100 written  epoch_id=[[2044.]]
# cell 101 written  epoch_id=[[2046.]]
# cell 102 written  epoch_id=[[2052.]]
# cell 103 written  epoch_id=[[2056.]]
# cell 104 written  epoch_id=[[2060.]]
# cell 105 written  epoch_id=[[2064.]]
# cell 106 written  epoch_id=[[2069.]]
# cell 107 written  epoch_id=[[2071.]]
# cell 108 written  epoch_id=[[2072.]]
# cell 109 written  epoch_id=[[2074.]]
# cell 110 written  epoch_id=[[2079.]]
# cell 111 written  epoch_id=[[2083.]]
# cell 112 written  epoch_id=[[2084.]]
# cell 113 written  epoch_id=[[2085.]]
# cell 114 written  epoch_id=[[2088.]]
# cell 115 written  epoch_id=[[2089.]]
# cell 116 written  epoch_id=[[2090.]]
# cell 117 written  epoch_id=[[2091.]]
# cell 118 written  epoch_id=[[2092.]]
# cell 119 written  epoch_id=[[2098.]]
# cell 120 written  epoch_id=[[2099.]]
# cell 121 written  epoch_id=[[2100.]]
# cell 122 written  epoch_id=[[2103.]]
# cell 123 written  epoch_id=[[2104.]]
# cell 124 written  epoch_id=[[2115.]]
# cell 125 written  epoch_id=[[2116.]]
# cell 126 written  epoch_id=[[2117.]]
# cell 127 written  epoch_id=[[2121.]]
# cell 128 written  epoch_id=[[2122.]]
# cell 129 written  epoch_id=[[2127.]]
# cell 130 written  epoch_id=[[2133.]]
# cell 131 written  epoch_id=[[2134.]]
# cell 132 written  epoch_id=[[2139.]]
# cell 133 written  epoch_id=[[2141.]]
# cell 134 written  epoch_id=[[2153.]]
# cell 135 written  epoch_id=[[2155.]]
# cell 136 written  epoch_id=[[2156.]]
# cell 137 written  epoch_id=[[2159.]]
# cell 138 written  epoch_id=[[2162.]]
# cell 139 written  epoch_id=[[2167.]]
# cell 140 written  epoch_id=[[2172.]]
# cell 141 written  epoch_id=[[2173.]]
# cell 142 written  epoch_id=[[2174.]]
# cell 143 written  epoch_id=[[2184.]]
# cell 144 written  epoch_id=[[2188.]]
# cell 145 written  epoch_id=[[2198.]]
# cell 146 written  epoch_id=[[2204.]]
# cell 147 written  epoch_id=[[2207.]]
# cell 148 written  epoch_id=[[2212.]]
# cell 149 written  epoch_id=[[2214.]]
# cell 150 written  epoch_id=[[2215.]]
# cell 151 written  epoch_id=[[2219.]]
# cell 152 written  epoch_id=[[2221.]]
# cell 153 written  epoch_id=[[2223.]]
# cell 154 written  epoch_id=[[2224.]]
# cell 155 written  epoch_id=[[2225.]]
# cell 156 written  epoch_id=[[2226.]]
# cell 157 written  epoch_id=[[2228.]]
# cell 158 written  epoch_id=[[2229.]]
# cell 159 written  epoch_id=[[2231.]]
# cell 160 written  epoch_id=[[2233.]]
# cell 161 written  epoch_id=[[2237.]]
# cell 162 written  epoch_id=[[2238.]]
# cell 163 written  epoch_id=[[2251.]]
# cell 164 written  epoch_id=[[2253.]]
# cell 165 written  epoch_id=[[2257.]]
# cell 166 written  epoch_id=[[2261.]]
# cell 167 written  epoch_id=[[2264.]]
# cell 168 written  epoch_id=[[2276.]]
# cell 169 written  epoch_id=[[2278.]]
# cell 170 written  epoch_id=[[2279.]]
# cell 171 written  epoch_id=[[2282.]]
# cell 172 written  epoch_id=[[2283.]]
# cell 173 written  epoch_id=[[2284.]]
# cell 174 written  epoch_id=[[2286.]]
# cell 175 written  epoch_id=[[2293.]]
# cell 176 written  epoch_id=[[2294.]]
# cell 177 written  epoch_id=[[2296.]]
# cell 178 written  epoch_id=[[2299.]]
# cell 179 written  epoch_id=[[2301.]]
# cell 180 written  epoch_id=[[2302.]]
# cell 181 written  epoch_id=[[2303.]]
# cell 182 written  epoch_id=[[2304.]]
# cell 183 written  epoch_id=[[2305.]]
# cell 184 written  epoch_id=[[2307.]]
# cell 185 written  epoch_id=[[2308.]]
# cell 186 written  epoch_id=[[2309.]]
# cell 187 written  epoch_id=[[2312.]]
# cell 188 written  epoch_id=[[2314.]]
# cell 189 written  epoch_id=[[2317.]]
# cell 190 written  epoch_id=[[2322.]]
# cell 191 written  epoch_id=[[2323.]]
# cell 192 written  epoch_id=[[2327.]]
# cell 193 written  epoch_id=[[2329.]]
# cell 194 written  epoch_id=[[2332.]]
# cell 195 written  epoch_id=[[2334.]]
# cell 196 written  epoch_id=[[2337.]]
# cell 197 written  epoch_id=[[2339.]]
# cell 198 written  epoch_id=[[2344.]]
# cell 199 written  epoch_id=[[2345.]]
# cell 200 written  epoch_id=[[2346.]]
# cell 201 written  epoch_id=[[2350.]]
# cell 202 written  epoch_id=[[2358.]]
# cell 203 written  epoch_id=[[2359.]]
# cell 204 written  epoch_id=[[2361.]]
# cell 205 written  epoch_id=[[2365.]]
# cell 206 written  epoch_id=[[2369.]]
# cell 207 written  epoch_id=[[2373.]]
# cell 208 written  epoch_id=[[2375.]]
# cell 209 written  epoch_id=[[2376.]]
# cell 210 written  epoch_id=[[2380.]]
# cell 211 written  epoch_id=[[2389.]]
# cell 212 written  epoch_id=[[2390.]]
# cell 213 written  epoch_id=[[2391.]]
# cell 214 written  epoch_id=[[2396.]]
# cell 215 written  epoch_id=[[2397.]]
# cell 216 written  epoch_id=[[2404.]]
# cell 217 written  epoch_id=[[2406.]]
# cell 218 written  epoch_id=[[2407.]]
# cell 219 written  epoch_id=[[2410.]]
# cell 220 written  epoch_id=[[2414.]]
# cell 221 written  epoch_id=[[2415.]]
# cell 222 written  epoch_id=[[2416.]]
# cell 223 written  epoch_id=[[2417.]]
# cell 224 written  epoch_id=[[2421.]]
# cell 225 written  epoch_id=[[2423.]]
# cell 226 written  epoch_id=[[2436.]]
# cell 227 written  epoch_id=[[2439.]]
# cell 228 written  epoch_id=[[2441.]]
# cell 229 written  epoch_id=[[2444.]]
# cell 230 written  epoch_id=[[2447.]]
# cell 231 written  epoch_id=[[2449.]]
# cell 232 written  epoch_id=[[2450.]]
# cell 233 written  epoch_id=[[2454.]]
# cell 234 written  epoch_id=[[2456.]]
# cell 235 written  epoch_id=[[2460.]]
# cell 236 written  epoch_id=[[2463.]]
# cell 237 written  epoch_id=[[2465.]]
# cell 238 written  epoch_id=[[2466.]]
# cell 239 written  epoch_id=[[2478.]]
# cell 240 written  epoch_id=[[2484.]]
# cell 241 written  epoch_id=[[2485.]]
# cell 242 written  epoch_id=[[2488.]]
# cell 243 written  epoch_id=[[2490.]]
# cell 244 written  epoch_id=[[2491.]]
# cell 245 written  epoch_id=[[2494.]]
# cell 246 written  epoch_id=[[2495.]]
# cell 247 written  epoch_id=[[2499.]]
# cell 248 written  epoch_id=[[2500.]]
# cell 249 written  epoch_id=[[2506.]]
# cell 250 written  epoch_id=[[2507.]]
# cell 251 written  epoch_id=[[2509.]]
# cell 252 written  epoch_id=[[2511.]]
# cell 253 written  epoch_id=[[2512.]]
# cell 254 written  epoch_id=[[2516.]]
# cell 255 written  epoch_id=[[2517.]]
# cell 256 written  epoch_id=[[2520.]]
# cell 257 written  epoch_id=[[2523.]]
# cell 258 written  epoch_id=[[2525.]]
# cell 259 written  epoch_id=[[2529.]]
# cell 260 written  epoch_id=[[2531.]]
# cell 261 written  epoch_id=[[2532.]]
# cell 262 written  epoch_id=[[2535.]]
# cell 263 written  epoch_id=[[2538.]]
# cell 264 written  epoch_id=[[2544.]]
# cell 265 written  epoch_id=[[2549.]]
# cell 266 written  epoch_id=[[2553.]]
# cell 267 written  epoch_id=[[2555.]]
# cell 268 written  epoch_id=[[2561.]]
# cell 269 written  epoch_id=[[2563.]]
# cell 270 written  epoch_id=[[2564.]]
# cell 271 written  epoch_id=[[2567.]]
# cell 272 written  epoch_id=[[2569.]]
# cell 273 written  epoch_id=[[2570.]]
# cell 274 written  epoch_id=[[2571.]]
# cell 275 written  epoch_id=[[2573.]]
# cell 276 written  epoch_id=[[2578.]]
# cell 277 written  epoch_id=[[2579.]]
# cell 278 written  epoch_id=[[2580.]]
# cell 279 written  epoch_id=[[2581.]]
# cell 280 written  epoch_id=[[2593.]]
# cell 281 written  epoch_id=[[2594.]]
# cell 282 written  epoch_id=[[2596.]]
# cell 283 written  epoch_id=[[2601.]]
# cell 284 written  epoch_id=[[2602.]]
# cell 285 written  epoch_id=[[2603.]]
# cell 286 written  epoch_id=[[2610.]]
# cell 287 written  epoch_id=[[2611.]]
# cell 288 written  epoch_id=[[2612.]]
# cell 289 written  epoch_id=[[2615.]]
# cell 290 written  epoch_id=[[2620.]]
# cell 291 written  epoch_id=[[2626.]]
# cell 292 written  epoch_id=[[2627.]]
# cell 293 written  epoch_id=[[2629.]]
# cell 294 written  epoch_id=[[2630.]]
# cell 295 written  epoch_id=[[2634.]]
# cell 296 written  epoch_id=[[2635.]]
# cell 297 written  epoch_id=[[2644.]]
# cell 298 written  epoch_id=[[2646.]]
# cell 299 written  epoch_id=[[2648.]]
# cell 300 written  epoch_id=[[2653.]]
# cell 301 written  epoch_id=[[2662.]]
# cell 302 written  epoch_id=[[2663.]]
# cell 303 written  epoch_id=[[2664.]]
# cell 304 written  epoch_id=[[2665.]]
# cell 305 written  epoch_id=[[2669.]]
# cell 306 written  epoch_id=[[2670.]]
# cell 307 written  epoch_id=[[2672.]]
# cell 308 written  epoch_id=[[2674.]]
# cell 309 written  epoch_id=[[2675.]]
# cell 310 written  epoch_id=[[2680.]]
# cell 311 written  epoch_id=[[2686.]]
# cell 312 written  epoch_id=[[2688.]]
# cell 313 written  epoch_id=[[2689.]]
# cell 314 written  epoch_id=[[2691.]]
# cell 315 written  epoch_id=[[2696.]]
# cell 316 written  epoch_id=[[2697.]]
# cell 317 written  epoch_id=[[2699.]]
# cell 318 written  epoch_id=[[2700.]]
# cell 319 written  epoch_id=[[2701.]]
# cell 320 written  epoch_id=[[2702.]]
# cell 321 written  epoch_id=[[2705.]]
# cell 322 written  epoch_id=[[2707.]]
# cell 323 written  epoch_id=[[2709.]]
# cell 324 written  epoch_id=[[2711.]]
# cell 325 written  epoch_id=[[2714.]]
# cell 326 written  epoch_id=[[2715.]]
# cell 327 written  epoch_id=[[2726.]]
# cell 328 written  epoch_id=[[2727.]]
# cell 329 written  epoch_id=[[2729.]]
# cell 330 written  epoch_id=[[2733.]]
# cell 331 written  epoch_id=[[2737.]]
# cell 332 written  epoch_id=[[2742.]]
# cell 333 written  epoch_id=[[2753.]]
# cell 334 written  epoch_id=[[2755.]]
# cell 335 written  epoch_id=[[2757.]]
# cell 336 written  epoch_id=[[2761.]]
# cell 337 written  epoch_id=[[2767.]]
# cell 338 written  epoch_id=[[2772.]]
# cell 339 written  epoch_id=[[2773.]]
# cell 340 written  epoch_id=[[2774.]]
# cell 341 written  epoch_id=[[2779.]]
# cell 342 written  epoch_id=[[2780.]]
# cell 343 written  epoch_id=[[2781.]]
# cell 344 written  epoch_id=[[2786.]]
# cell 345 written  epoch_id=[[2789.]]
# cell 346 written  epoch_id=[[2791.]]
# cell 347 written  epoch_id=[[2796.]]
# cell 348 written  epoch_id=[[2797.]]
# cell 349 written  epoch_id=[[2798.]]
# cell 350 written  epoch_id=[[2803.]]
# cell 351 written  epoch_id=[[2808.]]
# cell 352 written  epoch_id=[[2815.]]
# cell 353 written  epoch_id=[[2818.]]
# cell 354 written  epoch_id=[[2821.]]
# cell 355 written  epoch_id=[[2822.]]
# cell 356 written  epoch_id=[[2830.]]
# cell 357 written  epoch_id=[[2831.]]
# cell 358 written  epoch_id=[[2834.]]
# cell 359 written  epoch_id=[[2838.]]
# cell 360 written  epoch_id=[[2839.]]
# cell 361 written  epoch_id=[[2843.]]
# cell 362 written  epoch_id=[[2847.]]
# cell 363 written  epoch_id=[[2848.]]
# cell 364 written  epoch_id=[[2851.]]
# cell 365 written  epoch_id=[[2854.]]
# cell 366 written  epoch_id=[[2856.]]
# cell 367 written  epoch_id=[[2861.]]
# cell 368 written  epoch_id=[[2862.]]
# cell 369 written  epoch_id=[[2865.]]
# cell 370 written  epoch_id=[[2867.]]
# cell 371 written  epoch_id=[[2869.]]
# cell 372 written  epoch_id=[[2870.]]
# cell 373 written  epoch_id=[[2872.]]
# cell 374 written  epoch_id=[[2877.]]
# cell 375 written  epoch_id=[[2881.]]
# cell 376 written  epoch_id=[[2884.]]
# cell 377 written  epoch_id=[[2889.]]
# cell 378 written  epoch_id=[[2890.]]
# cell 379 written  epoch_id=[[2893.]]
# cell 380 written  epoch_id=[[2895.]]
# cell 381 written  epoch_id=[[2898.]]
# cell 382 written  epoch_id=[[2899.]]
# cell 383 written  epoch_id=[[2903.]]
# cell 384 written  epoch_id=[[2906.]]
# cell 385 written  epoch_id=[[2912.]]
# cell 386 written  epoch_id=[[2914.]]
# cell 387 written  epoch_id=[[2916.]]
# cell 388 written  epoch_id=[[2919.]]
# cell 389 written  epoch_id=[[2921.]]
# cell 390 written  epoch_id=[[2923.]]
# cell 391 written  epoch_id=[[2925.]]
# cell 392 written  epoch_id=[[2926.]]
# cell 393 written  epoch_id=[[2935.]]
# cell 394 written  epoch_id=[[2936.]]
# cell 395 written  epoch_id=[[2941.]]
# cell 396 written  epoch_id=[[2944.]]
# cell 397 written  epoch_id=[[2945.]]
# cell 398 written  epoch_id=[[2948.]]
# cell 399 written  epoch_id=[[2951.]]
# cell 400 written  epoch_id=[[2953.]]
# cell 401 written  epoch_id=[[2955.]]
# cell 402 written  epoch_id=[[2961.]]
# cell 403 written  epoch_id=[[2962.]]
# cell 404 written  epoch_id=[[2971.]]
# cell 405 written  epoch_id=[[2972.]]
# cell 406 written  epoch_id=[[2974.]]
# cell 407 written  epoch_id=[[2975.]]
# cell 408 written  epoch_id=[[2977.]]
# cell 409 written  epoch_id=[[2983.]]
# cell 410 written  epoch_id=[[2989.]]
# cell 411 written  epoch_id=[[2990.]]
# cell 412 written  epoch_id=[[2991.]]
# cell 413 written  epoch_id=[[2992.]]
# cell 414 written  epoch_id=[[2994.]]
# cell 415 written  epoch_id=[[3000.]]
# cell 416 written  epoch_id=[[3001.]]
# cell 417 written  epoch_id=[[3002.]]
# cell 418 written  epoch_id=[[3006.]]
# cell 419 written  epoch_id=[[3008.]]
# cell 420 written  epoch_id=[[3010.]]
# cell 421 written  epoch_id=[[3011.]]
# cell 422 written  epoch_id=[[3013.]]
# cell 423 written  epoch_id=[[3014.]]
# cell 424 written  epoch_id=[[3015.]]
# cell 425 written  epoch_id=[[3022.]]
# cell 426 written  epoch_id=[[3027.]]
# cell 427 written  epoch_id=[[3036.]]
# cell 428 written  epoch_id=[[3040.]]
# cell 429 written  epoch_id=[[3043.]]
# cell 430 written  epoch_id=[[3052.]]
# cell 431 written  epoch_id=[[3058.]]
# cell 432 written  epoch_id=[[3062.]]
# cell 433 written  epoch_id=[[3065.]]
# cell 434 written  epoch_id=[[3067.]]
# cell 435 written  epoch_id=[[3071.]]
# cell 436 written  epoch_id=[[3074.]]
# cell 437 written  epoch_id=[[3075.]]
# cell 438 written  epoch_id=[[3077.]]
# cell 439 written  epoch_id=[[3080.]]
# cell 440 written  epoch_id=[[3085.]]
# cell 441 written  epoch_id=[[3086.]]
# cell 442 written  epoch_id=[[3090.]]
# cell 443 written  epoch_id=[[3092.]]
# cell 444 written  epoch_id=[[3093.]]
# cell 445 written  epoch_id=[[3096.]]
# cell 446 written  epoch_id=[[3097.]]
# cell 447 written  epoch_id=[[3098.]]
# cell 448 written  epoch_id=[[3103.]]
# cell 449 written  epoch_id=[[3104.]]
# cell 450 written  epoch_id=[[3105.]]
# cell 451 written  epoch_id=[[3107.]]
# cell 452 written  epoch_id=[[3110.]]
# cell 453 written  epoch_id=[[3112.]]
# cell 454 written  epoch_id=[[3121.]]
# cell 455 written  epoch_id=[[3122.]]
# cell 456 written  epoch_id=[[3123.]]
# cell 457 written  epoch_id=[[3127.]]
# cell 458 written  epoch_id=[[3130.]]
# cell 459 written  epoch_id=[[3131.]]
# cell 460 written  epoch_id=[[3139.]]
# cell 461 written  epoch_id=[[3144.]]
# cell 462 written  epoch_id=[[3145.]]
# cell 463 written  epoch_id=[[3147.]]
# cell 464 written  epoch_id=[[3152.]]
# cell 465 written  epoch_id=[[3153.]]
# cell 466 written  epoch_id=[[3154.]]
# cell 467 written  epoch_id=[[3158.]]
# cell 468 written  epoch_id=[[3165.]]
# cell 469 written  epoch_id=[[3168.]]
# cell 470 written  epoch_id=[[3171.]]
# cell 471 written  epoch_id=[[3172.]]
# cell 472 written  epoch_id=[[3174.]]
# cell 473 written  epoch_id=[[3176.]]
# cell 474 written  epoch_id=[[3179.]]
# cell 475 written  epoch_id=[[3181.]]
# cell 476 written  epoch_id=[[3184.]]
# cell 477 written  epoch_id=[[3185.]]
# cell 478 written  epoch_id=[[3190.]]
# cell 479 written  epoch_id=[[3193.]]
# cell 480 written  epoch_id=[[3194.]]
# cell 481 written  epoch_id=[[3195.]]
# cell 482 written  epoch_id=[[3196.]]
# cell 483 written  epoch_id=[[3197.]]
# cell 484 written  epoch_id=[[3200.]]
# cell 485 written  epoch_id=[[3205.]]
# cell 486 written  epoch_id=[[3206.]]
# cell 487 written  epoch_id=[[3209.]]
# cell 488 written  epoch_id=[[3214.]]
# cell 489 written  epoch_id=[[3218.]]
# cell 490 written  epoch_id=[[3221.]]
# cell 491 written  epoch_id=[[3226.]]
# cell 492 written  epoch_id=[[3228.]]
# cell 493 written  epoch_id=[[3230.]]
# cell 494 written  epoch_id=[[3238.]]
# cell 495 written  epoch_id=[[3239.]]
# cell 496 written  epoch_id=[[3243.]]
# cell 497 written  epoch_id=[[3244.]]
# cell 498 written  epoch_id=[[3250.]]
# cell 499 written  epoch_id=[[3253.]]
# cell 500 written  epoch_id=[[3255.]]
# cell 501 written  epoch_id=[[3256.]]
# cell 502 written  epoch_id=[[3260.]]
# cell 503 written  epoch_id=[[3262.]]
# cell 504 written  epoch_id=[[3265.]]
# cell 505 written  epoch_id=[[3266.]]
# cell 506 written  epoch_id=[[3279.]]
# cell 507 written  epoch_id=[[3280.]]
# cell 508 written  epoch_id=[[3285.]]
# cell 509 written  epoch_id=[[3287.]]
# cell 510 written  epoch_id=[[3290.]]
# cell 511 written  epoch_id=[[3292.]]
# cell 512 written  epoch_id=[[3295.]]
# cell 513 written  epoch_id=[[3297.]]
# cell 514 written  epoch_id=[[3301.]]
# cell 515 written  epoch_id=[[3309.]]
# cell 516 written  epoch_id=[[3311.]]
# cell 517 written  epoch_id=[[3312.]]
# cell 518 written  epoch_id=[[3316.]]
# cell 519 written  epoch_id=[[3317.]]
# cell 520 written  epoch_id=[[3322.]]
# cell 521 written  epoch_id=[[3323.]]
# cell 522 written  epoch_id=[[3325.]]
# cell 523 written  epoch_id=[[3326.]]
# cell 524 written  epoch_id=[[3331.]]
# cell 525 written  epoch_id=[[3334.]]
# cell 526 written  epoch_id=[[3335.]]
# cell 527 written  epoch_id=[[3337.]]
# cell 528 written  epoch_id=[[3343.]]
# cell 529 written  epoch_id=[[3346.]]
# cell 530 written  epoch_id=[[3347.]]
# cell 531 written  epoch_id=[[3351.]]
# cell 532 written  epoch_id=[[3352.]]
# cell 533 written  epoch_id=[[3354.]]
# cell 534 written  epoch_id=[[3355.]]
# cell 535 written  epoch_id=[[3356.]]
# cell 536 written  epoch_id=[[3357.]]
# cell 537 written  epoch_id=[[3360.]]
# cell 538 written  epoch_id=[[3361.]]
# cell 539 written  epoch_id=[[3369.]]
# cell 540 written  epoch_id=[[3370.]]
# cell 541 written  epoch_id=[[3375.]]
# cell 542 written  epoch_id=[[3376.]]
# cell 543 written  epoch_id=[[3381.]]
# cell 544 written  epoch_id=[[3382.]]
# cell 545 written  epoch_id=[[3388.]]
# cell 546 written  epoch_id=[[3389.]]
# cell 547 written  epoch_id=[[3390.]]
# cell 548 written  epoch_id=[[3394.]]
# cell 549 written  epoch_id=[[3395.]]
# cell 550 written  epoch_id=[[3401.]]
# cell 551 written  epoch_id=[[3402.]]
# cell 552 written  epoch_id=[[3404.]]
# cell 553 written  epoch_id=[[3412.]]
# cell 554 written  epoch_id=[[3413.]]
# cell 555 written  epoch_id=[[3415.]]
# cell 556 written  epoch_id=[[3418.]]
# cell 557 written  epoch_id=[[3421.]]
# cell 558 written  epoch_id=[[3424.]]
# cell 559 written  epoch_id=[[3429.]]
# cell 560 written  epoch_id=[[3431.]]
# cell 561 written  epoch_id=[[3437.]]
# cell 562 written  epoch_id=[[3442.]]
# cell 563 written  epoch_id=[[3444.]]
# cell 564 written  epoch_id=[[3445.]]
# cell 565 written  epoch_id=[[3448.]]
# cell 566 written  epoch_id=[[3449.]]
# cell 567 written  epoch_id=[[3454.]]
# cell 568 written  epoch_id=[[3457.]]
# cell 569 written  epoch_id=[[3460.]]
# cell 570 written  epoch_id=[[3463.]]
# cell 571 written  epoch_id=[[3464.]]
# cell 572 written  epoch_id=[[3466.]]
# cell 573 written  epoch_id=[[3475.]]
# cell 574 written  epoch_id=[[3478.]]
# cell 575 written  epoch_id=[[3481.]]
# cell 576 written  epoch_id=[[3482.]]
# cell 577 written  epoch_id=[[3483.]]
# cell 578 written  epoch_id=[[3484.]]
# cell 579 written  epoch_id=[[3486.]]
# cell 580 written  epoch_id=[[3496.]]
# cell 581 written  epoch_id=[[3499.]]
# cell 582 written  epoch_id=[[3504.]]
# cell 583 written  epoch_id=[[3505.]]
# cell 584 written  epoch_id=[[3509.]]
# cell 585 written  epoch_id=[[3511.]]
# cell 586 written  epoch_id=[[3514.]]
# cell 587 written  epoch_id=[[3515.]]
# cell 588 written  epoch_id=[[3517.]]
# cell 589 written  epoch_id=[[3520.]]
# cell 590 written  epoch_id=[[3524.]]
# cell 591 written  epoch_id=[[3528.]]
# cell 592 written  epoch_id=[[3533.]]
# cell 593 written  epoch_id=[[3535.]]
# cell 594 written  epoch_id=[[3536.]]
# cell 595 written  epoch_id=[[3539.]]
# cell 596 written  epoch_id=[[3543.]]
# cell 597 written  epoch_id=[[3545.]]
# cell 598 written  epoch_id=[[3547.]]
# cell 599 written  epoch_id=[[3549.]]
# cell 600 written  epoch_id=[[3553.]]
# cell 601 written  epoch_id=[[3556.]]
# cell 602 written  epoch_id=[[3560.]]
# cell 603 written  epoch_id=[[3564.]]
# cell 604 written  epoch_id=[[3566.]]
# cell 605 written  epoch_id=[[3571.]]
# cell 606 written  epoch_id=[[3572.]]
# cell 607 written  epoch_id=[[3574.]]
# cell 608 written  epoch_id=[[3575.]]
# cell 609 written  epoch_id=[[3580.]]
# cell 610 written  epoch_id=[[3584.]]
# cell 611 written  epoch_id=[[3586.]]
# cell 612 written  epoch_id=[[3591.]]
# cell 613 written  epoch_id=[[3595.]]
# cell 614 written  epoch_id=[[3596.]]
# cell 615 written  epoch_id=[[3597.]]
# cell 616 written  epoch_id=[[3598.]]
# cell 617 written  epoch_id=[[3601.]]
# cell 618 written  epoch_id=[[3606.]]
# cell 619 written  epoch_id=[[3607.]]
# cell 620 written  epoch_id=[[3618.]]
# cell 621 written  epoch_id=[[3620.]]
# cell 622 written  epoch_id=[[3621.]]
# cell 623 written  epoch_id=[[3625.]]
# cell 624 written  epoch_id=[[3626.]]
# cell 625 written  epoch_id=[[3627.]]
# cell 626 written  epoch_id=[[3628.]]
# cell 627 written  epoch_id=[[3630.]]
# cell 628 written  epoch_id=[[3635.]]
# cell 629 written  epoch_id=[[3639.]]
# cell 630 written  epoch_id=[[3641.]]
# cell 631 written  epoch_id=[[3645.]]
# cell 632 written  epoch_id=[[3651.]]
# cell 633 written  epoch_id=[[3653.]]
# cell 634 written  epoch_id=[[3656.]]
# cell 635 written  epoch_id=[[3658.]]
# cell 636 written  epoch_id=[[3662.]]
# cell 637 written  epoch_id=[[3670.]]
# cell 638 written  epoch_id=[[3672.]]
# cell 639 written  epoch_id=[[3675.]]
# cell 640 written  epoch_id=[[3676.]]
# cell 641 written  epoch_id=[[3679.]]
# cell 642 written  epoch_id=[[3687.]]
# cell 643 written  epoch_id=[[3698.]]
# cell 644 written  epoch_id=[[3705.]]
# cell 645 written  epoch_id=[[3707.]]
# cell 646 written  epoch_id=[[3709.]]
# cell 647 written  epoch_id=[[3711.]]
# cell 648 written  epoch_id=[[3712.]]
# cell 649 written  epoch_id=[[3713.]]
# cell 650 written  epoch_id=[[3717.]]
# cell 651 written  epoch_id=[[3722.]]
# cell 652 written  epoch_id=[[3725.]]
# cell 653 written  epoch_id=[[3726.]]
# cell 654 written  epoch_id=[[3727.]]
# cell 655 written  epoch_id=[[3731.]]
# cell 656 written  epoch_id=[[3735.]]
# cell 657 written  epoch_id=[[3736.]]
# cell 658 written  epoch_id=[[3737.]]
# cell 659 written  epoch_id=[[3740.]]
# cell 660 written  epoch_id=[[3741.]]
# cell 661 written  epoch_id=[[3743.]]
# cell 662 written  epoch_id=[[3744.]]
# cell 663 written  epoch_id=[[3752.]]
# cell 664 written  epoch_id=[[3762.]]
# cell 665 written  epoch_id=[[3763.]]
# cell 666 written  epoch_id=[[3769.]]
# cell 667 written  epoch_id=[[3771.]]
# cell 668 written  epoch_id=[[3772.]]
# cell 669 written  epoch_id=[[3773.]]
# cell 670 written  epoch_id=[[3778.]]
# cell 671 written  epoch_id=[[3780.]]
# cell 672 written  epoch_id=[[3783.]]
# cell 673 written  epoch_id=[[3786.]]
# cell 674 written  epoch_id=[[3790.]]
# cell 675 written  epoch_id=[[3791.]]
# cell 676 written  epoch_id=[[3792.]]
# cell 677 written  epoch_id=[[3793.]]
# cell 678 written  epoch_id=[[3795.]]
